# %%
import pandas as pd
from tqdm import tqdm
from langchain_community.llms import Ollama

# %% [markdown]
# # Dataset

# %%
bbc_df = pd.read_csv('../../datasets/BBC News/BBC News Train.csv')
bbc_df = bbc_df.sample(n=735, random_state=42).reset_index(drop=True) # 735 samples to imitate test set (which is unlabelled)
bbc_df
# Out:
#      ArticleId                                               Text  \
# 0         2160  wal-mart is sued over rude lyrics the parents ...
# 1         1360  howard taunts blair over splits tony blair s f...
# 2          302  fox attacks blair s tory  lies  tony blair lie...
# 3          864  online commons to spark debate online communit...
# 4         2184  piero gives rugby perspective bbc sport unveil...
# ..         ...                                                ...
# 730        512  big guns ease through in san jose top-seeded a...
# 731        905  marsh executive in guilty plea an executive at...
# 732        351  sky takes over oscar night mantle sky has sign...
# 733        603  pension hitch for long-living men male life ex...
# 734       2064  campbell rescues arsenal sol campbell proved t...
#
#           Category
# 0    entertainment
# 1         politics
# 2         politics
# 3             tech
# 4             tech
# ..             ...
# 730          sport
# 731       business
# 732  entertainment
# 733       business
# 734          sport
#
# [735 rows x 3 columns]

# %% [markdown]
# # Modeling

# %%
llm = Ollama(model="gemma2")
# Out:
# /var/folders/87/dhv__9sj0yv1kz0pfv2ds9nh0000gn/T/ipykernel_17194/2721138275.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="gemma2")

# %% [markdown]
# ### Step 0 - Defining Topics according to the dataset

# %%
all_topics = [
'sport', 'business', 'politics', 'tech', 'entertainment' 
 ]

# %% [markdown]
# ### Step 3 - Assigning batches of dataset to Topics Generated in Step 2 and sentiment of the review

# %%
def assign_topics_in_batches(input_df, topics, batch_size, llm=None):
    """
    Assign topics to News Group in batches and update DataFrame directly.

    Parameters:
    input_df (pd.DataFrame): DataFrame containing Amazon reviews
    topics (str): String of topics to assign from
    batch_size (int): Number of reviews to process in each batch
    llm: The language model instance to use for assigning topics

    Returns:
    pd.DataFrame: Updated DataFrame with topic and sentiment assignments
    """
    if llm is None:
        raise ValueError("LLM instance must be provided")

    # Create a copy of the DataFrame to avoid modifying the original
    df = input_df.copy()

    # Initialize Topic and Sentiment columns with 'Unknown'
    df['Predicted Topic'] = 'Unknown'

    total_df = len(df)

    # Process reviews in batches with progress bar
    for start_idx in tqdm(range(0, total_df, batch_size), desc="Assigning topics"):
        end_idx = min(start_idx + batch_size, total_df)
        batch_news_list = df.iloc[start_idx:end_idx]
        batch_news = " ".join([f"Item {i + 1}: {review}," for i, review in enumerate(batch_news_list['Text'])])
        
        # Generate prompt for current batch
        prompt_assigning_prompt = f'''You are provided with news and helping to cluster them based on the topics.
Please assign the news to the topics provided. Return only the name of the topic for the respective nwes.
News can be found in tripletick block: ```{batch_news}```
Topics to choose from: {topics}
Please return in CSV format only topics for respective reviews and nothing else. Do not use triple backtick blocks. Only output exactly as on the example below:
Example: Having an input of News1, News2, News3, News4, News5, ... NewsN
Output: Topic1, Topic2, Topic3, Topic4, Topic5, ... TopicN
'''
        # Get assignments for current batch
        result = llm.invoke(prompt_assigning_prompt, temperature=0.0)
        try:
            # Get assignments for current batch
            result = llm.invoke(prompt_assigning_prompt, temperature=0.0)
            
            # Clean and split the result
            result = result.strip()
            if result.startswith('```') and result.endswith('```'):
                result = result[3:-3].strip()
            batch_assigned_topics = [topic.strip() for topic in result.split(',')]
            
            # Make sure we have the right number of topics
            current_batch_size = len(batch_news)
            
            # Update each row individually to avoid alignment issues
            for idx, topic in enumerate(batch_assigned_topics):
                current_idx = start_idx + idx
                if current_idx < len(df):
                    df.iloc[current_idx, df.columns.get_loc('Predicted Topic')] = topic
                    
        except Exception as e:
            print(f"\nError processing batch {start_idx}-{end_idx}: {str(e)}")
            print(f"Result received: {result}")
            print(f"Batch size: {current_batch_size}")
            print(f"Number of topics received: {len(batch_assigned_topics) if 'batch_assigned_topics' in locals() else 'N/A'}")
            continue
    return df

# %%
news_assigned = assign_topics_in_batches(
    bbc_df,
    topics=str(all_topics),
    batch_size=1,
    llm=llm
)
# Out:
# Assigning topics:   0%|          | 0/735 [00:00<?, ?it/s]
# Assigning topics: 100%|██████████| 735/735 [39:28<00:00,  3.22s/it]

# %%
news_assigned.to_csv('outputs/bbc_news_assigned.csv', index=False)

# %%
news_assigned = pd.read_csv('outputs/bbc_news_assigned.csv')

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score

def calculate_metrics(y_true, y_pred):
    """
    Calculate various classification metrics
    
    Parameters:
    y_true: True labels (actual categories)
    y_pred: Predicted labels
    
    Returns:
    dict: Dictionary containing various metrics
    """
    # Calculate individual metrics
    accuracy = (y_true == y_pred).mean()
    f1 = f1_score(y_true, y_pred, average='weighted')
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    
    # Get detailed classification report
    report = classification_report(y_true, y_pred)
    
    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred)
    
    metrics = {
        'accuracy': accuracy * 100,
        'f1_score': f1 * 100,
        'precision': precision * 100,
        'recall': recall * 100,
        'detailed_report': report,
        'confusion_matrix': conf_matrix
    }
    
    return metrics

# Using your existing data
metrics = calculate_metrics(
    news_assigned['Category'],
    news_assigned['Predicted Topic']
)

# Print results
print(f"Accuracy: {metrics['accuracy']:.2f}%")
print(f"F1 Score: {metrics['f1_score']:.2f}%")
print(f"Precision: {metrics['precision']:.2f}%")
print(f"Recall: {metrics['recall']:.2f}%")
print("\nDetailed Classification Report:")
print(metrics['detailed_report'])
# Out:
# Accuracy: 94.97%
# F1 Score: 94.93%
# Precision: 95.16%
# Recall: 94.97%
#
# Detailed Classification Report:
#                precision    recall  f1-score   support
#
#      business       0.99      0.88      0.93       169
# entertainment       0.94      0.98      0.96       128
#      politics       0.90      0.98      0.94       140
#         sport       0.96      1.00      0.98       162
#          tech       0.96      0.91      0.94       136
#
#      accuracy                           0.95       735
#     macro avg       0.95      0.95      0.95       735
#  weighted avg       0.95      0.95      0.95       735

# %%
news_assigned[news_assigned['Category'] != news_assigned['Predicted Topic']]
# Out:
#      ArticleId                                               Text  \
# 3          864  online commons to spark debate online communit...
# 4         2184  piero gives rugby perspective bbc sport unveil...
# 8          140  rich grab half colombia poor fund half of the ...
# 39        1969  brussels raps mobile call charges the european...
# 79        1503  iran budget seeks state sell-offs iran s presi...
# 110        182  blogger grounded by her airline a us airline a...
# 132        510  dutch watch van gogh s last film the last film...
# 169       1336  musicians  upbeat  about the net musicians are...
# 172       1820  halo fans  hope for sequel xbox video game hal...
# 187        548  ink helps drive democracy in asia the kyrgyz r...
# 193       1553  attack prompts bush site block the official re...
# 222        643  borussia dortmund near bust german football cl...
# 250       2073  hatfield executives go on trial engineering fi...
# 290       1730  us prepares for hybrid onslaught sales of hybr...
# 294       1533  saudi ministry to employ women women will be e...
# 382       1540  holmes wins  2004 top tv moment  sprinter kell...
# 417       2003  salary scandal in cameroon cameroon says wides...
# 437       1342  georgia plans hidden asset pardon georgia is o...
# 442       1118  tsunami slows sri lanka s growth sri lanka s p...
# 457       1565  ultimate game  award for doom 3 sci-fi shooter...
# 462        764  shares rise on new man utd offer shares in man...
# 480        430  venezuela identifies  idle  farms venezuelan a...
# 487       1846  rescue hope for borussia dortmund shares in st...
# 498       2108  game warnings  must be clearer  violent video ...
# 502       1749  id theft surge hits us consumers almost a quar...
# 511       1331  palestinian economy in decline despite a short...
# 517       1338  big war games battle it out the arrival of new...
# 535        957  web radio takes spanish rap global spin the ra...
# 558       1253  blinx sequel purrs nicely the original blinx w...
# 560       1185  man auctions ad space on forehead a 20-year-ol...
# 575        528  bank payout to pinochet victims a us bank has ...
# 585       1275  nasdaq planning $100m share sale the owner of ...
# 586       1582  howard  truanted to play snooker  conservative...
# 592       1012  making your office work for you our mission to...
# 688        410  eu aiming to fuel development aid european uni...
# 713        787  german jobless rate at new record more than 5....
# 733        603  pension hitch for long-living men male life ex...
#
#           Category Predicted Topic
# 3             tech        politics
# 4             tech           sport
# 8         business        politics
# 39        business            tech
# 79        business        politics
# 110           tech        business
# 132  entertainment        politics
# 169           tech   entertainment
# 172           tech   entertainment
# 187           tech        politics
# 193           tech        politics
# 222       business           sport
# 250       politics        business
# 290       business            tech
# 294       business        politics
# 382  entertainment           sport
# 417       business        politics
# 437       business        politics
# 442       business        politics
# 457           tech   entertainment
# 462       business           sport
# 480       business        politics
# 487       business           sport
# 498       politics   entertainment
# 502       business            tech
# 511       business        politics
# 517           tech   entertainment
# 535           tech   entertainment
# 558           tech   entertainment
# 560           tech   entertainment
# 575       business        politics
# 585       business            tech
# 586       politics           sport
# 592       business            tech
# 688       business        politics
# 713       business        politics
# 733       business        politics
