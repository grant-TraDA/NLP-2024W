# %% [markdown]
# # Nazwiska grupy
# # Stanisław Kurzątkowski
# # Patrycja Wysocka
# # Łukasz Jaremek

# %%
import nltk                                # Python library for NLP
from nltk.corpus import twitter_samples    # sample Twitter dataset from NLTK
from nltk.corpus import stopwords
import matplotlib.pyplot as plt            # library for visualization
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# We can load the text fields of the positive and negative tweets by using the module's `strings()` method like this:

# %%
# select the set of positive and negative tweets
import nltk
nltk.download('twitter_samples')

import nltk
nltk.download('stopwords')

all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\Studia\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Studia\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# To make it easier, let us used pandas dataframe

# %%
# Create a dataframe from positive tweets
pos_tweet = pd.DataFrame(all_positive_tweets, columns=['Tweet'])
# Add a column to dataframe for positive sentiment value 1
pos_tweet['Sentiment'] = 1
# Create a temporary dataframe for negative tweets
neg_tweet = pd.DataFrame(all_negative_tweets, columns=['Tweet'])
# Add a column to temporary dataframe for negative sentiment value 0
neg_tweet['Sentiment'] = 0
# Combe positive and negative tweets in one single dataframe
df = pd.concat([neg_tweet, pos_tweet], ignore_index=True)
# df = pos_tweet.append(neg_tweet, ignore_index=True)
df = df.sample(frac = 1) 
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                   Tweet  Sentiment
# 0     Tips ONLINE!\n6/7 WINNERS yesterday!\nJust 1 g...          0
# 1                       @norman__g lucky spike only :-(          0
# 2                      Wacky :D https://t.co/UThCcBQnKD          1
# 3                              @EmmaLK Looks painful :(          0
# 4     “@Johnny_Spacey: @Mandi_Tinker yes, very incon...          0
# ...                                                 ...        ...
# 9995                           @kapucumerve sakin ol :)          1
# 9996  I don't think I can watch degrassi for about 4...          0
# 9997  I will fulfil all your fantasies :) 👉 http://t...          1
# 9998                :( lmfaoooo https://t.co/Gu0QjHPMnX          0
# 9999  I could just really use a hug and maybe some i...          0
#
# [10000 rows x 2 columns]

# %% [markdown]
# Next, we'll print a report with the number of positive and negative tweets. It is also essential to know the data structure of the datasets

# %%
# Displaying shape of dataset
print('Dataset size:',df.shape)
df.groupby('Sentiment').count()
# Out:
# Dataset size: (10000, 2)
#            Tweet
# Sentiment
# 0           5000
# 1           5000

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(df,test_size = 0.1)
train
# Out:
#                                                   Tweet  Sentiment
# 4137  #FollowFriday @StayfanChemin @CCI_75 @aandreup...          1
# 1676          @my_nameis_dan Download only isn't it? :(          0
# 3479  The taxi driver thought me and Sophie worked f...          0
# 1500  @Dinnerbone *Future MegaMoh in 7/29/2015* Happ...          1
# 6379               @NotThatBobJames Hahaha Go Doug! :-)          1
# ...                                                 ...        ...
# 4574  @BigMammaJosie lil bitch, Heiya, visit my site...          1
# 7684  @MandaScapinello oh yeah?? I am definitely goi...          1
# 5163  Bowling is always best with friends :) http://...          1
# 2061  @caylahhhh lmfao seriously??? I can't remember...          0
# 5485  I felt bad when Irene forgot what she was goin...          0
#
# [9000 rows x 2 columns]

# %%
test
# Out:
#                                                   Tweet  Sentiment
# 6373                         @ThisOneNerd thank you! :D          1
# 3859  #FollowFriday @murtishaw @aqui_fr @FRTechStart...          1
# 8621  If you want a dm to justin let me know and I'l...          1
# 9847                i lagg so much on certain people :(          0
# 1847             @Miss_Dyna_Mite hi 5 back to you :) :)          1
# ...                                                 ...        ...
# 7269  ♛♛♛\n》》》》 \nI LOVE YOU SO MUCH.\nI BELİEVE THA...          0
# 4537  @Anbu002 @Pranto_ahp Hey guys! We know about t...          1
# 516                          im still giddy over d1 :-(          0
# 5923  YKR SPARKY\n40mm, 3.5 grs\nROCKFISHING, topwat...          1
# 6536         Horrible weather to be going to work in :(          0
#
# [1000 rows x 2 columns]

# %%
train_pos = train[ train['Sentiment'] == 1]
train_pos = train_pos['Tweet']
train_neg = train[ train['Sentiment'] == 0]
train_neg = train_neg['Tweet']


# def wordcloud_draw(data, color = 'black'):
#     words = ' '.join(data)
#     cleaned_word = " ".join([word for word in words.split()
#                             if 'http' not in word
#                                 and not word.startswith('@')
#                                 and not word.startswith('#')
#                                 and word != 'RT'
#                             ])

#     wordcloud = WordCloud(stopwords=STOPWORDS,
#                       background_color=color,
#                       width=2500,
#                       height=2000
#                      ).generate(cleaned_word)

#     plt.figure(1,figsize=(13, 13))
#     plt.imshow(wordcloud)
#     plt.axis('off')
#     plt.show()


# print("Positive words")
# wordcloud_draw(train_pos,'white')
# print("Negative words")
# wordcloud_draw(train_neg)
# Out:
# Positive words
# Negative words

# %%
                
# tweets = []
# stopwords_set = set(stopwords.words("english"))

# for index, row in train.iterrows():
#     words_filtered = [e.lower() for e in row.Tweet.split() if len(e) >= 3]
#     words_cleaned = [word for word in words_filtered
#         if 'http' not in word
#         and not word.startswith('@')
#         and not word.startswith('#')
#         and word != 'RT']
#     words_without_stopwords = [word for word in words_cleaned if not word in stopwords_set]
#     tweets.append((words_without_stopwords, row.Sentiment))

# test_pos = test[ test['Sentiment'] == 1]
# test_pos = test_pos['Tweet']
# test_neg = test[ test['Sentiment'] == 0]
# test_neg = test_neg['Tweet']

# %%
# # Extracting word features
# def get_words_in_tweets(tweets):
#     all = []
#     for (words, sentiment) in tweets:
#         all.extend(words)
#     return all


# def get_word_features(wordlist):
#     wordlist = nltk.FreqDist(wordlist)
#     features = wordlist.keys()
#     return features
# w_features = get_word_features(get_words_in_tweets(tweets))


# def extract_features(document):
#     document_words = set(document)
#     features = {}
#     for word in w_features:
#         features['contains(%s)' % word] = (word in document_words)
#     return features

# %%
# wordcloud_draw(w_features)

# %%
# tweets
# Out:
# [(['top', 'influencers', 'community', 'week'], 1),
#  (['download', 'it?'], 0),
#  (['taxi',
#    'driver',
#    'thought',
#    'sophie',
#    'worked',
#    'nintendo',
#    'took',
#    'gates',
#    'security',
#    'guards',
#    'gave',
#    'dirtiest',
#    'looks',
#    'haha'],
#   0),
#  (['*future', 'megamoh', '7/29/2015*', 'happy', 'birthday'], 1),
#  (['hahaha', 'doug!', ':-)'], 1),
#  (['liked', 'video', 'pasha', 'crying', 'terrible', 'donate'], 0),
#  (['beat', 'beat', 'sits', 'well', '(includes', 'new', 'video)', ':-)'], 1),
#  (['insurance',
#    'loss/stolen',
#    'accidentally',
#    'damaged',
#    'devices.',
#    'warranty',
#    'repairs',
#    'sent',
#    'repair',
#    'centre.'],
#   0),
#  (['still', 'really', 'miss', 'purple', 'hair', 'tie'], 0),
#  (['sometimes',
#    'sometimes',
#    'drown',
#    'half',
#    'bottle',
#    'nyquil',
#    'throat',
#    'effect'],
#   0),
#  (['goodnight',
#    'liam',
#    'hope',
#    'fantastic',
#    'day',
#    'today',
#    'sweet',
#    'dreams',
#    'baby',
#    'love',
#    'heart',
#    'xx.'],
#   1),
#  (['answer', 'fans', 'sleep', '???'], 0),
#  (['sure', 'wasnt', 'anything', "we're", 'already', 'used', 'glad', 'home!'],
#   1),
#  (["that's", 'build', 'sunday'], 1),
#  (['happy', 'birthday'], 1),
#  (['good', 'morning', ':))', 'drinkt', 'koffie'], 1),
#  (['know', 'is,', 'saying', 'know'], 1),
#  (['read'], 1),
#  (['omg', 'amber', ':(('], 0),
#  (['sick'], 0),
#  (['feytyaz', 'follback'], 1),
#  (['sweet', 'tooth!'], 1),
#  (['"@boy_hugots:',
#    'never',
#    'give',
#    'up.',
#    'best',
#    'things',
#    'take',
#    'time."',
#    'weh'],
#   0),
#  (['birthday',
#    'proves',
#    'favourite',
#    'news',
#    'reader',
#    'impeccable',
#    'fashion',
#    'sense'],
#   1),
#  (['bring',
#    'graphic',
#    'design',
#    'web',
#    'design',
#    'skills',
#    'next',
#    'level',
#    'learn',
#    'more:...'],
#   1),
#  (['secret!'], 0),
#  (['hayeee',
#    'hayeee',
#    'patwari',
#    'mam',
#    "ik's",
#    'vision',
#    'would',
#    'say',
#    'nothing',
#    'rather',
#    'lil',
#    'laugh'],
#   0),
#  (['given',
#    'sunburnt',
#    'managed',
#    'get',
#    'weekend,',
#    'maybe',
#    "i'll",
#    'safer',
#    'rain'],
#   0),
#  (['stats', 'day', 'arrived.', 'new', 'followers', 'unfollowers', 'via'], 1),
#  (['brief',
#    'introduction',
#    'earliest',
#    'history',
#    'subcontinent',
#    'even',
#    'bfr',
#    'mauryas:'],
#   1),
#  (['know',
#    'song',
#    'disappears',
#    'phone',
#    'itunes?',
#    "i've",
#    'lost',
#    'dazed',
#    'confused'],
#   0),
#  (['sad', 'manage', 'get', 'tickets', ':-('], 0),
#  ([':((', 'ill', 'make', 'another', 'one'], 0),
#  (['thanks', 'updating', 'profile', 'page', ':-)'], 1),
#  (['stop', 'sour', 'suit'], 0),
#  (["he's", 'always', 'gunna', 'former', 'leeds', 'manager'], 0),
#  (['“@ketchburning:', 'hate', 'japanese', 'call', '"bani"', ':(”'], 0),
#  (['honestly',
#    'love',
#    'dad',
#    'much',
#    "i'm",
#    'slightly',
#    'upset',
#    "i'm",
#    'seeing',
#    'birthday'],
#   0),
#  (['guys', 'add', 'kik', 'pely829'], 0),
#  (['sounds', 'good', "i'll", 'see', 'saturday'], 1),
#  (['food',
#    'kitchen,',
#    'money',
#    'wallet',
#    '(thanks',
#    'barcelona)',
#    'dad',
#    'home',
#    'month',
#    'beet',
#    'juice',
#    'either'],
#   0),
#  (['got', 'sleep', 'medicine,', 'imma', 'till', 'tomorrow', 'take', ':((('],
#   0),
#  (['gawd',
#    'really',
#    'need',
#    'get',
#    'more....',
#    'understood',
#    'whole',
#    'thing'],
#   0),
#  (['said',
#    'remedy',
#    'pak',
#    'prob',
#    'raiz',
#    'voice',
#    'nvr',
#    'up.wt',
#    'now?wt',
#    'imran',
#    'achieved?in',
#    'short',
#    '"thr',
#    'soln',
#    'pak',
#    'prob"'],
#   0),
#  (['middle', 'figuring', 'choreo', ':((', 'next', 'time', 'girl!!'], 0),
#  (['wahahaah.'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x10'],
#   1),
#  (['lol.', 'well.', "that's", 'life', 'thank', 'god', 'enn'], 1),
#  (['truly',
#    'better',
#    'feeling',
#    'mtg',
#    'getting',
#    'thoughtseized',
#    'twice',
#    'first',
#    'rounds',
#    'game',
#    'take',
#    'playables',
#    'away'],
#   0),
#  (['later', 'feel', 'place', ':(('], 0),
#  (['lart'], 0),
#  (['someone', 'talk', 'cant', 'sleep', 'ill', 'talk', 'anything', 'want'], 1),
#  (['found', 'flight', 'home', 'hours', 'long', ':((((((('], 0),
#  (['been,', 'sheriff?', 'seen', 'aaaaaaaaaaa', 'aaaaages', ':(('], 0),
#  (['discontinued',
#    'product,',
#    'sophie.',
#    'really',
#    'sorry',
#    'disappointment',
#    'pass',
#    'feedback',
#    'on!'],
#   0),
#  (['good',
#    'morning',
#    'dear',
#    'friends',
#    '&lt;3',
#    'listen',
#    'trance',
#    'lover"',
#    'enjoy',
#    'happy',
#    'friday',
#    '&lt;3'],
#   1),
#  (['omfg', 'harry', 'pls', 'bae', 'ignore'], 0),
#  (['someone', 'harry', 'potter', 'marathon', ':(('], 0),
#  (['funny'], 0),
#  (['time', 'party'], 1),
#  (['angeke',
#    'sbali!',
#    '"@ami_khang:',
#    'euuuwwww',
#    'lunch.',
#    'like',
#    'real',
#    'construction',
#    'worker',
#    ':-('],
#   0),
#  (['totally', 'slept', 'alarms', "can't", 'gym'], 0),
#  (['nou', 'youre', ':-(', 'picture', 'adam'], 0),
#  (['going', 'room', ':-)'], 1),
#  (['hey',
#    'guys!',
#    "i'll",
#    'live',
#    'mins!',
#    'want',
#    'fun',
#    'low',
#    'ranked',
#    'games',
#    'subgames',
#    'faceit',
#    'today?',
#    ':)...'],
#   1),
#  (['hey,',
#    'information',
#    'give',
#    'argos',
#    'card',
#    'ring',
#    '0345',
#    '640',
#    'nad'],
#   1),
#  (['love', 'sucks', 'it?'], 1),
#  (['yay!',
#    "can't",
#    'wait!',
#    'hope',
#    'keep',
#    'swimming',
#    'riding',
#    'recently,',
#    'best'],
#   1),
#  (['wanna', 'loser', 'like'], 1),
#  (["t'would", 'tweetup', 'without', 'booked', 'rest', 'assured.', 'booked'],
#   1),
#  (['proud!!',
#    'night',
#    'social',
#    'app',
#    'katerina',
#    'maniataki',
#    'design',
#    'ideas',
#    'via'],
#   1),
#  (['happy', 'friday', ':-)'], 1),
#  (['little', 'suggestion', 'another', 'day'], 1),
#  (['followed', 'thanks,', 'please', 'followed'], 0),
#  (['bad', 'day???:-('], 0),
#  (['anymore', ':-('], 0),
#  (['“@anelempupa:',
#    'vandag"@chatlas:',
#    'long',
#    'ass',
#    'month...re',
#    'kgola',
#    'neng',
#    'eintlik?!'],
#   0),
#  (['anyone',
#    'managed',
#    'get',
#    'yet?',
#    'keep',
#    'getting',
#    'busy',
#    'messages.',
#    'think',
#    'worse',
#    'tube',
#    'strike'],
#   0),
#  (['reynoldsgrl',
#    'either',
#    'deactivated',
#    'got',
#    'suspended',
#    'wanted',
#    'shade'],
#   0),
#  (['team', 'killed'], 0),
#  (['thank', 'you,', 'lovely', 'weekend!'], 1),
#  (['please?', 'okay', 'tho.', 'sooooooooo', 'soooo', 'hard', 'get', 'follow'],
#   0),
#  (['macbook?'], 1),
#  ([], 1),
#  (["can't", 'even', 'see', 'hyungwon'], 0),
#  (['sad',
#    'long',
#    'though.',
#    'maybe',
#    'little',
#    'longer',
#    '&amp;',
#    'love',
#    'it?',
#    'restarted',
#    'assassins',
#    'creed',
#    'heaps,',
#    'fell',
#    'love'],
#   0),
#  (['stats', 'day', 'arrived.', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['family', 'hang', '^_^', 'feeling', 'festive', 'jamuna', 'future', 'park'],
#   1),
#  (["thank's", 'follow', 'kevens'], 1),
#  (['amazing!',
#    'glad',
#    'hear',
#    'could',
#    'make',
#    'friday',
#    'morning',
#    'little',
#    'better',
#    ':-)',
#    '^ks'],
#   1),
#  ([':-(',
#    'maternity',
#    'discrimination:',
#    'needed',
#    'boss,',
#    'kicked',
#    'teeth',
#    '...'],
#   0),
#  (['deantd', ':-('], 0),
#  (['embarrassing', 'texted', 'wrong', 'organization', 'gosh'], 0),
#  (['lols.'], 1),
#  (["i'm", 'supposed', 'ask', 'buy', 'albums'], 1),
#  (['god'], 0),
#  (['great', 'stuff'], 1),
#  (['course,',
#    "that's",
#    'understand',
#    'it.',
#    'noticed',
#    'issue',
#    'well.',
#    'phileas',
#    'club',
#    'inc',
#    'tomorrow!'],
#   1),
#  (['cares?', 'haha'], 1),
#  (['sad',
#    'dream',
#    'boys',
#    'rtd',
#    'me,',
#    'louis',
#    '&amp;',
#    'harry',
#    'followed',
#    'woke',
#    '&amp;',
#    'true.'],
#   0),
#  (['wanna', 'feel', 'loved'], 0),
#  (['yes..cant', 'see', 'rider.:('], 0),
#  (['hay'], 1),
#  (['told',
#    'survive',
#    'living',
#    'alone',
#    'rest',
#    'life',
#    "can't",
#    'even',
#    'left',
#    'alone',
#    'day'],
#   0),
#  (['didnt'], 0),
#  (['please',
#    'help',
#    'getting',
#    'back',
#    'disabled',
#    'account.',
#    'really',
#    'really',
#    'need',
#    'back.'],
#   0),
#  (['rip', 'whitney', 'houston.'], 0),
#  (['chill',
#    'smu',
#    'oval',
#    "'coz",
#    'basketball',
#    'player',
#    'now.',
#    'whahahaha!'],
#   1),
#  (["there's", 'totally', 'stomping'], 0),
#  (['same.', ':((((('], 0),
#  (['local', 'legend'], 0),
#  (['bantime:'], 1),
#  (['rude'], 0),
#  (['rela', 'building'], 1),
#  (['buuuut', 'want', ':(((('], 0),
#  (['looking', 'fun?', 'snapchat', 'jillcruz18'], 0),
#  (['hello', 'ligao', 'city,', 'albay!', ':-)'], 1),
#  (['make', 'dms', 'open', 'pls', 'questions', 'ask', 'hehe'], 1),
#  (['feeling', 'sick'], 0),
#  (['chickmt123:',
#    'greymind43:',
#    'breaking',
#    'news:',
#    'chris',
#    'gayle',
#    'says',
#    'cricket',
#    '2-3',
#    'months',
#    'due',
#    'back',
#    'surgery.',
#    ':(…'],
#   0),
#  (['question', 'flawed.', 'pain', 'negate', 'strength'], 1),
#  (['miss'], 0),
#  (['video:', 'sararocs:', 'angry', 'world'], 0),
#  (['course',
#    'understand',
#    '&gt;&gt;&gt;"@khalila_:',
#    "y'all",
#    'gonna',
#    'ignore',
#    'questions',
#    'huh?',
#    'niqqa',
#    'desperate',
#    'need',
#    'answers',
#    'lol"'],
#   0),
#  (['gaaawd'], 0),
#  (['awww',
#    'thanks',
#    'guys!!',
#    'wishing',
#    'wicked',
#    'weekend',
#    'travel',
#    'safe!'],
#   1),
#  (['upside'], 1),
#  (['follow', 'stay', 'updated', ':-)'], 1),
#  (["i'd", 'man', 'work', 'right'], 0),
#  (['hahaha!', 'bailey', 'may', 'fan', 'boy', 'ariana', 'grande!!'], 1),
#  (['please', 'follow'], 0),
#  (['chat', 'detail', 'project', 'inshallah', 'ready'], 1),
#  (['went', 'bed', 'headache...woke', 'headache'], 0),
#  (['delphy', 'injured'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x29'],
#   1),
#  (['guys', 'great', 'weekend', 'too!:)'], 1),
#  (['♛♛♛',
#    '》》》》',
#    'love',
#    'much.',
#    'beli̇eve',
#    'wi̇ll',
#    'follow.',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15.347',
#    '》》》》ｓｅｅ',
#    '♛♛♛'],
#   0),
#  (['yes', 'bbq', 'attend'], 0),
#  (['seem',
#    'burned',
#    'everything',
#    'apart',
#    'tea',
#    'morning.',
#    'bravo',
#    'friday',
#    'too,',
#    'richard.',
#    ':-('],
#   0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x30'],
#   1),
#  (['wow',
#    'right',
#    "i'm",
#    'done',
#    'school',
#    '(for',
#    'short',
#    'while)',
#    'internet',
#    'decides',
#    'act',
#    'like',
#    'bitch',
#    ':(('],
#   0),
#  (['wet', 'feet', 'welcome', 'carpet', 'to,worry'], 1),
#  (['school', 'monday', 'wanna', 'meet', 'new', 'people'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x46'],
#   1),
#  (['locked', 'house'], 0),
#  ([], 0),
#  (['yes',
#    'thanks',
#    'depressing',
#    'weather',
#    'forecast,',
#    'word',
#    "'rain'",
#    'mentioned',
#    'several',
#    'times',
#    ':-('],
#   0),
#  (['lets', 'take', 'lighter', 'down,', 'shall', 'we?', ':-)'], 1),
#  (['wanna', 'duo'], 0),
#  (['without', 'miss'], 0),
#  (['waiting', 'love', 'recuerda', 'tanto', 'bath', ':(('], 0),
#  (['white',
#    'things',
#    'ngeze',
#    'turn',
#    'white',
#    'parties',
#    "i've",
#    'to.',
#    'nothing',
#    'cocktaily',
#    'classy',
#    '😭😭😭',
#    'stressed.'],
#   0),
#  (['natsuki', 'often', 'writes', 'really', 'catchy', 'songs'], 1),
#  ([], 0),
#  (['tonight', 'got', 'photoshoooot'], 0),
#  (['joined', 'program'], 1),
#  (['me:',
#    'long',
#    'feel',
#    'comfortable',
#    'gonna',
#    'wear',
#    'want',
#    'mother:',
#    'haha...that',
#    'sounds',
#    'nice...but',
#    ':-)'],
#   1),
#  (['mamayang', '11pm', 'part', 'something', 'magic', '89.9', 'radio'], 1),
#  (['thank', 'bhaiya.', ':-)'], 1),
#  (['a9)', 'would', 'sad', 'world', 'women'], 0),
#  (['mayday', 'parade', 'feels'], 0),
#  (['watching',
#    'story',
#    'snapchat',
#    'killing',
#    'me.',
#    'whats',
#    'life',
#    'beach',
#    'pool',
#    'week',
#    'long',
#    'working',
#    'bitch'],
#   0),
#  (['ahaha',
#    "i'm",
#    'laying',
#    'bed',
#    'like',
#    'whyyyyyy.',
#    'pretty',
#    'wine',
#    'glasses',
#    'sucked'],
#   0),
#  (['it’s', 'raining', 'cold'], 0),
#  (['wanna', 'follow', 'personal', '!!!!', 'bye', 'guysss', ':))))'], 1),
#  (['found',
#    '&amp;',
#    'flow.',
#    'thanks',
#    'sharing',
#    ':-)',
#    'already',
#    'passed',
#    'like'],
#   1),
#  (['city', '0-2', 'madrid'], 0),
#  (['lol', 'really?"@praisekingdavid:', 'unlike', ':("'], 0),
#  (['ever', 'wanna', 'sleeep', 'let', 'mee'], 0),
#  (['♛♛♛',
#    '》》》》',
#    'love',
#    'much.',
#    'beli̇eve',
#    'wi̇ll',
#    'follow.',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15.332',
#    '》》》》ｓｅｅ',
#    '♛♛♛'],
#   0),
#  (['song',
#    'week',
#    'ducktails',
#    'surreal',
#    'exposure',
#    'jingly',
#    'jangly',
#    'loveliness!',
#    ':-)'],
#   1),
#  (['goood', 'hot', 'tan', 'line', 'ugly', 'going', 'home', 'tonight!:('], 0),
#  (['goodbye', '🚖🗽🌃'], 0),
#  (['happy', 'friday', ':-)'], 1),
#  (['ready'], 1),
#  (['stats', 'day', 'arrived.', 'new', 'follower', 'unfollowers', 'via'], 1),
#  ([], 0),
#  (['ugly', 'daniel,', 'good', 'ape?:)'], 1),
#  (['thanks', 'bae'], 1),
#  (['thanks'], 1),
#  (['every', 'way', 'like', 'jess.'], 1),
#  (['great',
#    'incentive',
#    'get',
#    'kids',
#    'eat',
#    'fruit',
#    '&amp;',
#    'veges',
#    ':-)'],
#   1),
#  (['goodmorning.', 'smile', 'debit', 'orders', 'soon', 'over.'], 1),
#  (['hello', 'get', 'youth', 'job', 'opportunities', 'follow', '&gt;&gt;'], 1),
#  (['always', 'nice', 'get', 'invite'], 1),
#  (["he's", 'cute'], 0),
#  (['lmao', 'hahahaha', 'slr', 'jgh', 'school', ':(('], 0),
#  (['waiting', 'bro', ':-)'], 1),
#  (['thanks',
#    'adding',
#    'list!',
#    'make',
#    'sure',
#    'keep',
#    'touch',
#    'news',
#    'light',
#    'bulbs',
#    'made',
#    'corn',
#    'waste.'],
#   1),
#  (['today', ':-('], 0),
#  (['hi!',
#    'saw',
#    'follow',
#    'thought',
#    'might',
#    'like',
#    '"dark"',
#    '.plz',
#    'let',
#    'know',
#    'think'],
#   1),
#  (['wanna', 'see', 'beautiful', 'rotate', 'photo', 'works.....'], 1),
#  (['dah', 'move', ':))'], 1),
#  (['yes!', 'appreciate', 'smile'], 1),
#  (['yeahhh', 'means', '"hacharatt'], 0),
#  (["i'm",
#    'still',
#    'awake',
#    'feeling',
#    'like',
#    'need',
#    'delete',
#    '80%',
#    'people',
#    'snap.'],
#   0),
#  (['blog',
#    'post',
#    '&gt;',
#    'hunger',
#    'games:',
#    'mockingjay',
#    'part',
#    '(2015):',
#    'teasers',
#    ':-)'],
#   1),
#  (["damn,it's",
#    'true',
#    '"@dailyteenwords:',
#    'moment',
#    'realize',
#    'holiday',
#    'almost',
#    'done',
#    'nothing."'],
#   0),
#  (['know,', 'right?', 'sure,', 'leave', 'huge', 'gap', 'comic', 'plots'], 0),
#  (['&amp;',
#    "can't",
#    'find',
#    'subtitles',
#    'oitnb',
#    'need',
#    'understand',
#    'changs',
#    'backstory'],
#   0),
#  (['cant',
#    'wait',
#    'truck',
#    'fixed',
#    'missin',
#    'hangin',
#    'wiff',
#    'mah',
#    'friends',
#    'time.'],
#   0),
#  (['life',
#    'remember',
#    'one',
#    'time',
#    'years',
#    'ago',
#    'changed',
#    'avi',
#    'lost',
#    'followers',
#    'looooool'],
#   0),
#  (['thx', 'follow'], 1),
#  (["can't", 'able', 'view', 'pics', 'da..', 'wat', 'pic', 'this?'], 0),
#  (['missin', 'homeslice', 'bday', ':((', '&lt;/333'], 0),
#  (['scary', 'dream', '&amp;', "can't", 'back', 'sleep', ':-(((('], 0),
#  (['soon...'], 1),
#  (['like', 'consumerism', 'treat', 'soul'], 1),
#  (['&amp;',
#    'yup',
#    'in-shaa-allah',
#    'make',
#    'dua',
#    '&amp;',
#    'see',
#    'thru',
#    'hatreds',
#    '&amp;',
#    'move',
#    'towards',
#    'truth.',
#    'aameen',
#    '(4/5)'],
#   1),
#  (['yeah', 'horrible', 'big', 'hugs!', '&amp;', 'means', 'lot.'], 0),
#  (['morning!', 'sheffield', 'excited', 'starts', 'today.', "who's", 'going?'],
#   1),
#  (['still', 'havent', 'found', 'handsome', 'jack', 'drawing', ':(((('], 0),
#  (['beautiful...winter?', 'like', 'summer', 'russia'], 1),
#  (["i'd", 'willing', 'try', 'that!'], 1),
#  (['always', 'welcome', 'dear.', ':-)', 'good', 'afternoon.', '..:-)'], 1),
#  (['smooth', 'handover'], 0),
#  (['nowhere', 'near', 'tired'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x36'],
#   1),
#  (['happier', 'running', 'around', 'house', 'wearing', 'h&amp;m', 'shirt.'],
#   0),
#  (['fulfil', 'fantasies'], 1),
#  (['saw', 'mine', 'huhu', '....', ':((('], 0),
#  (['jumma', 'kareem', 'friday', 'reminder:', 'recite', 'surah', 'kahaf..'], 1),
#  (['counting.'], 0),
#  (['smile,'], 1),
#  (['supposedly', 'one', 'worst', 'kernels', 'device'], 0),
#  (['morning', ':-)))'], 1),
#  (['looking', 'fun?', 'kik', 'slacke565'], 0),
#  (['india', 'become', 'developed', 'nation'], 0),
#  (['jadi',
#    'langsung',
#    'flasback',
#    '"@ggstepit:',
#    'dont',
#    'cry',
#    'babyy',
#    ';("'],
#   0),
#  (['fave', 'unfollows', ':(😩💖'], 0),
#  (['top', 'influencers', 'community', 'week'], 1),
#  (['darn'], 0),
#  (['lol.hook'], 1),
#  (['thanks',
#    'bunch',
#    'hope',
#    'get',
#    'training',
#    'among',
#    'you.',
#    'hopefully',
#    'find',
#    'something.'],
#   0),
#  (['nice', 'connect', 'yael'], 1),
#  (['going', 'streaming', 'soon'], 1),
#  (['one', 'days', 'think', 'would', 'love', 'meet', 'person.'], 1),
#  (['freaking', 'cat', 'cuddle', ':-('], 0),
#  (['hahahahahahahahahahahahahaha',
#    'dying',
#    ':))',
#    'literally',
#    'front',
#    'like'],
#   1),
#  (['done'], 1),
#  (['miss', 'seeing', 'krystoria', 'moments'], 0),
#  (['days', 'without', 'talking', 'bae'], 0),
#  (['good', 'afternoon'], 1),
#  (['money', 'belle', 'sebastian', 'ticket', 'sale', 'absolutely', 'kills'], 0),
#  (['woohyun',
#    'seems',
#    'weird',
#    'inspirit',
#    'shining',
#    'night...',
#    'ised',
#    'seeing',
#    'like',
#    'this........',
#    'happened'],
#   0),
#  (['online',
#    'days',
#    'ago!',
#    'like',
#    'notifs',
#    'days',
#    'dammit',
#    'stop',
#    'guys',
#    'lol',
#    '&lt;3'],
#   0),
#  (['current', 'mood', ':-)'], 1),
#  (['love', 'you..sad', 'front'], 0),
#  (['idaho',
#    'restrict',
#    'fishing',
#    'despite',
#    'regional',
#    'drought-linked',
#    'die-of...',
#    ':-('],
#   0),
#  (['want', 'meet'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x28'],
#   1),
#  (['appreciate',
#    'weekly',
#    'update',
#    'weapons',
#    'ever',
#    'way?',
#    'nowhere',
#    'put',
#    'one',
#    'already'],
#   0),
#  (["i'm", 'coughing.'], 0),
#  (["i'm",
#    'rude!',
#    'saying',
#    'help..',
#    'me.so',
#    'might',
#    'help',
#    'others',
#    'tho.',
#    'good',
#    'idea'],
#   1),
#  (['thaaanks!', 'december', 'puhon.', ':))'], 1),
#  (['yes', 'fridays.'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x19'],
#   1),
#  (['miss', 'pleasanton', 'friends'], 0),
#  (['want', 'cri', 'one', ':((((((('], 0),
#  (['new', 'video', 'people,', 'check'], 1),
#  (['tack!', ':-)'], 1),
#  (["i'm",
#    'confused',
#    'put',
#    'inital',
#    'location?',
#    'asking',
#    'location',
#    'destination'],
#   0),
#  (['funny'], 0),
#  (['lovely', 'lovelayyy!', 'thanks!', 'kidney..', 'want', 'anyway.'], 1),
#  (['movie',
#    'different',
#    'book',
#    'still!!!',
#    'ikr',
#    'tams',
#    'boses',
#    'lang',
#    'theo',
#    'ugh',
#    'miss',
#    'more!!!'],
#   0),
#  (['aww',
#    'poor',
#    'thing',
#    'hope',
#    "it'okay",
#    'good',
#    'health.',
#    'luckely',
#    'freed',
#    'rocks'],
#   0),
#  (['wanna',
#    'home',
#    'bring',
#    'english',
#    'food',
#    "i'll",
#    'gladly',
#    'stay',
#    ':(('],
#   0),
#  (['tomorrow', ':((('], 0),
#  (['idea.', 'weeks,', "i've", 'say', 'rip', 'hats'], 0),
#  (['never', 'talks', 'racial', 'issues', ':(('], 0),
#  (['love', ':-)'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x34'],
#   1),
#  (['happy', 'tweeting!', 'liking', 'new', 'build?', '^mm'], 1),
#  (['eyes',
#    'men',
#    'speak',
#    'words',
#    'tongue',
#    'cannot',
#    'pronounce.',
#    'native',
#    'american',
#    'proverb'],
#   1),
#  (['name', 'couple', 'yet??', ':))'], 1),
#  (['probs', 'fun', 'david'], 0),
#  (['justinbieber',
#    'pls',
#    'follow',
#    '&gt;daianerufato&lt;',
#    "i've",
#    'trying',
#    'long',
#    'ilysm',
#    'bae!',
#    '(july',
#    '24,',
#    '2015',
#    '07:02am)'],
#   0),
#  (['yep,', '*are*', 'expert', 'bisexuality', 'good', 'luck!'], 1),
#  (['♛♛♛',
#    '》》》》',
#    'love',
#    'much.',
#    'beli̇eve',
#    'wi̇ll',
#    'follow.',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15.318',
#    '》》》》ｓｅｅ',
#    '♛♛♛'],
#   0),
#  (["we've",
#    'received',
#    'payment',
#    'order',
#    'processed',
#    'thanks',
#    'shopping',
#    'spree!'],
#   1),
#  (['girl'], 1),
#  (['plan',
#    'watching',
#    'later)',
#    'mins',
#    'leia',
#    'appears',
#    'hologram',
#    'r2d2',
#    'message',
#    'obi',
#    'wan',
#    'sits',
#    'luke'],
#   1),
#  (['twitter',
#    'help',
#    'center',
#    'can&amp;#39;t',
#    'follow',
#    'people?',
#    'via',
#    'really',
#    'really',
#    'sorry',
#    'following',
#    'evry',
#    'one'],
#   0),
#  (['ah.',
#    'good',
#    'luck',
#    'then.',
#    'cat',
#    'used',
#    'let',
#    'house',
#    'something',
#    'play',
#    'winter.',
#    'fast',
#    'little',
#    'buggers'],
#   0),
#  (['no...not',
#    'face',
#    'enough',
#    'that...just',
#    'face',
#    'flesh.',
#    'know',
#    'daft..but',
#    'cope',
#    'it!',
#    ':-('],
#   0),
#  (['please', 'come', 'netherlands', ':(('], 0),
#  (['never', 'seeing', 'dad', 'midnight', 'worked', 'hard', 'fuck'], 0),
#  (['dat',
#    'tho.',
#    'thank',
#    'much',
#    'guys',
#    'celebrating',
#    'one',
#    'month',
#    'partnership',
#    'me!!!',
#    'raid!'],
#   1),
#  (['luv', 'urs', ':-)'], 1),
#  (['made', 'song', 'plz', 'give', 'feedback', 'link::'], 1),
#  (['omg', "can't", 'tell', 'say', "can't", 'wait', 'know', '!!!!'], 1),
#  (['nobody', 'cares', 'optimisation', ':((('], 0),
#  (['greet', '"welcome', 'loyal', 'subjects', 'life', 'debt', '":)'], 1),
#  (['sending.', 'finally!!!!!!!!!!!!!!'], 0),
#  (['thanks', 'following', 'happy', 'friday'], 1),
#  (['dii', 'cant', 'forget', 'sis'], 1),
#  (['looking', 'fun?', 'kik', 'vaing642'], 1),
#  (['already'], 1),
#  (['hyungwon', 'beautiful', 'now!!!!!!!!'], 0),
#  (['bed'], 0),
#  (["i'm",
#    'frustrated',
#    'planks.',
#    'times',
#    'super',
#    'inconsistent,',
#    'idea',
#    "i'm",
#    'wrong.'],
#   0),
#  ([], 1),
#  (['bro:u',
#    'wan',
#    'cut',
#    'hair',
#    'anot,ur',
#    'hair',
#    'long',
#    'liao',
#    'me:since',
#    'ord',
#    'liao,take',
#    'easy',
#    'lor',
#    'treat',
#    'save',
#    'leave',
#    'longer',
#    'bro:lol',
#    'sibei',
#    'xialan'],
#   1),
#  (['music', 'bank', 'encore', 'always', 'short'], 0),
#  (["i'm", 'inactive'], 0),
#  (['good', 'mornin', 'beautiful', 'yapsters', ':-)', 'happy', 'friday', ':-)'],
#   1),
#  (['nobody', 'picking', 'one', 'right'], 0),
#  (['watching', 'game?'], 0),
#  (['btw', 'remember...'], 1),
#  (['leeds?', 'wanna', 'see', 'live'], 0),
#  (['love?'], 0),
#  (['day', 'practice', 'songs'], 1),
#  (['ehdar', 'pegea', 'panga', 'dosto', 'open', 'link', 'read', 'news'], 0),
#  (['fuck',
#    'sake',
#    'hamstring',
#    'injury',
#    'delph',
#    ':-(',
#    'another',
#    'rodwell'],
#   0),
#  (['act',
#    'mischievousness,',
#    'calling',
#    'etl',
#    'layer',
#    'in-house',
#    'warehousing',
#    'app',
#    'katamari.',
#    'well…',
#    'name',
#    'implies',
#    ':p.'],
#   1),
#  (['feel', 'bad', 'helmy'], 0),
#  (['people', 'like', 'you,', 'fra...', 'kinda', 'selfish'], 0),
#  (['thank'], 1),
#  (['check', 'final', 'design'], 1),
#  (['yeah,', 'shogi', 'took'], 0),
#  (['playing',
#    '"give',
#    'heart',
#    'break"',
#    'memories',
#    '"the',
#    'breakup"',
#    'episode',
#    'love',
#    'song',
#    'tho'],
#   0),
#  (['aaaaaaaaaaaah', 'sound', 'kanye', 'makes', 'hey', 'mama', 'cute'], 0),
#  (['tired', 'yesterday', 'choroo', 'nahi'], 1),
#  (['hahahah', 'holy', 'shit!!!', 'comforting', 'why?'], 0),
#  (['like', 'michael', 'thanks', 'kind', 'words!', 'cheers,'], 1),
#  (['haha', 'indirecting', 'best', 'friend', ':))'], 1),
#  (['think',
#    "it'll",
#    'sam',
#    'would',
#    'love',
#    "he's",
#    'made',
#    'biggest',
#    'improvement',
#    'start'],
#   1),
#  (['stu', 'mean,', 'wanna', 'sleep'], 0),
#  (['country,',
#    'first',
#    'sign',
#    'decent',
#    'outdoor',
#    'rave',
#    'pisses',
#    'day',
#    "i've",
#    'pack...'],
#   1),
#  (['sad', 'moment', 'gon', 'vomit'], 0),
#  (['fwm'], 0),
#  (["i'm", 'really', 'sorry'], 0),
#  (['sleep', 'would', 'nice', ':-)'], 1),
#  ([], 0),
#  (['wish',
#    'you.',
#    'would',
#    'beat',
#    'home',
#    'numb',
#    'mouth',
#    'dentist',
#    'visit!'],
#   0),
#  (['crazy', 'hurts', 'much', 'know', 'shit', 'aint', 'real', 'edited'], 0),
#  (['9/11',
#    'kinda',
#    'ruined',
#    'me.',
#    'sound',
#    'makes',
#    'brace',
#    'hearing',
#    'plane',
#    'crash',
#    'every',
#    'time.',
#    'bueno.'],
#   0),
#  (['georgia',
#    'saffron',
#    'amazing',
#    'queens',
#    'poor',
#    'peasant',
#    'wish',
#    'could',
#    'like',
#    'them...'],
#   0),
#  (['pls',
#    'think',
#    'good',
#    'enough',
#    '^__________^',
#    'let',
#    'be.',
#    "he's",
#    'missing',
#    'chance',
#    'fault'],
#   0),
#  (['aur', 'han', 'imran', 'khan', 'still', 'younger', 'many.'], 1),
#  (['listening', 'everything', ':(('], 0),
#  (['thank', 'u!!'], 1),
#  (['hahaha',
#    'everyone',
#    'fun',
#    'story',
#    'related',
#    'song.',
#    'got',
#    'labeled',
#    'worst',
#    'batch',
#    'principal',
#    'due'],
#   1),
#  (['thanks', 'mom'], 1),
#  (['course,', 'would', 'like'], 1),
#  (['okayy'], 1),
#  (["i'm", 'freezing'], 0),
#  (['looking', 'way'], 0),
#  (['dave.'], 1),
#  (['baby', 'looks', 'good', 'black', ':(('], 0),
#  (['😪😪😪', 'tired', 'sis', 'wait', 'nas'], 0),
#  (['aww', 'thankyou'], 1),
#  (['precious', 'never', 'end'], 0),
#  (['civ', 'crashed', 'middle', 'marathon', 'game...'], 0),
#  (['mom', 'ignores', 'calls'], 0),
#  (['derek',
#    'trending',
#    'horrible',
#    'reasons',
#    'hope',
#    "he's",
#    'found',
#    'safe',
#    'well.'],
#   0),
#  (['happy', 'friday!'], 1),
#  (['hayst'], 0),
#  (['alright', 'sleep', 'well!:)'], 1),
#  (['rage', 'quit!!!'], 0),
#  (['thank', 'you!', ':-)'], 1),
#  (['perfect', 'evening', 'light', 'helped,', 'good', 'one', 'jackie'], 1),
#  (['*hug*', 'many'], 1),
#  (['emoji', ':((('], 0),
#  (['last',
#    'time',
#    'one',
#    'working',
#    'gone',
#    'too?',
#    'checked',
#    'long',
#    'time',
#    'lol'],
#   0),
#  (['notice', "i'm", 'hopeless'], 0),
#  (['know', 'fml'], 0),
#  (['miss', ':-('], 0),
#  (['hi!',
#    'would',
#    'like',
#    'concert?',
#    'let',
#    'know',
#    'city',
#    'country',
#    "i'll",
#    'start',
#    'working',
#    'it!',
#    'thanks'],
#   1),
#  (['nhe', 'yar'], 0),
#  (['morning!',
#    'hospital',
#    'day',
#    'today',
#    'hoping',
#    'finally',
#    'get',
#    'signed',
#    'long',
#    'year',
#    'pain',
#    'ops'],
#   1),
#  (["apma's"], 0),
#  (['thanks'], 1),
#  (['mean', 'offering?'], 0),
#  (['delighted,', "m'dear!:)"], 1),
#  (['yass', ':(:'], 0),
#  (['cheers', ':-)'], 1),
#  (['yes', 'please', 'would', 'great', 'work'], 1),
#  (['see', 'this,', 'follow', 'me?', "i'm", 'waiting', 'long'], 0),
#  (['biggest', 'blue', 'bottle', 'ever', 'come', "room...it's", 'room'], 0),
#  (['♛♛♛',
#    '》》》》',
#    'love',
#    'much.',
#    'beli̇eve',
#    'wi̇ll',
#    'follow.',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15.343',
#    '》》》》ｓｅｅ',
#    '♛♛♛'],
#   0),
#  (['add', 'kik', 'hiondsheings58543'], 0),
#  (['forwarding', "richard...it's", "'follow'"], 1),
#  (['thanks', 'sharing!', 'wishing', 'wicked', 'weekend'], 1),
#  (["they're",
#    'even',
#    'familiar',
#    'idea',
#    'snapchat.',
#    'sure',
#    'phones',
#    'question',
#    'bothered',
#    'enough?'],
#   1),
#  (['one', 'gift', '*feeling', 'jealous'], 0),
#  (['case', "didn't..", 'facebook', 'wall.'], 1),
#  (['happy',
#    'belated',
#    'birthday',
#    'cikaaa☺wish',
#    'best',
#    'o:)',
#    'maaf',
#    'telat',
#    'ngucapinnya'],
#   1),
#  (["i've",
#    'heard',
#    'four',
#    'seasons',
#    'pretty',
#    'dope.',
#    'penthouse,',
#    'obvs',
#    'fun',
#    "y'all"],
#   1),
#  (["can't",
#    'even',
#    'deliver',
#    'ice',
#    'cream.',
#    'tried',
#    'twice,',
#    'ice',
#    'cream',
#    'vans',
#    'busy'],
#   0),
#  (['hey!', 'lot', 'write', 'deathly', 'hallows', 'supernatural', 'go!'], 1),
#  (["can't",
#    'afford',
#    'please',
#    'give',
#    'first',
#    'full',
#    'mashup',
#    'pack',
#    'please'],
#   0),
#  (['ems', 'haha'], 0),
#  (['want', 'panem', 'end', 'love', 'books', 'movies'], 0),
#  (['elmhurst', ':-(', "i'll", 'always'], 0),
#  (['one', '"ok', "i'll", 'run', "photo'", 'moments'], 1),
#  (['know',
#    'average',
#    'takes',
#    'seconds',
#    'read',
#    'god',
#    'dam',
#    'mother',
#    'fucking',
#    'tweet.'],
#   1),
#  (["i'm", 'using', 'time', 'chat', 'seem', 'like', 'want', 'chat'], 0),
#  (['one', 'tree', 'hill', 'makes', 'cry', 'lot', '😕:-('], 0),
#  (['follow', 'mixcloud'], 1),
#  (["australia's",
#    "'dirtiest'",
#    'power',
#    'station',
#    'considers',
#    "'clean",
#    "energy'",
#    'biomass',
#    '...',
#    ':-('],
#   0),
#  (['dat', 'suks', 'want', 'old', 'sleeping', 'schedule', 'back'], 0),
#  (['cuz',
#    'thought',
#    'could',
#    'ask',
#    'team',
#    'snapchat',
#    'make',
#    'live',
#    'concert',
#    'since',
#    'last',
#    'concert',
#    'eunhae'],
#   0),
#  (['scoups^^', 'like', 'jren', 'nuest!:d'], 1),
#  (['hello!!', 'love', 'carter'], 1),
#  (['nakaka', 'beastmode.', 'lost'], 0),
#  (['shame', 'like', '£3k'], 0),
#  (['hello', 'get', 'youth', 'job', 'opportunities', 'follow', '&gt;&gt;'], 1),
#  (['people', 'wished', 'birthday.'], 0),
#  (['first', 'leg', 'tour', 'going', 'well!'], 1),
#  (['hates', 'now,', "that's", 'sure.', ':((('], 0),
#  (['yaaay', 'get', 'see', 'bff', 'tomorrow'], 1),
#  (["i'm",
#    'drugs',
#    'alcohol',
#    'apexis',
#    'crystal',
#    'meth',
#    'apexis',
#    'crystal',
#    'champagne',
#    'watching',
#    'apexis',
#    'crystal',
#    'palace'],
#   1),
#  ([':-)'], 1),
#  (['pre', "i'm", 'sick', 'huhu', 'sad', 'hahaha'], 0),
#  (['shanzay', 'salabraty', ':((('], 0),
#  (['happy',
#    'folks!!',
#    'order',
#    'online',
#    'get',
#    'upto',
#    '£40',
#    'cashback!!',
#    '(t&amp;cs',
#    'apply)'],
#   1),
#  (['need', 'translator'], 0),
#  ([':((((', 'thank', 'bby.', 'love', 'too.'], 0),
#  (['happy',
#    'birthday',
#    'amazingly',
#    'talanted',
#    'hope',
#    'year',
#    'brings',
#    'happiness',
#    'success',
#    'deserve',
#    'all.',
#    'cheers'],
#   1),
#  (['happy', 'birthday', 'mitch', ':-)', 'wish', 'best', 'good', 'day'], 1),
#  (['aww', 'thanks', 'anyway!!'], 0),
#  (['much'], 0),
#  (['praying', 'years,', 'avail', ':(('], 0),
#  ([':-)', 'nice', 'hair', 'tbh'], 1),
#  (['follow', '&amp;', 'follow', 'back'], 1),
#  (['zayn', ':(('], 0),
#  (['dont',
#    'know',
#    'huhu',
#    'tests',
#    'kasi',
#    'namin',
#    'didnt',
#    'finish',
#    'test',
#    ':-('],
#   0),
#  (['thanking'], 1),
#  (['looking', 'fun?', 'kik', 'thencerest547'], 1),
#  (['finished',
#    'day',
#    'plan',
#    "'bible",
#    "days'.",
#    'check',
#    'here:',
#    'chronicles',
#    'completed'],
#   1),
#  (['seriously',
#    'unfair',
#    'asking',
#    'questions!',
#    'ready',
#    'answer',
#    'win',
#    "='(",
#    'busy',
#    'asking',
#    'questions!!'],
#   0),
#  (['followed', 'thanks,', 'please', 'followed'], 0),
#  (['lovely',
#    'intern',
#    'leaving',
#    'today',
#    'look',
#    'yummy',
#    'treats',
#    'brought',
#    'us!'],
#   0),
#  (['especially', 'like', "can't", 'song'], 0),
#  (['pleasure'], 1),
#  (['cried',
#    'derby',
#    'county',
#    'leeds',
#    'united',
#    'coffee',
#    'mugs',
#    'unable',
#    'share',
#    'hate',
#    'man'],
#   0),
#  (['okay', ':((((('], 0),
#  (['omg',
#    'know.............',
#    'haha',
#    'keedz',
#    'gonna',
#    'long',
#    'time',
#    'party',
#    ':((('],
#   0),
#  (['last', 'concert', 'went', 'stadium', "tomorrow's", 'show', 'justin'], 0),
#  (['sudden', ':(('], 0),
#  (['true.....', 'honesty', 'lonely', 'word!!!!'], 0),
#  (['prompts',
#    'claimed',
#    'far',
#    'kinda...',
#    'like',
#    "i've",
#    'aready',
#    'read',
#    'something',
#    'similar',
#    'soulmate',
#    'au,',
#    'canon...',
#    'zzz...'],
#   0),
#  (["can't", 'sleep', 'normal', 'time'], 0),
#  (['whose',
#    'playing',
#    'fifa',
#    'wow',
#    'sounds',
#    'like',
#    'good',
#    'lineup',
#    ':))'],
#   1),
#  (['fab', ':(((', 'hahahahaha', 'creds'], 0),
#  (['bby', 'gurl'], 1),
#  (['may', 'interested', 'blog'], 1),
#  (['team', 'site', 'ready', 'balkan', 'gypsy', 'folk', 'festival', 'mayhem'],
#   1),
#  (["that's",
#    'awful',
#    'son',
#    'missed',
#    'physics',
#    'exam',
#    'chicken',
#    'pox',
#    'gave',
#    'predicted',
#    'grade.',
#    'poor',
#    'girl.'],
#   0),
#  (['skin', 'thinks', 'still', '&amp;', 'decides', 'break', ':-)', 'cool'], 1),
#  ([], 1),
#  (['followed', 'thanks,', 'please', 'followed'], 0),
#  (['aitor',
#    'sns,',
#    'would',
#    'mind',
#    'checking',
#    'bio',
#    'participate',
#    'ps4',
#    'giveaway?',
#    'could',
#    'winner'],
#   1),
#  (['lyka', 'follow', 'back'], 1),
#  (['miss'], 0),
#  (['looking', 'fun?', 'snapchat', 'gooffeanottere'], 1),
#  (['love', 'author', 'pic', 'mwf', 'programme!', 'going', 'rock'], 1),
#  (['oooh', 'lovely!', 'hope', 'fantastic', 'time'], 1),
#  (['rain'], 0),
#  (['even', 'real', 'word'], 1),
#  (['need', 'come', 'back', 'england....:('], 0),
#  (['thanks', 'team', 'yellow'], 1),
#  (['tfw',
#    'boyfriend',
#    '(lol',
#    'jest)',
#    'cooking',
#    'relaxes',
#    'me.',
#    "i'm",
#    'sure',
#    "i'll",
#    'eat',
#    'lunch',
#    'tomorrow.'],
#   0),
#  (['saw',
#    'nicest',
#    'mehendi',
#    'design',
#    "someone's",
#    'picture',
#    'dash',
#    "can't",
#    'find',
#    'bookmark',
#    '&gt;:('],
#   0),
#  (['kid', 'inside!!!', 'want', 'one!!', ':-)'], 1),
#  (['hey', 'please', 'check', 'final', 'design'], 1),
#  (["panic's", 'new', 'album', 'come', '22nd'], 0),
#  (['unsettled',
#    'weather',
#    'trend',
#    'next',
#    'days.',
#    'sun',
#    'morning.',
#    'showers',
#    'afternoon.',
#    '18c.',
#    'mixed',
#    'bag',
#    'weekend',
#    ':-(.'],
#   0),
#  ([':-('], 0),
#  (["he's", 'sleeping', "he's", 'cute', ':-('], 0),
#  (['manga', 'cute', 'yet', 'made', 'cry..'], 0),
#  (['lol',
#    'person',
#    'want',
#    'hug',
#    'cant',
#    'lmbo',
#    'dangit',
#    'miss',
#    'people',
#    'much',
#    'cant',
#    'help',
#    'though'],
#   0),
#  (['units', 'first', 'sem', 'second', 'year?', 'please', 'tell', 'kidding.'],
#   0),
#  (['clash', ':))', '"@prasetyoseven:', 'milano', 'calling'], 1),
#  (['morning', 'hayley', ':-)'], 1),
#  (['thanks', ':)))'], 1),
#  (['yosh'], 1),
#  (['definitely', 'good', 'news...', 'consultant...:)'], 1),
#  (['city', 'shit'], 0),
#  (['aditya,', 'mommy', 'miss', 'sooo', 'much'], 0),
#  (['perfect,', 'already', 'know', "what's", 'waiting'], 1),
#  (["i've", 'wanted', 'panda', 'like', 'days'], 0),
#  (['sorry'], 0),
#  (['earth', '2.0...', 'yuppiieee'], 1),
#  (['miss', 'baao'], 0),
#  ([':-(', 'need', 'investigate', 'more....'], 0),
#  (['*yawns*',
#    'good',
#    'morning',
#    'everyone',
#    '*wags',
#    'tail*',
#    'everyone',
#    'today'],
#   1),
#  (['really', 'want', 'see', ':-('], 0),
#  (['reachability', 'bug', 'still', 'much', 'there!:p'], 1),
#  (['fuuuuuuuuuck', 'jesus', '&gt;:('], 0),
#  (['haha', "that's", 'great'], 1),
#  (['wanted', 'bloody', 'sandwhich'], 0),
#  (['work', 'hours...'], 0),
#  (['halfway',
#    'around',
#    'world',
#    'got',
#    'nothing',
#    'better',
#    'do,',
#    'best',
#    'friend',
#    "who's",
#    'forgotten',
#    ':-)'],
#   1),
#  (['enjoy', 'share', 'experience.'], 1),
#  (['thank', 'pauline!'], 1),
#  (['jumma', 'mubbarak'], 1),
#  (['a9.', 'would', 'ice', 'cream', 'without', 'ice', ':(('], 0),
#  (['hahaha',
#    'serious?',
#    'himmat',
#    'karain',
#    'aur',
#    'moo',
#    'pay',
#    'baat',
#    'karain',
#    'believe',
#    'meri',
#    'debates',
#    'abu',
#    'cousins',
#    'sath',
#    'hotee-my',
#    'uncles!😂'],
#   1),
#  (['lucky',
#    'feeling',
#    'hungry,',
#    'wanna',
#    'get',
#    'bed',
#    'either,',
#    'gotta',
#    'wait',
#    'mañana'],
#   0),
#  (['awww', 'lovely', 'trend!!!', 'doubt'], 1),
#  (['hey', 'marty', 'glad', 'see', 'twitter.'], 1),
#  (['want',
#    'new',
#    'stuff',
#    'used',
#    'love',
#    "friday's",
#    'xur',
#    'months',
#    'excitement'],
#   0),
#  (['want', 'braces', 'back!'], 0),
#  (['getting', 'holiday', 'clothes', 'day', 'like', 'this.', 'wanna'], 0),
#  (['thanks',
#    'helen!',
#    'keep',
#    'touch',
#    'ever',
#    'want',
#    'filming',
#    'blood',
#    'service',
#    'know',
#    'am!'],
#   1),
#  (['sometimes', 'wanted', 'myself....'], 0),
#  (['goes'], 1),
#  (['lol',
#    'sorry',
#    '/-\\',
#    'ultor',
#    'first',
#    'hitter',
#    'so...i',
#    'favor',
#    'much',
#    ':))'],
#   1),
#  (['updated', 'soon', "i'm", 'sure.', 'sign', 'set', 'text', 'alerts', '|da'],
#   1),
#  (['weekend',
#    'gonna',
#    'shoot',
#    'lovely',
#    '&lt;3!',
#    'picture',
#    'made',
#    'last',
#    'time'],
#   1),
#  (["i'm", 'sorry'], 0),
#  (['nothing',
#    'except',
#    'lie,',
#    'fraud,',
#    'double',
#    'cross,',
#    'diplomacy,',
#    'survival',
#    'fittest,',
#    'zero',
#    'tolerant.....'],
#   0),
#  (['know', 'disappointed'], 0),
#  (['yeahh', '100%', '&amp;', 'good', 'day'], 1),
#  (['miss', 'church', 'helping', 'get', 'armor'], 0),
#  (['sun', 'shining', "i'm", 'gonna', 'make'], 1),
#  (['sameee~', 'rest', 'well'], 1),
#  (['thanks', 'omar'], 1),
#  (['"@yettygeers:', 'dont', 'give', 'know', 'better', 'days', 'coming', ':-)'],
#   1),
#  (['yay!', 'happy', 'publication', 'month!', 'ask', 'order'], 1),
#  (['feelin', 'sick', ':(('], 0),
#  (['omg', 'hahah', ':((', 'omg', 'debut', 'next', 'year', ':((('], 0),
#  (['georgie', 'bet', 'back', 'soon!!', 'last', 'month', 'fly'], 0),
#  (['goodnight', 'nikki', 'good', 'one'], 1),
#  (['???:p'], 1),
#  (['actually', 'hehe', 'live?', 'strange', 'imagine...'], 1),
#  (['ill', 'better', 'soon.', 'feeling', 'sick'], 1),
#  (["that's", 'damn', 'lie'], 0),
#  (['got', 'home.', 'got', 'ol.', 'ugh', 'outdated', ':((('], 0),
#  (['everyone', 'going', 'womad'], 0),
#  ([':-(', "i'm", 'sorry'], 0),
#  (['hey', 'working', ':-)'], 1),
#  (['love', 'makes', 'two', 'hearts', 'one.'], 1),
#  (['want', 'back'], 0),
#  (['frightening', 'case.', 'really', 'gets'], 0),
#  (['follback'], 1),
#  (['miss', 'everything', 'you":('], 0),
#  (['really', 'is;', 'week', 'big', 'decisions', 'feeling', 'rather', 'badass'],
#   1),
#  (['could',
#    'drive',
#    'pass',
#    'advert',
#    'everyday',
#    'going',
#    'work',
#    'rosebury'],
#   0),
#  (["i'm", 'kinda', 'sort', 'fucked', ':-)'], 1),
#  (['whenever',
#    'sister',
#    'sees',
#    'crying',
#    'texts',
#    'ask',
#    'okay',
#    'someone',
#    'cares',
#    ':-)'],
#   1),
#  (['great!',
#    'irish',
#    'literature',
#    'really',
#    'inaccessible',
#    'without',
#    'irish'],
#   1),
#  (['kidding', 'kaaaa'], 1),
#  (['another', 'rumor'], 0),
#  (["i'll", 'living', 'vegetarian', "i'm", 'sure', "she'll", 'help'], 1),
#  (['miss'], 0),
#  (['want', 't-shirts', 'cool'], 1),
#  (['etienne', 'making', 'sad'], 0),
#  (['friends',
#    "'hi",
#    'saw',
#    'dead',
#    'thing',
#    'made',
#    'think',
#    "you'",
#    'aww',
#    'thanks',
#    'guys!'],
#   1),
#  (['want', 'look', 'good'], 1),
#  (['pleasure!', 'let', 'know', "there's", 'anything', 'else', 'need'], 1),
#  (['looks', 'pretty', 'nice.', 'love', 'flat', 'looks.'], 1),
#  (['ghanton', 'light', 'nahi', ':))))))'], 1),
#  (['know', "i'm", 'sorry,', 'let', 'make'], 0),
#  (['miss'], 0),
#  (['430', 'smh'], 1),
#  (['vidcon', ':((('], 0),
#  (['sleeps!',
#    'officially',
#    'way',
#    'paris!',
#    'cannot',
#    'wait',
#    '🇫🇷🍷🍸☀️🇫🇷🚲🇫🇷🍷🍸☀️🚲'],
#   1),
#  (['بندر',
#    'العنزي,',
#    'heiyo,',
#    'visit',
#    'website',
#    'free',
#    '50.000',
#    'coins',
#    'ball',
#    'pool',
#    'now!',
#    'thanks'],
#   1),
#  (['pret',
#    ':((',
#    'wkwkw"@wlk_jhope:',
#    'verfied',
#    'active,',
#    'forget',
#    'follow',
#    'member.',
#    'thanks',
#    'join.',
#    'goodbye"'],
#   0),
#  (['double', 'whammy'], 0),
#  (['sounds', 'great,', 'better', 'lunch'], 0),
#  (['around', 'tom.'], 0),
#  (['don’t', 'care', 'force', 'exercise', 'even', 'body', 'screaming', 'pain'],
#   1),
#  (['oops', 'got', 'days', 'muddled', 'up.', "i'll", 'tomorrow'], 1),
#  (['excited', 'weekend', ':-)'], 1),
#  (['sorry!!!'], 0),
#  (["that's", 'true,', 'disappoint!', 'looking', 'forward', 'paper', 'towns?'],
#   1),
#  (["that's", 'true.', 'quit', 'whenever', 'want', 'to.'], 1),
#  (['nice', 'day', 'work', 'today', 'tmrw'], 1),
#  (['wondered',
#    'happened',
#    'earlier?',
#    'realized,',
#    'leadership',
#    'it!',
#    ':-('],
#   0),
#  (['yeah', 'guessed', 'much.', 'hope', 'decide', 'play', 'nicely', 'you.'], 0),
#  (['basically', 'piss', 'cup', 'test', ':)))'], 1),
#  (['«--"@yokokuali:', ':)"@kreizi_:', 'wants', 's/o??""'], 1),
#  (['ask', 'made', 'year'], 1),
#  (['thank', 'much', 'babe'], 1),
#  (['followed', 'thanks,', 'please', 'followed'], 0),
#  (['need', 'big', 'cuddle', 'lew', 'kisses', 'face', ':((((', 'want'], 0),
#  (['sorna', ':(((('], 0),
#  (['feel',
#    'drained',
#    'like',
#    'omg',
#    'like',
#    'tired',
#    'physically',
#    'mentally',
#    'haizzz',
#    'eyes',
#    'still',
#    'hurt',
#    'urghhh',
#    'sat',
#    'sun',
#    'cant',
#    'even',
#    'stay',
#    'home'],
#   0),
#  (["morning........it's", 'friday!', 'happy', 'friday', 'beautiful', 'people'],
#   1),
#  (["that's",
#    'great',
#    'hear,',
#    "we'll",
#    'sure',
#    'pass',
#    'thanks',
#    'staff',
#    '-nic'],
#   1),
#  (['diz',
#    'personal',
#    'account.',
#    'also',
#    'fan',
#    'acc.',
#    'link',
#    'bioooo',
#    ':-(',
#    'taray.',
#    'yumu-youtuber.'],
#   0),
#  (['easier', 'said', 'done'], 0),
#  (['place', 'peaceful', 'relaxing..:)'], 1),
#  (['stats', 'day', 'arrived.', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['thank', 'much😊😊'], 1),
#  (['would',
#    'entertain',
#    'tbh',
#    '"@imkhwezin:',
#    '"hey,',
#    'remember',
#    'me?"',
#    'typa',
#    'weather',
#    ':("'],
#   0),
#  (['kik', 'himseek8'], 0),
#  (['hi,',
#    'unfortunately,',
#    "we're",
#    'unable',
#    'locate',
#    'original',
#    'complaint.',
#    'pls',
#    'product',
#    'details',
#    '&amp;',
#    "we'll",
#    'get',
#    'back',
#    'you.'],
#   0),
#  (['know', 'right', 'hard', 'believe'], 0),
#  (['well',
#    'get',
#    'recruited',
#    'team',
#    'doom.',
#    'nasty',
#    'crew',
#    'going',
#    'affiliated.',
#    '&gt;:)'],
#   1),
#  (['landlords', 'like', "mp's", 'though', "that's", 'going', 'easy?', ':-('],
#   0),
#  (['nightmares'], 0),
#  (['movie', 'essentially', 'cut', 'beginning', 'book', 'plot.'], 0),
#  (['better',
#    'gay',
#    'lesbian',
#    'rigid',
#    'theocratic,',
#    'right',
#    'wing',
#    'fundamentalist',
#    'islamist.'],
#   1),
#  (['hi!',
#    'would',
#    'like',
#    'concert?',
#    'let',
#    'know',
#    'city',
#    'country',
#    "i'll",
#    'start',
#    'working',
#    'it!',
#    'thanks'],
#   1),
#  (['boat', 'trip', 'beautiful', 'wife', ':-)'], 1),
#  (['jealous', 'always', 'planned', 'together!!!'], 0),
#  (['need', 'sleep...'], 0),
#  (['class', 'today', 'traine', 'friends'], 1),
#  (['miss'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x32'],
#   1),
#  (['top', 'engaged', 'members', 'community', 'week'], 1),
#  (['sleep.', "i'm"], 0),
#  (['oops'], 0),
#  (['sometimes', 'choosing', 'ego', 'relationship.'], 1),
#  (['ocean',
#    'without',
#    'water,',
#    'vehicles',
#    'without',
#    'petrol',
#    'diesel',
#    'empty',
#    'wardrobe'],
#   0),
#  (['case', 'bae', 'acts', 'brand', 'new', ':)💘'], 1),
#  (['gegu', 'want', 'space', 'gray', 'iphone', ':(('], 0),
#  (['thank',
#    'survive',
#    'p90x',
#    'either,',
#    "i'm",
#    'p90,',
#    "that's",
#    'easy',
#    'version'],
#   1),
#  (['yes!', 'joined', 'call', '&amp;', 'gift', '&lt;3', 'gotta', 'get'], 1),
#  (['sorry', "i'm", 'fully', 'booked', ':-('], 0),
#  (['also,', 'twitter', 'terrible', 'complicated', 'discussions'], 1),
#  (['3wks', 'flowers', '1st', 'wedding!', 'shame', 'feverfew'], 0),
#  (['cheapest',
#    'printing',
#    'world?',
#    'looking',
#    'regular',
#    'printer',
#    'countries',
#    'close',
#    'ireland,',
#    'drop',
#    'ship',
#    'printers'],
#   1),
#  (['raining', 'today', 'gym', '💪🏻🐒'], 0),
#  (['like'], 0),
#  (['fun', 'danielle!', 'hope', 'goes', 'well', ':-)'], 1),
#  (["we're", 'gonna', 'running', 'cali', 'w/o', 'woe'], 0),
#  (['care'], 0),
#  (['home', 'time', 'today'], 0),
#  (['sending', 'alex', 'like', 'million', 'pictures'], 1),
#  ([':((', 'okay!!x'], 0),
#  (['shit',
#    'rlly?:(',
#    'heard',
#    'hamsters',
#    'eat',
#    'thats',
#    'pretty',
#    'fucked',
#    'hamsters',
#    'weird'],
#   0),
#  (['think', 'could', 'get', 'sponsor'], 1),
#  (['hardly', 'respond', ':-('], 0),
#  (['yeah',
#    "they're",
#    'giving',
#    'subtle',
#    'hints.',
#    'also',
#    'tip',
#    'use',
#    'community',
#    'last',
#    'years.',
#    ':-)',
#    'prim’s',
#    'algorithm',
#    'iii'],
#   1),
#  (['istg', 'wanna', 'lick', 'jackson', ':((((((', 'nsbzhdnxndamal'], 0),
#  (['market', 'main', 'launched', 'pretoria.'], 1),
#  (['things', 'know...', "women's", 'fiction'], 1),
#  (['real', 'measure', 'mans', 'wealth', 'invested', 'eternity.', ':-)'], 1),
#  (['poor',
#    'sbenu',
#    ':&lt;',
#    'sasin',
#    'happy',
#    'all...',
#    'best',
#    'player',
#    'team..',
#    'anarchy~~~',
#    '&lt;3'],
#   0),
#  (['smile'], 1),
#  (['thanks',
#    'connecting.',
#    'specialise',
#    'thermal',
#    'imaging',
#    'surveys',
#    'need'],
#   1),
#  (['getting', 'close', 'now.', "can't", 'wait', 'new', 'season'], 1),
#  (['kwento', 'fbc'], 0),
#  (['sorry', ':(('], 0),
#  (['fback?'], 1),
#  (['finally', 'hate', 'switzerland', 'kfc'], 0),
#  (['one', 'perhaps', 'something', 'else?', '87.7'], 0),
#  (['gooodnight', 'love', 'boys', 'ris', 'zoe', 'katy', 'jaycy', 'jen'], 1),
#  (['want', 'get', 'dota', 'fuck'], 0),
#  (['car', 'batteries', 'expensive', ':(.', 'hope', 'get', 'new', 'life'], 0),
#  (['woooo!', 'happy', 'friday', 'friends'], 1),
#  (['miss', 'already'], 0),
#  (['everyone',
#    'adored',
#    'you.',
#    'talking',
#    'long',
#    'left.',
#    'new',
#    'fans.',
#    'knew',
#    'would',
#    'case.',
#    ':-)'],
#   1),
#  (['suite', 'life', 'zack', 'cody', ':-)'], 1),
#  (["i'm", 'glad', 'like', 'services.', 'happy', 'shopping', '^dv'], 1),
#  (['contributions', 'reqd', ':-)'], 1),
#  (['wish', 'could'], 0),
#  (['hey', 'check', 'pictures', 'think?:)', 'notice', 'follow', 'please?💕'], 1),
#  (['dear!!', ':-('], 0),
#  (['wearing', 'mine', 'next', 'fri', ':-)'], 1),
#  (['world',
#    'alternis',
#    'kills',
#    'really',
#    'sad',
#    'leave',
#    'place',
#    'everyone',
#    'die'],
#   0),
#  (['tato', 'bulat'], 1),
#  (['love', 'it!'], 1),
#  (['please',
#    'use',
#    'york',
#    'residents',
#    'card',
#    'available',
#    'nearest',
#    'central',
#    'library',
#    'lendal'],
#   1),
#  (['wishing', 'colorado'], 1),
#  (['nice', 'quote'], 1),
#  (['welcome'], 1),
#  (['foreals', 'wesen', 'uwesiti'], 0),
#  (['happy',
#    'birthday,',
#    'miss',
#    'chenoweth!',
#    'hope',
#    'great',
#    'one...',
#    'oodles',
#    'cake'],
#   1),
#  (['looks',
#    'like',
#    'great',
#    'way',
#    'spend',
#    'friday',
#    'afternoon!',
#    'enjoy',
#    'marathon',
#    'iflix!'],
#   1),
#  (['lyka', 'followback'], 1),
#  (['want', 'kitten', 'badly', 'god', ':(('], 0),
#  (['haix',
#    'wish',
#    'student',
#    ':(((',
#    'everyday',
#    'breakfast',
#    'late',
#    'class',
#    'already',
#    'haix'],
#   0),
#  (['hungry!:-)'], 1),
#  (['state', 'hair'], 0),
#  (['give', 'all.'], 1),
#  (["can't", 'sleep', ':((('], 0),
#  (['know', ':),', 'hot', 'always'], 1),
#  (['waking', 'sound', 'rain', 'hitting', 'tent', 'yay'], 1),
#  (['happy',
#    'friday',
#    'everyone!',
#    "i'm",
#    '5pm',
#    'answer',
#    'queries.',
#    'great',
#    'day',
#    'abby.'],
#   1),
#  (['miss', 'oscar'], 0),
#  (['abby', 'please', 'try', 'help', 'get', 'mum', 'come', 'see', 'london!:('],
#   0),
#  (["that's", 'fair,', 'happened'], 0),
#  (['omg', 'love', 'zap', ':(((((('], 0),
#  (["i'm", 'honoured'], 1),
#  (['ella', 'cheer', 'pls'], 0),
#  (["i'm", 'sorry.'], 0),
#  (['yes,',
#    'shirts.',
#    "they're",
#    'nice',
#    'rofl',
#    'old',
#    'mints',
#    "i'm",
#    'rocking',
#    'sexy',
#    'superdry',
#    'tee',
#    'right'],
#   1),
#  (['hope', 'win'], 1),
#  (['got',
#    'google',
#    'image,',
#    'know',
#    'already',
#    'closed',
#    'browser',
#    'sorry',
#    ':(('],
#   0),
#  (['next', 'week,', 'office', 'lets'], 1),
#  (['relate',
#    '"sweet',
#    'sour"',
#    'kind',
#    '"bi-polar"',
#    'people',
#    'life...',
#    'cuz',
#    'life...',
#    'full',
#    'them...'],
#   0),
#  (['sucks',
#    'much',
#    'sick',
#    'plan',
#    'start',
#    'work',
#    'first',
#    'gundam',
#    'night',
#    'nope.'],
#   0),
#  (['rly',
#    'wanna',
#    'buy',
#    'limited',
#    'ver',
#    'well',
#    'normal',
#    'edition.',
#    'huhuhu',
#    'choose?'],
#   0),
#  (['know', 'feel', 'man'], 0),
#  (['awwww',
#    'thank',
#    'daw',
#    'tine.',
#    'btw',
#    'heard',
#    'gensan',
#    'ka????',
#    'miss',
#    'know'],
#   1),
#  (['get',
#    'offer',
#    'play',
#    'film',
#    'turn',
#    'cause',
#    'summer',
#    'body',
#    'ready',
#    'yet'],
#   1),
#  (['open', 'worldwide'], 1),
#  (['nak', 'tgk', 'paper', 'townssssss', 'sigh'], 0),
#  (['fucked'], 0),
#  (['july',
#    '24,',
#    '2015',
#    '01:16am',
#    'means',
#    'time',
#    'give',
#    'love',
#    'mist45gameplay.'],
#   1),
#  (['wish', 'bloopers', ':(((('], 0),
#  (['no,', 'get', 'one', 'think', 'previous', 'one'], 0),
#  (['determined', 'feel', 'ill', 'tonight!!!'], 0),
#  (['tried', 'tweeting', "unicef's", 'accounts', 'answer'], 0),
# ...
#    '"dark"',
#    '.plz',
#    'let',
#    'know',
#    'think'],
#   1),
#  (['good', 'trip.', 'need', 'brolly', 'there...', ':-('], 0),
#  (['chover'], 0),
#  (['free',
#    'slice',
#    'toast',
#    'every',
#    'large',
#    'coffee-weekdays',
#    '9-11.30',
#    'ask',
#    'offer'],
#   1),
#  (['movie',
#    "'key",
#    "life'",
#    '(japanese',
#    'version)',
#    'interesting',
#    'storyline!'],
#   1),
#  (['never', 'call'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x17'],
#   1),
#  (['would', 'email', '(donnae.strydom@westerncape.gov.za)', ':-)', '---'], 1),
#  (['like'], 0),
#  (['super'], 1),
#  (['jaysus!'], 0),
#  (['ores!'], 0),
#  (['hello',
#    'america',
#    'california',
#    'usa!',
#    'dear',
#    'friend',
#    'thank',
#    'following'],
#   1),
#  (['.@1234mania', 'whatever', 'article', 'polish', 'cider', 'anyway'], 1),
#  (['thank'], 1),
#  (['tweet'], 1),
#  (['thq', 'lot', 'continous', 'support', 'thalaivar', 'bro:):):)'], 1),
#  (['spotify', 'finally', 'figured', "i'm", 'let', 'listen', 'anymore'], 0),
#  (['fell',
#    'asleep',
#    'arond',
#    '1:30',
#    'really',
#    'late',
#    'considering',
#    'working',
#    'exhausted'],
#   1),
#  (['gonna', 'watch', 'lcs', 'hours', 'help', 'need', 'sleep'], 0),
#  (['days', 'chal', 'raha', 'hai'], 0),
#  (['think'], 0),
#  (["i'm", 'terrible', 'daughter', ':-('], 0),
#  (['something', 'wrong'], 0),
#  (['aff', 'uname', 'jonginuh,', 'feel', 'free', 'add'], 1),
#  (['last', 'classes', 'morning', 'two', 'week', 'break!', ':-)'], 1),
#  (['.@sabal_abla',
#    'joking',
#    'headline.',
#    'friends?',
#    'pls',
#    "dn't",
#    'brk',
#    'heart.',
#    ":'("],
#   0),
#  (['lest', 'get', '^_^'], 0),
#  (['use', 'app', 'listen', 'music?', 'yes,', 'app?', ':-)', 'idownloader'], 1),
#  (['grans', 'funeral', 'today', 'going', 'hard'], 0),
#  (['wow,',
#    'thanks',
#    'donna!',
#    'determined',
#    'get',
#    'women',
#    'cycling',
#    'amazing',
#    '&amp;',
#    'changed',
#    'life'],
#   1),
#  (["can't",
#    'sleep',
#    'much',
#    'want',
#    'love',
#    'bugs',
#    'made',
#    'tokens',
#    'never',
#    'mind'],
#   1),
#  (['looking',
#    'gen.ad.',
#    'better',
#    'price',
#    'negotiable',
#    ':((((',
#    'someone',
#    'help',
#    ':(((((',
#    'huhuhuhuhu'],
#   0),
#  (['no!', 'used', 'love', 'derek.', 'hope', "he's", 'okay.'], 0),
#  (['hate', 'offline'], 0),
#  (['send', 'free,'], 1),
#  (['sr.', 'financial', 'analyst', 'expedia,', 'inc.:', '(#bellevue,', 'wa)'],
#   0),
#  (['that’s', 'exactly', 'look', 'i’m', 'going'], 1),
#  (['miss', ':-('], 0),
#  (["there's", 'love', 'anymore'], 0),
#  (['need',
#    'clean',
#    'window',
#    'point',
#    'today',
#    'hugh',
#    'keeps',
#    'pawing',
#    'leaving',
#    'muddy',
#    'marks',
#    'everywhere'],
#   0),
#  (['＠real_liam_payne',
#    'please',
#    'follow',
#    'waiting',
#    'follow',
#    'back',
#    'please',
#    'follow',
#    'back',
#    'retweet',
#    'reply'],
#   0),
#  (['goodnight',
#    'guys',
#    ':-)',
#    'remember',
#    'tomorrow',
#    'brand',
#    'new',
#    'day,',
#    'fresh',
#    'start',
#    'another',
#    'chance'],
#   1),
#  (['lol', 'thank', 'you.', 'definitely', 'source', 'appeasement...'], 1),
#  (['guy',
#    'buys',
#    'water,',
#    "can't",
#    'drink',
#    'watch',
#    'cup',
#    'like',
#    'hawk',
#    'transferred',
#    'bartender'],
#   0),
#  (['fulfil', 'fantasies'], 1),
#  (['man',
#    'right',
#    'now,',
#    'wish',
#    'someone',
#    'would',
#    'bring',
#    'food',
#    'office.',
#    "i'm",
#    'starving.'],
#   0),
#  (['rettweet', ':-)'], 1),
#  (['nice',
#    'one',
#    'baz.',
#    'lucky',
#    'working',
#    'wonderful',
#    'company',
#    'people.',
#    ':-)'],
#   1),
#  (['altered',
#    'sandra',
#    'bland',
#    'storify',
#    'btw',
#    'now!',
#    'quite',
#    'angry',
#    'wrote',
#    'originally',
#    'best',
#    ':-('],
#   0),
#  (['woohoo!',
#    "can't",
#    'wait',
#    'signed',
#    'yet,',
#    'still',
#    'thinking',
#    'it?',
#    'mka'],
#   1),
#  (['pak', 'saturday', 'classes,', 'pak', 'monthly', 'test'], 0),
#  (['weather,', 'mad?', '&amp;', 'work'], 0),
#  (['konami', 'policy', 'pes', 'version', 'happen', 'version', ':((('], 0),
#  (['takfaham.'], 0),
#  (['powys,', 'close', 'shropshire', 'border'], 1),
#  (['evet'], 1),
#  (['payback', 'liking', 'videos', 'trying', 'help', 'get', 'kit', 'kats?'], 0),
#  (['welcome', 'bomb', 'family'], 1),
#  (['unfollow'], 0),
#  (['alone', ':-('], 0),
#  (['pro', 'soccer', 'play', 'would', 'cool'], 0),
#  (['bus',
#    'girl',
#    'uses',
#    'long',
#    'cardi',
#    'almost',
#    'everyday,',
#    'everytime',
#    'see',
#    'laughing/smiling',
#    'cute',
#    'smile!'],
#   1),
#  (['please',
#    'help',
#    'find',
#    'replacement',
#    'strap',
#    'dz9055',
#    'love',
#    'watch!'],
#   0),
#  (['nice', 'word'], 1),
#  (['followed', 'yet', ':(('], 0),
#  (['forever', 'missed', '&amp;', 'loved', 'lolo.'], 0),
#  (['gyu', 'cute', ':-(', 'hurts'], 0),
#  (['yeah', 'screwed', ':-(', 'time', 'thought', 'something', 'good', 'good'],
#   0),
#  (['would',
#    'love',
#    'see',
#    'w/nick',
#    'picks',
#    'one',
#    'waisted',
#    'time.',
#    '&amp;',
#    'never',
#    'work',
#    'anyway.'],
#   0),
#  (['follow', '&amp;', 'follow', 'back'], 1),
#  (['good', 'going', 'andre!', 'keep'], 1),
#  (['see',
#    'going',
#    'at.',
#    'yes.',
#    'subjective',
#    'pain',
#    'may',
#    'real,',
#    'make',
#    'less',
#    'painful.'],
#   1),
#  (['wrong', 'password/recall', 'thingy', 'working', 'prob', ':-('], 0),
#  (['helpinggroupdms:', 'quote', 'tweet', 'really', 'want', "i'll", 'surprise'],
#   1),
#  (['fun', 'fact:', 'love', 'meeting', 'new', 'people'], 1),
#  (['got',
#    'secrets',
#    'grindea,',
#    'courier',
#    'crypts',
#    'possibly',
#    'arma',
#    'record',
#    'today.....',
#    'gosh!',
#    'new',
#    'game',
#    'looks',
#    'like',
#    'limbo'],
#   1),
#  (['bird', 'flew', 'window', 'dead', ':-('], 0),
#  (['trending..', 'follow', 'bobble', 'link.'], 1),
#  (['fback?'], 1),
#  (['omg', "i'd", 'facetime', 'juliana', 'phone', ':-('], 0),
#  (['literally', 'torn', 'room', 'apart', 'looking', 'retainers'], 0),
#  (['yes', 'one', 'team'], 1),
#  (['sometimes',
#    "be's",
#    'like',
#    'that,',
#    'yo.',
#    'follow',
#    'someone',
#    'days',
#    'later',
#    'realise',
#    "they're",
#    'problematic',
#    'fuck.',
#    'life'],
#   0),
#  (['back'], 1),
#  (['use', 'chrome'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    '&lt;3',
#    'love',
#    '&lt;3',
#    'x11'],
#   1),
#  (['tired',
#    '&amp;',
#    'grumpy',
#    'today.',
#    'hate',
#    'missing',
#    'exercise,',
#    'makes',
#    'feel',
#    'much',
#    'better.',
#    'combat',
#    'holidays'],
#   0),
#  (['great', 'hear', 'nice', 'day,', 'thanks', 'visiting'], 1),
#  (['forced', ':-('], 0),
#  (['grandad', 'really', 'well', 'worry', 'much', 'him!'], 0),
#  (['faith'], 0),
#  (['sounds', 'still', 'like', 'good', 'idea'], 1),
#  (['happy', 'birthday'], 1),
#  (['forgot',
#    'wake',
#    '6:30',
#    'babysit',
#    'stayed',
#    'late',
#    'jacob',
#    'last',
#    'night',
#    'tired'],
#   0),
#  (["let's", 'play'], 1),
#  (['thank',
#    'lovely,',
#    'going',
#    'write',
#    'list',
#    'ones',
#    "i've",
#    'recommended',
#    'see',
#    'one',
#    'choose,',
#    'budget',
#    'big'],
#   0),
#  (['aha', 'yesss!', 'looking', 'forward', 'seeing?:)'], 1),
#  (['want', 'foood', ':(('], 0),
#  ([], 1),
#  (['twitter',
#    'turning',
#    'much',
#    'complicated.',
#    "can't",
#    'find',
#    'trends',
#    'now.'],
#   0),
#  (['awwhh', 'good', 'friday', 'everyone'], 1),
#  (['thanks',
#    'bringing',
#    'attention.',
#    'let',
#    'know',
#    'questions',
#    '1tb',
#    'would',
#    'amazing!'],
#   1),
#  (['shoe',
#    'box',
#    'size',
#    'shop,',
#    'gems',
#    'makes',
#    'geekiest',
#    'geeks',
#    'cry',
#    'wallets.'],
#   1),
#  (['fback?'], 1),
#  (['welcome...', ':-)', ':-)'], 1),
#  (['"ngga',
#    'usah',
#    'dipikirin',
#    'elah"',
#    "can't",
#    'easily',
#    'say',
#    'someone',
#    "who's",
#    'entp',
#    'reason'],
#   1),
#  (['awkward',
#    'moment',
#    'feel',
#    'got',
#    'abs',
#    "can't",
#    'stop',
#    'laughing',
#    'reading',
#    'tweets'],
#   1),
#  (["let's"], 1),
#  (['really', 'want', 'visit', 'iceland'], 0),
#  (['$$$$2', 'dollar', '😭😭😭😭😭😭'], 0),
#  (['ice', 'cream', ':-('], 0),
#  (['the_madstork', 'follback'], 1),
#  (['left'], 0),
#  (['first',
#    'love',
#    'you,',
#    'wanna',
#    'fuck,',
#    'late',
#    'night',
#    'thinking',
#    'got',
#    'nut',
#    ':-)',
#    '"look...'],
#   1),
#  (['mommy', 'left'], 0),
#  (["i'm", 'excited', "what's", 'coming', 'really', 'deserves', 'it.'], 1),
#  (['delphy'], 0),
#  (['maggie-',
#    'afraid',
#    'knowledge',
#    'mull',
#    'limited',
#    '(nil!:)).',
#    'look',
#    'web',
#    'page-',
#    'definitely',
#    'best',
#    'place',
#    'look'],
#   1),
#  (['poorly', 'pup'], 0),
#  (['biggest',
#    'fear',
#    'getting',
#    'drugs',
#    'laced',
#    'something',
#    'flipping',
#    'fuck'],
#   0),
#  (["i'm", 'really'], 0),
#  (['boohoo',
#    'back',
#    'work',
#    'tonight,',
#    'another',
#    'weekend',
#    'nights',
#    ':-(:-(:-('],
#   0),
#  (['...',
#    'he´s',
#    'attacked,',
#    'criticised',
#    'every',
#    'gesture,',
#    'word,',
#    'pedal',
#    'stroke.',
#    'one',
#    'must',
#    'attentive',
#    'notice',
#    'little',
#    'things'],
#   1),
#  (['marco,',
#    'fruits',
#    'herbs',
#    'parks',
#    'view,',
#    'hope',
#    'appreciate',
#    'eyes.',
#    'thanks!'],
#   1),
#  (['annoying', 'selfies', 'friday.'], 1),
#  (['dont',
#    'really',
#    'know',
#    'sorry.:(',
#    'try',
#    'opening',
#    'paint',
#    'save',
#    'as.'],
#   0),
#  (['back!', 'thnx', 'god!!!', "i'm", 'happy'], 1),
#  (['cant',
#    'believe',
#    '&amp;',
#    'finally',
#    'egypt',
#    'still',
#    'wont',
#    'able',
#    'meet'],
#   0),
#  (['laura.', ':-)', 'ask'], 1),
#  (['top', 'supports', 'community', 'week'], 1),
#  (['baby'], 0),
#  (['gfriend', 'looked', 'cute', ':((('], 0),
#  (['thanks', 'alex.', ':-)'], 1),
#  (['stats', 'week', 'arrived.', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['thanks', 'million', 'keeping', 'eye', 'tweets,', 'always', 'appreciated'],
#   1),
#  (['thank', 'much', 'mention!', 'awesome!!'], 1),
#  (['wanna', 'house', 'give', 'big', 'big', 'hug.', ':((('], 0),
#  (['works'], 1),
#  (['read', 'reviews', 'sounds', 'awesome.', 'thanks', 'suggestion'], 1),
#  (['havent', 'tweeting', 'years,', 'kinda', 'miss'], 1),
#  (['know',
#    'happens',
#    'internet',
#    'light',
#    'connection',
#    'drops?',
#    'thanks,',
#    'kei.'],
#   0),
#  (['found',
#    'song',
#    'mentioned;',
#    'nylons',
#    'gvb',
#    "'it",
#    'takes',
#    'mountain.titled',
#    "'do",
#    'unto',
#    'others'],
#   1),
#  (['check', 'out!:)', 'untangling', 'never', 'easier!'], 1),
#  ([], 0),
#  (['thanks', 'following', 'me..', ':-)', 'via'], 1),
#  (['worries'], 1),
#  (['sure',
#    'do,',
#    'esp',
#    'ppl',
#    'talking',
#    'crap',
#    'millie!!',
#    '&gt;:(',
#    "i'll",
#    'straight',
#    'page:)'],
#   0),
#  (['new',
#    'video',
#    'week',
#    'updated',
#    'face',
#    '&amp;',
#    'brows',
#    'routine',
#    '(oily',
#    'skin)',
#    'maricarljanah',
#    'via'],
#   1),
#  (['last',
#    'day',
#    'working',
#    'munchkin',
#    'today...:(...bought',
#    'little',
#    'parting',
#    'gift...so',
#    'far…'],
#   0),
#  (['times', 'control', 'havent', 'able', ':(:(', 'miss', ':(:('], 0),
#  ([':-d', 'love', 'lots', ':-)'], 1),
#  (["i'm", 'sure', 'tapir', 'calf', 'one', 'likes', 'adventurous', 'mealtimes'],
#   1),
#  (["that's",
#    'village',
#    'thing',
#    'everywhere',
#    'world.',
#    'different',
#    'big',
#    'cities,',
#    'unfortunately'],
#   0),
#  (['long',
#    'day/week,',
#    '(#legsupthewall)',
#    'perfect',
#    'pose',
#    'unwind...',
#    'enjoy!!!',
#    ':-)'],
#   1),
#  (['good', 'morning', 'girl.', 'amazing', 'beach'], 1),
#  (['mumbai',
#    '&amp;',
#    'gujarat',
#    'rain',
#    'distrubed',
#    'collection',
#    'otherwise',
#    'week',
#    '190cr+',
#    'inspite',
#    'highest',
#    'record',
#    'holder',
#    'till'],
#   1),
#  (['follow', '&amp;', 'follow', 'back'], 1),
#  (['message', 'right', 'nicola', 'forward', 'brighten', 'day', 'helen'], 1),
#  (['thank', ':-)))', 'fun!!', 'enjoy', 'day'], 1),
#  (['b-but,',
#    'favorite',
#    'thing',
#    'gintama',
#    'shinsengumi',
#    'special',
#    'chapters'],
#   0),
#  (['fback?'], 1),
#  (['hope',
#    'regular',
#    'problem',
#    'please',
#    'let',
#    'know',
#    'travel',
#    'to/from',
#    'time',
#    'due?'],
#   0),
#  (['wtf', 'stereo', 'kicks'], 0),
#  (['noo', "i've", 'ben', 'watching', 'like', 'hawke', 'week!', 'gutted'], 0),
#  (['maaaaaay', 'pre-ordered'], 1),
#  (['sorry', 'god.'], 0),
#  (['ate', 'whole', 'pizza', 'idk', 'feel'], 0),
#  (['sure', 'will!', ':))'], 1),
#  (['finally', 'fucking', 'weekend'], 1),
#  (['cricket',
#    'world',
#    'cup,',
#    'asian',
#    'cup',
#    'state',
#    'origin...',
#    'this?!',
#    'wow',
#    'matt',
#    'lucky',
#    'boy',
#    ':-)',
#    'fun!'],
#   1),
#  (['awh', ':-(', 'stay'], 0),
#  (['hot'], 0),
#  (['best',
#    'atp',
#    'players',
#    '(wimbledon',
#    '2015):',
#    'federer,',
#    'nadal,',
#    'monfils.',
#    'handsome',
#    'atp',
#    'players:',
#    'cilic,',
#    'cilic,',
#    'cilic.'],
#   1),
#  (['like', 'ballads', 'idk', ':(('], 0),
#  (['welcome', 'fun'], 1),
#  (['yay!', 'thankyou', 'bonding', 'ulit', 'soon!!', ":')"], 1),
#  (['glad',
#    'hear',
#    'it,',
#    'dan!',
#    "we're",
#    'mega',
#    'excited',
#    'retail',
#    'launch',
#    'forget',
#    'look',
#    'boots',
#    'whsmith,',
#    'too!'],
#   1),
#  (['thank', 'following'], 1),
#  (['sleep',
#    'stay',
#    'entire',
#    'thing',
#    'tmw!uwu...well',
#    'younger',
#    'jinki',
#    'older',
#    'taems',
#    'one',
#    ':(((',
#    'gifs'],
#   0),
#  (['sneak',
#    'peek',
#    'items',
#    'august',
#    'collection.',
#    'stay',
#    'tuned',
#    'inbox',
#    'orders',
#    'prices'],
#   1),
#  (['kids', 'makes', '://:(\\\\\\'], 0),
#  (['...and', 'play', 'al***n,', "he'll", 'score', 'fucking', 'night'], 1),
#  (['guy.',
#    'know',
#    'thing.',
#    '"@ceafive:',
#    'weather',
#    'set',
#    'sleep',
#    'responsibilities.',
#    ':-("'],
#   0),
#  (['good',
#    'morning!',
#    'sn16',
#    '9dg',
#    'stop',
#    'following',
#    'follow',
#    'signs',
#    'instead',
#    'soon',
#    'see'],
#   1),
#  (["town's", 'sister', 'town'], 1),
#  (['bigbang',
#    'need',
#    'rest',
#    'travelling',
#    'one',
#    'place',
#    'another,',
#    'must',
#    'really',
#    'tiring'],
#   0),
#  (['thanks', 'follow', 'great', 'day'], 1),
#  (['follow', '&amp;', 'follow', 'back'], 1),
#  (['please',
#    'beliebers',
#    'stop',
#    'voting',
#    'twitter!',
#    'count',
#    'vote',
#    'refresh'],
#   0),
#  (['buff', 'legs', 'yet'], 0),
#  (['select', 'others..', 'get'], 1),
#  (['thankyou', 'pretty!'], 1),
#  (['oh,', "doedn't", 'sound', 'good', 'all.', ':-('], 0),
#  (['guys', 'great', 'last', 'night'], 1),
#  (['happy',
#    'birthday',
#    'chocolate',
#    'lovers',
#    'cake.....tenerina!!!!',
#    'auguri',
#    'italy',
#    'best',
#    'wishes'],
#   1),
#  (['thanks',
#    'again,',
#    'time',
#    '16.20',
#    'right?',
#    "that's",
#    'perfect',
#    'timing',
#    ':).'],
#   1),
#  (['really',
#    'good',
#    'm&amp;g',
#    'idea',
#    "i'm",
#    'never',
#    'going',
#    'meet',
#    ':((('],
#   0),
#  (['feel',
#    'look',
#    'better',
#    'people',
#    "can't",
#    'see',
#    'tbh',
#    'look',
#    'tacky',
#    ':(('],
#   0),
#  (['macauley,',
#    'mexico',
#    'sounds',
#    'lovely',
#    ':-)',
#    'plans',
#    'add',
#    'new',
#    'countries',
#    'moment,',
#    'however',
#    "we're..."],
#   1),
#  (['still', 'suck', 'editing', 'turns', 'something', 'special', 'owe', 'guys'],
#   1),
#  (['chicks'], 1),
#  (['weren’t', 'kale', 'crisps', ':-)', 'ruin', 'good', 'thing?'], 1),
#  (['stats', 'day', 'arrived.', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['person.', 'small', 'things', 'expect', 'person', 'love'], 1),
#  (['wayward', 'pines', 'later!:)'], 1),
#  (['lovely',
#    'time!',
#    'get',
#    'chance,',
#    'come',
#    'say',
#    'hello',
#    'garden',
#    '&amp;',
#    'home',
#    'area,',
#    'really',
#    'hope',
#    'enjoy',
#    'show'],
#   1),
#  (['steve',
#    'bell',
#    'john',
#    'prescott',
#    'labour',
#    'leadership',
#    'contest',
#    'cartoon',
#    'let',
#    'loose',
#    'dog!'],
#   1),
#  (['cry'], 0),
#  (['sad', 'day', 'nathan'], 0),
#  (['rather',
#    'finding',
#    '"bests"',
#    'person',
#    'finding',
#    'worsts,',
#    'makes',
#    'life',
#    'easy',
#    'others'],
#   1),
#  (['know',
#    'dumb,',
#    'think',
#    'own.',
#    'johnny',
#    'rock',
#    'seen',
#    'utube',
#    "video's?",
#    'mad',
#    'respect!'],
#   1),
#  (['rooting', 'kuch', 'nahi', 'hua'], 0),
#  (['heck', 'follow', 'her?'], 0),
#  (['left', 'ear', 'swelling'], 0),
#  ...]

# %%
# # Training the Naive Bayes classifier
# training_set = nltk.classify.apply_features(extract_features, tweets)
# classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
# neg_cnt = 0
# pos_cnt = 0
# for obj in test_neg: 
#     res =  classifier.classify(extract_features(obj.split()))
#     if(res == 0): 
#         neg_cnt = neg_cnt + 1
# for obj in test_pos: 
#     res =  classifier.classify(extract_features(obj.split()))
#     if(res == 1): 
#         pos_cnt = pos_cnt + 1

# print('[Negative]: %s/%s '  % (len(test_neg),neg_cnt))        
# print('[Positive]: %s/%s '  % (len(test_pos),pos_cnt))

# %% [markdown]
# ## Useful links to start NLP
# <br>
# https://realpython.com/python-nltk-sentiment-analysis/

# %%
models = (
    "nb",  # naive bayes
    "rf",  # random forest
    "lg",  # 
    "svm",  # svm
    "vader"
)

metrics = (
    "f1",
    "prec",
    "recal"
)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Studia\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
train
# Out:
#                                                   Tweet  Sentiment
# 4137  #FollowFriday @StayfanChemin @CCI_75 @aandreup...          1
# 1676          @my_nameis_dan Download only isn't it? :(          0
# 3479  The taxi driver thought me and Sophie worked f...          0
# 1500  @Dinnerbone *Future MegaMoh in 7/29/2015* Happ...          1
# 6379               @NotThatBobJames Hahaha Go Doug! :-)          1
# ...                                                 ...        ...
# 4574  @BigMammaJosie lil bitch, Heiya, visit my site...          1
# 7684  @MandaScapinello oh yeah?? I am definitely goi...          1
# 5163  Bowling is always best with friends :) http://...          1
# 2061  @caylahhhh lmfao seriously??? I can't remember...          0
# 5485  I felt bad when Irene forgot what she was goin...          0
#
# [9000 rows x 2 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import precision_score, recall_score, f1_score

tweets = []
stopwords_set = set(stopwords.words("english"))

for index, row in train.iterrows():
    words_filtered = [e.lower() for e in row.Tweet.split() if len(e) >= 3]
    words_cleaned = [word for word in words_filtered
                     if 'http' not in word
                     and not word.startswith('@')
                     and not word.startswith('#')
                     and word != 'RT']

    words_without_stopwords = [
        word
        for word in words_cleaned
        if not word in stopwords_set
        ]

    tweets.append((' '.join(words_without_stopwords), row.Sentiment))

tweet_texts, labels = zip(*tweets)

X_train, X_test, y_train, y_test = train_test_split(
    tweet_texts, labels, test_size=0.2, random_state=42
    )

models = {
    "nb": make_pipeline(CountVectorizer(), MultinomialNB()),  # Naive Bayes
    "rf": make_pipeline(CountVectorizer(), RandomForestClassifier()),  # Random Forest
    "lg": make_pipeline(CountVectorizer(), LogisticRegression()),  # Logistic Regression
    "svm": make_pipeline(CountVectorizer(), SVC()),  # Support Vector Machine
    "vader": SentimentIntensityAnalyzer()  # VADER - narzędzie do analizy sentymentu
}

results = {}

for name, model in models.items():
    if name != "vader":
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
    else:
        y_pred = [
            1
            if models["vader"].polarity_scores(tweet)["compound"] > 0
            else 0
            for tweet in X_test
            ]

    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results[name] = {
        "F1": f1,
        "Precision": precision,
        "Recall": recall,
        
    }

df_results = pd.DataFrame(results).T

test_pos = test[test['Sentiment'] == 1]['Tweet']
test_neg = test[test['Sentiment'] == 0]['Tweet']

# %%
df_results.T
# Out:
#                  nb        rf        lg       svm     vader
# F1         0.742508  0.712684  0.730435  0.708333  0.655076
# Precision  0.739227  0.756892  0.760870  0.786395  0.659142
# Recall     0.745819  0.673356  0.702341  0.644370  0.651059

# %%
from sklearn.model_selection import GridSearchCV


# Funkcja do tuningu hiperparametrów modeli
def tune_model(model, param_grid, X_train, y_train):
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='f1', cv=5)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_


# Definicja parametrów do tuningu dla każdego modelu
param_grids = {
    "nb": {
        'countvectorizer__ngram_range': [(1, 1), (1, 2)],
        'multinomialnb__alpha': [0.1, 0.5, 1.0]
    },
    "rf": {
        'countvectorizer__ngram_range': [(1, 1), (1, 2)],
        'randomforestclassifier__n_estimators': [100, 200],
        'randomforestclassifier__max_depth': [None, 10, 20]
    },
    "lg": {
        'countvectorizer__ngram_range': [(1, 1), (1, 2)],
        'logisticregression__C': [0.1, 1.0, 10.0],
        'logisticregression__solver': ['liblinear', 'lbfgs']
    },
    "svm": {
        'countvectorizer__ngram_range': [(1, 1), (1, 2)],
        'svc__C': [0.1, 1.0, 10.0],
        'svc__kernel': ['linear', 'rbf']
    }
}

# Tunowanie modeli i zapis najlepszych parametrów
best_models = {}
best_params = {}

for name, model in models.items():
    if name != "vader":
        print(f"Tuning modelu: {name}")
        best_model, best_param = tune_model(model, param_grids[name], X_train, y_train)
        best_models[name] = best_model
        best_params[name] = best_param

# Wyświetlanie najlepszych parametrów
for name, params in best_params.items():
    print(f"Najlepsze parametry dla {name}: {params}")

# Ocena najlepszych modeli
# results_tuned = {}

# for name, model in best_models.items():
#     # Predykcja na danych testowych przy użyciu najlepszych modeli
#     y_pred = model.predict(X_test)
    
#     # Obliczanie metryk
#     precision = precision_score(y_test, y_pred)
#     recall = recall_score(y_test, y_pred)
#     f1 = f1_score(y_test, y_pred)
    
#     # Zapis wyników dla modelu
#     results_tuned[name] = {
#         "Precision": precision,
#         "Recall": recall,
#         "F1": f1
#     }

# # Wyświetlanie wyników
# df_results_tuned = pd.DataFrame(results_tuned).T
# import ace_tools as tools; tools.display_dataframe_to_user(name="Tuned Model Performance", dataframe=df_results_tuned)
# Out:
# Tuning modelu: nb
# Tuning modelu: rf
