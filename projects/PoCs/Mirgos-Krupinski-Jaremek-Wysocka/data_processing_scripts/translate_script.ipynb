# %%
import os, openai
from pathlib import Path
import random, asyncio, aiohttp
from typing import List

async def translate_chunk_async(text: str, session) -> str:
    async with session.post(
        "https://api.openai.com/v1/chat/completions",
        headers={"Authorization": f"Bearer {openai.api_key}"},
        json={
            "model": "gpt-4o-mini-2024-07-18",
            "messages": [
                {"role": "system", "content": "Translate the following text to English. Keep the original structure and formatting."},
                {"role": "user", "content": text}
            ]
        }
    ) as response:
        result = await response.json()
        return result['choices'][0]['message']['content'].strip()

async def process_batch(paragraphs: List[str], session) -> List[str]:
    tasks = [translate_chunk_async(p, session) for p in paragraphs]
    results = await asyncio.gather(*tasks, return_exceptions=True)
    return [r for r in results if not isinstance(r, Exception)]

def split_into_paragraphs(text: str) -> List[str]:
    return [p.strip() for p in text.split('\n\n') if p.strip()]

async def process_files_async(input_dir: str, output_dir: str, batch_size: int = 5, min_paragraphs: int = 100):
    source_dir = Path(output_dir) / 'source'
    translations_dir = Path(output_dir) / 'translations'
    
    for dir_path in [source_dir, translations_dir]:
        dir_path.mkdir(parents=True, exist_ok=True)
    
    async with aiohttp.ClientSession() as session:
        for file_path in Path(input_dir).glob('*.txt'):
            text = file_path.read_text()
            paragraphs = split_into_paragraphs(text)
            
            if len(paragraphs) > min_paragraphs:
                paragraphs = random.sample(paragraphs, min_paragraphs)
            
            source_chunks = []
            translated_chunks = []
            
            for i in range(0, len(paragraphs), batch_size):
                batch = paragraphs[i:i+batch_size]
                translations = await process_batch(batch, session)
                
                source_chunks.extend(batch)
                translated_chunks.extend(translations)
                print(f"{file_path.stem}: {len(translated_chunks)}/{len(paragraphs)} paragraphs translated")
            
            # Save source and translation with === separators
            (source_dir / f"{file_path.stem}.txt").write_text('\n===\n'.join(source_chunks))
            (translations_dir / f"{file_path.stem}.txt").write_text('\n===\n'.join(translated_chunks))

if __name__ == "__main__":
    with open('../../secret.txt') as f:
        openai.api_key = f.read().strip()
    await process_files_async('../rawdata', 'trans')
# Out:
# Balladyna: 5/100 paragraphs translated
# Balladyna: 10/100 paragraphs translated
# Balladyna: 15/100 paragraphs translated
# Balladyna: 20/100 paragraphs translated
# Balladyna: 25/100 paragraphs translated
# Balladyna: 30/100 paragraphs translated
# Balladyna: 35/100 paragraphs translated
# Balladyna: 40/100 paragraphs translated
# Balladyna: 45/100 paragraphs translated
# Balladyna: 50/100 paragraphs translated
# Balladyna: 55/100 paragraphs translated
# Balladyna: 60/100 paragraphs translated
# Balladyna: 65/100 paragraphs translated
# Balladyna: 70/100 paragraphs translated
# Balladyna: 75/100 paragraphs translated
# Balladyna: 80/100 paragraphs translated
# Balladyna: 85/100 paragraphs translated
# Balladyna: 90/100 paragraphs translated
# Balladyna: 95/100 paragraphs translated
# Balladyna: 100/100 paragraphs translated
# Dziady_(Mickiewicz): 5/100 paragraphs translated
# Dziady_(Mickiewicz): 10/100 paragraphs translated
# Dziady_(Mickiewicz): 15/100 paragraphs translated
# Dziady_(Mickiewicz): 20/100 paragraphs translated
# Dziady_(Mickiewicz): 25/100 paragraphs translated
# Dziady_(Mickiewicz): 30/100 paragraphs translated
# Dziady_(Mickiewicz): 35/100 paragraphs translated
# Dziady_(Mickiewicz): 40/100 paragraphs translated
# Dziady_(Mickiewicz): 45/100 paragraphs translated
# Dziady_(Mickiewicz): 50/100 paragraphs translated
# Dziady_(Mickiewicz): 55/100 paragraphs translated
# Dziady_(Mickiewicz): 60/100 paragraphs translated
# Dziady_(Mickiewicz): 65/100 paragraphs translated
# Dziady_(Mickiewicz): 70/100 paragraphs translated
# Dziady_(Mickiewicz): 75/100 paragraphs translated
# Dziady_(Mickiewicz): 80/100 paragraphs translated
# Dziady_(Mickiewicz): 85/100 paragraphs translated
# Dziady_(Mickiewicz): 90/100 paragraphs translated
# Dziady_(Mickiewicz): 95/100 paragraphs translated
# Dziady_(Mickiewicz): 100/100 paragraphs translated
# Konrad_Wallenrod: 5/100 paragraphs translated
# Konrad_Wallenrod: 10/100 paragraphs translated
# Konrad_Wallenrod: 15/100 paragraphs translated
# Konrad_Wallenrod: 20/100 paragraphs translated
# Konrad_Wallenrod: 25/100 paragraphs translated
# Konrad_Wallenrod: 30/100 paragraphs translated
# Konrad_Wallenrod: 35/100 paragraphs translated
# Konrad_Wallenrod: 40/100 paragraphs translated
# Konrad_Wallenrod: 45/100 paragraphs translated
# Konrad_Wallenrod: 50/100 paragraphs translated
# Konrad_Wallenrod: 55/100 paragraphs translated
# Konrad_Wallenrod: 60/100 paragraphs translated
# Konrad_Wallenrod: 65/100 paragraphs translated
# Konrad_Wallenrod: 70/100 paragraphs translated
# Konrad_Wallenrod: 75/100 paragraphs translated
# Konrad_Wallenrod: 80/100 paragraphs translated
# Konrad_Wallenrod: 85/100 paragraphs translated
# Konrad_Wallenrod: 90/100 paragraphs translated
# Konrad_Wallenrod: 95/100 paragraphs translated
# Konrad_Wallenrod: 100/100 paragraphs translated
# Kordian: 5/100 paragraphs translated
# Kordian: 10/100 paragraphs translated
# Kordian: 15/100 paragraphs translated
# Kordian: 20/100 paragraphs translated
# Kordian: 25/100 paragraphs translated
# Kordian: 30/100 paragraphs translated
# Kordian: 35/100 paragraphs translated
# Kordian: 40/100 paragraphs translated
# Kordian: 45/100 paragraphs translated
# Kordian: 50/100 paragraphs translated
# Kordian: 55/100 paragraphs translated
# Kordian: 60/100 paragraphs translated
# Kordian: 65/100 paragraphs translated
# Kordian: 70/100 paragraphs translated
# Kordian: 75/100 paragraphs translated
# Kordian: 80/100 paragraphs translated
# Kordian: 85/100 paragraphs translated
# Kordian: 90/100 paragraphs translated
# Kordian: 95/100 paragraphs translated
# Kordian: 100/100 paragraphs translated
# Lalka_(Prus): 5/100 paragraphs translated
# Lalka_(Prus): 10/100 paragraphs translated
# Lalka_(Prus): 15/100 paragraphs translated
# Lalka_(Prus): 20/100 paragraphs translated
# Lalka_(Prus): 25/100 paragraphs translated
# Lalka_(Prus): 30/100 paragraphs translated
# Lalka_(Prus): 35/100 paragraphs translated
# Lalka_(Prus): 40/100 paragraphs translated
# Lalka_(Prus): 45/100 paragraphs translated
# Lalka_(Prus): 50/100 paragraphs translated
# Lalka_(Prus): 55/100 paragraphs translated
# Lalka_(Prus): 60/100 paragraphs translated
# Lalka_(Prus): 65/100 paragraphs translated
# Lalka_(Prus): 70/100 paragraphs translated
# Lalka_(Prus): 75/100 paragraphs translated
# Lalka_(Prus): 80/100 paragraphs translated
# Lalka_(Prus): 85/100 paragraphs translated
# Lalka_(Prus): 90/100 paragraphs translated
# Lalka_(Prus): 95/100 paragraphs translated
# Lalka_(Prus): 100/100 paragraphs translated
# Ogniem_i_mieczem: 5/100 paragraphs translated
# Ogniem_i_mieczem: 10/100 paragraphs translated
# Ogniem_i_mieczem: 15/100 paragraphs translated
# Ogniem_i_mieczem: 20/100 paragraphs translated
# Ogniem_i_mieczem: 25/100 paragraphs translated
# Ogniem_i_mieczem: 30/100 paragraphs translated
# Ogniem_i_mieczem: 35/100 paragraphs translated
# Ogniem_i_mieczem: 40/100 paragraphs translated
# Ogniem_i_mieczem: 45/100 paragraphs translated
# Ogniem_i_mieczem: 50/100 paragraphs translated
# Ogniem_i_mieczem: 55/100 paragraphs translated
# Ogniem_i_mieczem: 60/100 paragraphs translated
# Ogniem_i_mieczem: 65/100 paragraphs translated
# Ogniem_i_mieczem: 70/100 paragraphs translated
# Ogniem_i_mieczem: 75/100 paragraphs translated
# Ogniem_i_mieczem: 80/100 paragraphs translated
# Ogniem_i_mieczem: 85/100 paragraphs translated
# Ogniem_i_mieczem: 90/100 paragraphs translated
# Ogniem_i_mieczem: 95/100 paragraphs translated
# Ogniem_i_mieczem: 100/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 5/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 10/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 15/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 20/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 25/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 30/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 35/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 40/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 45/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 50/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 55/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 60/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 65/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 70/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 75/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 80/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 85/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 90/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 95/100 paragraphs translated
# Pan_Tadeusz_(wyd._1834): 100/100 paragraphs translated
# Pan_Wołodyjowski: 5/100 paragraphs translated
# Pan_Wołodyjowski: 10/100 paragraphs translated
# Pan_Wołodyjowski: 15/100 paragraphs translated
# Pan_Wołodyjowski: 20/100 paragraphs translated
# Pan_Wołodyjowski: 25/100 paragraphs translated
# Pan_Wołodyjowski: 30/100 paragraphs translated
# Pan_Wołodyjowski: 35/100 paragraphs translated
# Pan_Wołodyjowski: 40/100 paragraphs translated
# Pan_Wołodyjowski: 45/100 paragraphs translated
# Pan_Wołodyjowski: 50/100 paragraphs translated
# Pan_Wołodyjowski: 55/100 paragraphs translated
# Pan_Wołodyjowski: 60/100 paragraphs translated
# Pan_Wołodyjowski: 65/100 paragraphs translated
# Pan_Wołodyjowski: 70/100 paragraphs translated
# Pan_Wołodyjowski: 75/100 paragraphs translated
# Pan_Wołodyjowski: 80/100 paragraphs translated
# Pan_Wołodyjowski: 85/100 paragraphs translated
# Pan_Wołodyjowski: 90/100 paragraphs translated
# Pan_Wołodyjowski: 95/100 paragraphs translated
# Pan_Wołodyjowski: 100/100 paragraphs translated
# Potop_(Sienkiewicz): 5/100 paragraphs translated
# Potop_(Sienkiewicz): 10/100 paragraphs translated
# Potop_(Sienkiewicz): 15/100 paragraphs translated
# Potop_(Sienkiewicz): 20/100 paragraphs translated
# Potop_(Sienkiewicz): 25/100 paragraphs translated
# Potop_(Sienkiewicz): 30/100 paragraphs translated
# Potop_(Sienkiewicz): 35/100 paragraphs translated
# Potop_(Sienkiewicz): 40/100 paragraphs translated
# Potop_(Sienkiewicz): 45/100 paragraphs translated
# Potop_(Sienkiewicz): 50/100 paragraphs translated
# Potop_(Sienkiewicz): 55/100 paragraphs translated
# Potop_(Sienkiewicz): 60/100 paragraphs translated
# Potop_(Sienkiewicz): 65/100 paragraphs translated
# Potop_(Sienkiewicz): 70/100 paragraphs translated
# Potop_(Sienkiewicz): 75/100 paragraphs translated
# Potop_(Sienkiewicz): 80/100 paragraphs translated
# Potop_(Sienkiewicz): 85/100 paragraphs translated
# Potop_(Sienkiewicz): 90/100 paragraphs translated
# Potop_(Sienkiewicz): 95/100 paragraphs translated
# Potop_(Sienkiewicz): 100/100 paragraphs translated
# Quo_vadis: 5/100 paragraphs translated
# Quo_vadis: 10/100 paragraphs translated
# Quo_vadis: 15/100 paragraphs translated
# Quo_vadis: 20/100 paragraphs translated
# Quo_vadis: 25/100 paragraphs translated
# Quo_vadis: 30/100 paragraphs translated
# Quo_vadis: 35/100 paragraphs translated
# Quo_vadis: 40/100 paragraphs translated
# Quo_vadis: 45/100 paragraphs translated
# Quo_vadis: 50/100 paragraphs translated
# Quo_vadis: 55/100 paragraphs translated
# Quo_vadis: 60/100 paragraphs translated
# Quo_vadis: 65/100 paragraphs translated
# Quo_vadis: 70/100 paragraphs translated
# Quo_vadis: 75/100 paragraphs translated
# Quo_vadis: 80/100 paragraphs translated
# Quo_vadis: 85/100 paragraphs translated
# Quo_vadis: 90/100 paragraphs translated
# Quo_vadis: 95/100 paragraphs translated
# Quo_vadis: 100/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 5/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 10/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 15/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 20/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 25/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 30/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 35/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 40/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 45/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 50/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 55/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 60/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 65/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 70/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 75/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 80/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 85/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 90/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 95/100 paragraphs translated
# Sonety_Adama_Mickiewicza: 100/100 paragraphs translated
