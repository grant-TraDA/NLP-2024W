# %%
import os, openai
from pathlib import Path
import asyncio, aiohttp, random
from typing import List, Tuple

async def summarize_chunk_async(text: str, session) -> str:
    async with session.post(
        "https://api.openai.com/v1/chat/completions",
        headers={"Authorization": f"Bearer {openai.api_key}"},
        json={
            "model": "gpt-4o-mini-2024-07-18",
            "messages": [
                {"role": "system", "content": "Provide a concise summary in Polish focusing on key points. Make it into a paragraph in one line."},
                {"role": "user", "content": text}
            ]
        }
    ) as response:
        result = await response.json()
        return result['choices'][0]['message']['content'].strip()

async def process_batch(chunks: List[str], session) -> List[str]:
    tasks = [summarize_chunk_async(chunk, session) for chunk in chunks]
    results = await asyncio.gather(*tasks, return_exceptions=True)
    return [r for r in results if not isinstance(r, Exception)]

def get_chunks(text: str, chunk_size: int = 2000, num_samples: int = 100) -> List[Tuple[int, str]]:
    # Create chunks with their positions
    chunks = [(i, text[i:i+chunk_size]) 
             for i in range(0, len(text), chunk_size)]
    
    # Sample if we have more chunks than needed
    if len(chunks) > num_samples:
        return random.sample(chunks, num_samples)
    return chunks

async def process_files_async(input_dir: str, output_dir: str, batch_size: int = 5, chunk_size: int = 2000):
    source_dir = Path(output_dir) / 'source'
    summaries_dir = Path(output_dir) / 'summaries'
    
    for dir_path in [source_dir, summaries_dir]:
        dir_path.mkdir(parents=True, exist_ok=True)
    
    async with aiohttp.ClientSession() as session:
        for file_path in Path(input_dir).glob('*.txt'):
            text = file_path.read_text()
            chunk_pairs = get_chunks(text, chunk_size)  # Get position-chunk pairs
            # Sort by position to maintain order
            chunk_pairs.sort(key=lambda x: x[0])
            chunks = [chunk for _, chunk in chunk_pairs]
            
            summaries = []
            for i in range(0, len(chunks), batch_size):
                batch = chunks[i:i+batch_size]
                batch_summaries = await process_batch(batch, session)
                summaries.extend(batch_summaries)
                print(f"{file_path.stem}: {len(summaries)}/{len(chunks)} chunks summarized")
            
            # Save source chunks and summaries with === separators
            (source_dir / f"{file_path.stem}.txt").write_text('\n===\n'.join(chunks))
            (summaries_dir / f"{file_path.stem}.txt").write_text('\n===\n'.join(summaries))

if __name__ == "__main__":
    with open('../../secret.txt') as f:
        openai.api_key = f.read().strip()
    await process_files_async('../rawdata', 'summary')
# Out:
# Balladyna: 5/86 chunks summarized
# Balladyna: 10/86 chunks summarized
# Balladyna: 15/86 chunks summarized
# Balladyna: 20/86 chunks summarized
# Balladyna: 25/86 chunks summarized
# Balladyna: 30/86 chunks summarized
# Balladyna: 35/86 chunks summarized
# Balladyna: 40/86 chunks summarized
# Balladyna: 45/86 chunks summarized
# Balladyna: 50/86 chunks summarized
# Balladyna: 55/86 chunks summarized
# Balladyna: 60/86 chunks summarized
# Balladyna: 65/86 chunks summarized
# Balladyna: 70/86 chunks summarized
# Balladyna: 75/86 chunks summarized
# Balladyna: 80/86 chunks summarized
# Balladyna: 85/86 chunks summarized
# Balladyna: 86/86 chunks summarized
# Dziady_(Mickiewicz): 5/100 chunks summarized
# Dziady_(Mickiewicz): 10/100 chunks summarized
# Dziady_(Mickiewicz): 15/100 chunks summarized
# Dziady_(Mickiewicz): 20/100 chunks summarized
# Dziady_(Mickiewicz): 25/100 chunks summarized
# Dziady_(Mickiewicz): 30/100 chunks summarized
# Dziady_(Mickiewicz): 35/100 chunks summarized
# Dziady_(Mickiewicz): 40/100 chunks summarized
# Dziady_(Mickiewicz): 45/100 chunks summarized
# Dziady_(Mickiewicz): 50/100 chunks summarized
# Dziady_(Mickiewicz): 55/100 chunks summarized
# Dziady_(Mickiewicz): 60/100 chunks summarized
# Dziady_(Mickiewicz): 65/100 chunks summarized
# Dziady_(Mickiewicz): 70/100 chunks summarized
# Dziady_(Mickiewicz): 75/100 chunks summarized
# Dziady_(Mickiewicz): 80/100 chunks summarized
# Dziady_(Mickiewicz): 85/100 chunks summarized
# Dziady_(Mickiewicz): 90/100 chunks summarized
# Dziady_(Mickiewicz): 95/100 chunks summarized
# Dziady_(Mickiewicz): 100/100 chunks summarized
# Konrad_Wallenrod: 5/51 chunks summarized
# Konrad_Wallenrod: 10/51 chunks summarized
# Konrad_Wallenrod: 15/51 chunks summarized
# Konrad_Wallenrod: 20/51 chunks summarized
# Konrad_Wallenrod: 25/51 chunks summarized
# Konrad_Wallenrod: 30/51 chunks summarized
# Konrad_Wallenrod: 35/51 chunks summarized
# Konrad_Wallenrod: 40/51 chunks summarized
# Konrad_Wallenrod: 45/51 chunks summarized
# Konrad_Wallenrod: 50/51 chunks summarized
# Konrad_Wallenrod: 51/51 chunks summarized
# Kordian: 5/100 chunks summarized
# Kordian: 10/100 chunks summarized
# Kordian: 15/100 chunks summarized
# Kordian: 20/100 chunks summarized
# Kordian: 25/100 chunks summarized
# Kordian: 30/100 chunks summarized
# Kordian: 35/100 chunks summarized
# Kordian: 40/100 chunks summarized
# Kordian: 45/100 chunks summarized
# Kordian: 50/100 chunks summarized
# Kordian: 55/100 chunks summarized
# Kordian: 60/100 chunks summarized
# Kordian: 65/100 chunks summarized
# Kordian: 70/100 chunks summarized
# Kordian: 75/100 chunks summarized
# Kordian: 80/100 chunks summarized
# Kordian: 85/100 chunks summarized
# Kordian: 90/100 chunks summarized
# Kordian: 95/100 chunks summarized
# Kordian: 100/100 chunks summarized
# Lalka_(Prus): 5/100 chunks summarized
# Lalka_(Prus): 10/100 chunks summarized
# Lalka_(Prus): 15/100 chunks summarized
# Lalka_(Prus): 20/100 chunks summarized
# Lalka_(Prus): 25/100 chunks summarized
# Lalka_(Prus): 30/100 chunks summarized
# Lalka_(Prus): 35/100 chunks summarized
# Lalka_(Prus): 40/100 chunks summarized
# Lalka_(Prus): 45/100 chunks summarized
# Lalka_(Prus): 50/100 chunks summarized
# Lalka_(Prus): 55/100 chunks summarized
# Lalka_(Prus): 60/100 chunks summarized
# Lalka_(Prus): 65/100 chunks summarized
# Lalka_(Prus): 70/100 chunks summarized
# Lalka_(Prus): 75/100 chunks summarized
# Lalka_(Prus): 80/100 chunks summarized
# Lalka_(Prus): 85/100 chunks summarized
# Lalka_(Prus): 90/100 chunks summarized
# Lalka_(Prus): 95/100 chunks summarized
# Lalka_(Prus): 100/100 chunks summarized
# Ogniem_i_mieczem: 5/100 chunks summarized
# Ogniem_i_mieczem: 10/100 chunks summarized
# Ogniem_i_mieczem: 15/100 chunks summarized
# Ogniem_i_mieczem: 20/100 chunks summarized
# Ogniem_i_mieczem: 25/100 chunks summarized
# Ogniem_i_mieczem: 30/100 chunks summarized
# Ogniem_i_mieczem: 35/100 chunks summarized
# Ogniem_i_mieczem: 40/100 chunks summarized
# Ogniem_i_mieczem: 45/100 chunks summarized
# Ogniem_i_mieczem: 50/100 chunks summarized
# Ogniem_i_mieczem: 55/100 chunks summarized
# Ogniem_i_mieczem: 60/100 chunks summarized
# Ogniem_i_mieczem: 65/100 chunks summarized
# Ogniem_i_mieczem: 70/100 chunks summarized
# Ogniem_i_mieczem: 75/100 chunks summarized
# Ogniem_i_mieczem: 80/100 chunks summarized
# Ogniem_i_mieczem: 85/100 chunks summarized
# Ogniem_i_mieczem: 90/100 chunks summarized
# Ogniem_i_mieczem: 95/100 chunks summarized
# Ogniem_i_mieczem: 100/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 5/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 10/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 15/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 20/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 25/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 30/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 35/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 40/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 45/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 50/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 55/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 60/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 65/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 70/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 75/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 80/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 85/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 90/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 95/100 chunks summarized
# Pan_Tadeusz_(wyd._1834): 100/100 chunks summarized
# Pan_Wołodyjowski: 5/100 chunks summarized
# Pan_Wołodyjowski: 10/100 chunks summarized
# Pan_Wołodyjowski: 15/100 chunks summarized
# Pan_Wołodyjowski: 20/100 chunks summarized
# Pan_Wołodyjowski: 25/100 chunks summarized
# Pan_Wołodyjowski: 30/100 chunks summarized
# Pan_Wołodyjowski: 35/100 chunks summarized
# Pan_Wołodyjowski: 40/100 chunks summarized
# Pan_Wołodyjowski: 45/100 chunks summarized
# Pan_Wołodyjowski: 50/100 chunks summarized
# Pan_Wołodyjowski: 55/100 chunks summarized
# Pan_Wołodyjowski: 60/100 chunks summarized
# Pan_Wołodyjowski: 65/100 chunks summarized
# Pan_Wołodyjowski: 70/100 chunks summarized
# Pan_Wołodyjowski: 75/100 chunks summarized
# Pan_Wołodyjowski: 80/100 chunks summarized
# Pan_Wołodyjowski: 85/100 chunks summarized
# Pan_Wołodyjowski: 90/100 chunks summarized
# Pan_Wołodyjowski: 95/100 chunks summarized
# Pan_Wołodyjowski: 100/100 chunks summarized
# Potop_(Sienkiewicz): 5/100 chunks summarized
# Potop_(Sienkiewicz): 10/100 chunks summarized
# Potop_(Sienkiewicz): 15/100 chunks summarized
# Potop_(Sienkiewicz): 20/100 chunks summarized
# Potop_(Sienkiewicz): 25/100 chunks summarized
# Potop_(Sienkiewicz): 30/100 chunks summarized
# Potop_(Sienkiewicz): 35/100 chunks summarized
# Potop_(Sienkiewicz): 40/100 chunks summarized
# Potop_(Sienkiewicz): 45/100 chunks summarized
# Potop_(Sienkiewicz): 50/100 chunks summarized
# Potop_(Sienkiewicz): 55/100 chunks summarized
# Potop_(Sienkiewicz): 60/100 chunks summarized
# Potop_(Sienkiewicz): 65/100 chunks summarized
# Potop_(Sienkiewicz): 70/100 chunks summarized
# Potop_(Sienkiewicz): 75/100 chunks summarized
# Potop_(Sienkiewicz): 80/100 chunks summarized
# Potop_(Sienkiewicz): 85/100 chunks summarized
# Potop_(Sienkiewicz): 90/100 chunks summarized
# Potop_(Sienkiewicz): 95/100 chunks summarized
# Potop_(Sienkiewicz): 100/100 chunks summarized
# Quo_vadis: 5/100 chunks summarized
# Quo_vadis: 10/100 chunks summarized
# Quo_vadis: 15/100 chunks summarized
# Quo_vadis: 20/100 chunks summarized
# Quo_vadis: 25/100 chunks summarized
# Quo_vadis: 30/100 chunks summarized
# Quo_vadis: 35/100 chunks summarized
# Quo_vadis: 40/100 chunks summarized
# Quo_vadis: 45/100 chunks summarized
# Quo_vadis: 50/100 chunks summarized
# Quo_vadis: 55/100 chunks summarized
# Quo_vadis: 60/100 chunks summarized
# Quo_vadis: 65/100 chunks summarized
# Quo_vadis: 70/100 chunks summarized
# Quo_vadis: 75/100 chunks summarized
# Quo_vadis: 80/100 chunks summarized
# Quo_vadis: 85/100 chunks summarized
# Quo_vadis: 90/100 chunks summarized
# Quo_vadis: 95/100 chunks summarized
# Quo_vadis: 100/100 chunks summarized
# Sonety_Adama_Mickiewicza: 5/20 chunks summarized
# Sonety_Adama_Mickiewicza: 10/20 chunks summarized
# Sonety_Adama_Mickiewicza: 15/20 chunks summarized
# Sonety_Adama_Mickiewicza: 20/20 chunks summarized
