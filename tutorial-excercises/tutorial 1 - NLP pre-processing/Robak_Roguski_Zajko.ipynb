# %% [markdown]
# ## Introduction to NLP (Natural Language Processing)
# <br>
# © mgr inż. Soveatin Kuntur / Winter School - Data Literacy
# <br>
# Warsaw, 06.02 - 10.02.2023
#
# © Anna Wróblewska, improvements and adding more metrics, and classifiers

# %% [markdown]
# As we know from lecture, general pipeline of NLP is as follows:
# <br>
# 1. Data Preprocessing
# <br>
# 2. Data Processing
# <br>
# 3. Output

# %% [markdown]
# ## Data Processing
#
# Now we come to second part of our experiment which is data processing. This task will be classification problem. Which means, we will ask our model to classify the sentiment. It is worth to mention that, you can use your clean dataset to do this part. <br>
#
# As for example reason, teacher will show how to use sklearn packages on this part.

# %% [markdown]
# ## Dataset Description
# The sample dataset from NLTK is separated into positive and negative tweets. It contains 5000 positive tweets and 5000 negative tweets exactly. The exact match between these classes is not a coincidence. The intention is to have a balanced dataset. That does not reflect the real distributions of positive and negative classes in live Twitter streams. It is just because balanced datasets simplify the design of most computational methods that are required for sentiment analysis. However, it is better to be aware that this balance of classes is artificial.
#
# You can download the dataset in your workspace (or in your local computer) by doing
# <br>
# nltk.download('twitter_samples')

# %%
import nltk                                # Python library for NLP
from nltk.corpus import twitter_samples    # sample Twitter dataset from NLTK
from nltk.corpus import stopwords
import matplotlib.pyplot as plt            # library for visualization
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
# We can load the text fields of the positive and negative tweets by using the module's `strings()` method like this:

# %%
# downloads sample twitter dataset.
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/mikolaj3/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# To make it easier, let us used pandas dataframe

# %%
# Create a dataframe from positive tweets
pos_tweet = pd.DataFrame(all_positive_tweets, columns=['Tweet'])
# Add a column to dataframe for positive sentiment value 1
pos_tweet['Sentiment'] = 1
# Create a temporary dataframe for negative tweets
neg_tweet = pd.DataFrame(all_negative_tweets, columns=['Tweet'])
# Add a column to temporary dataframe for negative sentiment value 0
neg_tweet['Sentiment'] = 0
# Combe positive and negative tweets in one single dataframe
#df = pos_tweet.append(neg_tweet, ignore_index=True)
df = pd.concat([neg_tweet, pos_tweet], ignore_index=True)

df = df.sample(frac = 1)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                   Tweet  Sentiment
# 0                                        Aww too bad :(          0
# 1     This actually made me cry this is so disgustin...          0
# 2     Waiting patiently for mr. crush :) but first, ...          1
# 3     @TikoSD Hi! Would you like an @imPastel concer...          1
# 4     @GFuelEnergy i want that but i dont have paypa...          0
# ...                                                 ...        ...
# 9995        @glennlondey @CarltonFC looking that way :(          0
# 9996  so I guess blocking number on phones spam SMS ...          0
# 9997  @jackiHS What an absolute cutie - congratulati...          1
# 9998                        @CallmeLexine Same Mommy :(          0
# 9999  @LewissCharles Cooper, but I'm not convinced. ...          0
#
# [10000 rows x 2 columns]

# %% [markdown]
# Next, we'll print a report with the number of positive and negative tweets. It is also essential to know the data structure of the datasets

# %%
# Displaying shape of dataset
print('Dataset size:',df.shape)
df.groupby('Sentiment').count()
# Out:
# Dataset size: (10000, 2)
#            Tweet
# Sentiment
# 0           5000
# 1           5000

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(df,test_size = 0.1)
train
# Out:
#                                                   Tweet  Sentiment
# 7099                                  @twcxmina shit :(          0
# 598   @AdoreDelano are u there too? :( http://t.co/P...          0
# 2750  Only my bad would remind me to exercise at 1:1...          1
# 7711                            @izzkamilhalda lols. :D          1
# 4843                       @triangledarren thank you :)          1
# ...                                                 ...        ...
# 4112  SNAPCHAT : TammiRossM #snapchat #kikgirl #kikc...          0
# 182                            I can't feel tomorrow :(          0
# 5600  @theemilygrayxo Mmmmm if i wasn't at work i wo...          0
# 8786                            Homebound. :D HAHAHAYS.          1
# 6073  http://t.co/a5rmka5axn thanks for following!! ...          1
#
# [9000 rows x 2 columns]

# %%
test
# Out:
#                                                   Tweet  Sentiment
# 2788  @mr__cooke @CCWeekUK Thank you! We're set to h...          1
# 7644  @hansolotto with SCoups^^ they are for 17 like...          1
# 8075            @SP4NKO Aww love it. My kind of men :))          1
# 1431  @ShadEO9 No worries! Let us know how it goes :...          1
# 3430  💓🚮👯- the definition of perfection would have a...          1
# ...                                                 ...        ...
# 8956                    @safirahasnaerdy follback?:)) x          1
# 7062   can my mum stop picking on my clothes please :-(          0
# 1311  I went on at 10:59 and stayed on at 11.00 unti...          0
# 945   @nuriaagonzalez it was amazing!! Such a short ...          0
# 2167            Happy Friday :-) http://t.co/NHHhKPXstg          1
#
# [1000 rows x 2 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/mikolaj3/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
tweets = []
stopwords_set = set(stopwords.words("english"))
tokenizer = nltk.tokenize.TweetTokenizer(strip_handles=True, reduce_len=True)


for index, row in train.iterrows():
    tweets.append((tokenizer.tokenize(row.Tweet), row.Sentiment))


test_pos = test[ test['Sentiment'] == 1]
test_pos = test_pos['Tweet']
test_neg = test[ test['Sentiment'] == 0]
test_neg = test_neg['Tweet']

# %%
tc = nltk.text.TextCollection(tweets)

def extract_features(document):
    document_words = set(document)
    features = {}
    for word in document_words:
        features[word] = tc.tf_idf(word, document)
    return features

# %%
tweets
# Out:
# [(['shit'], 0),
#  ([], 0),
#  (['bad',
#    'would',
#    'remind',
#    'exercise',
#    '1:12',
#    ':-)',
#    'miss',
#    'needs',
#    'come',
#    'back'],
#   1),
#  (['lols'], 1),
#  (['thank'], 1),
#  (['sisters', 'best', 'best', 'pre', 'bday', 'celebration'], 1),
#  (['...', 'switch', ':-('], 0),
#  (['beautiful', 'via', 'disney.arts', 'talented', 'elmoprinssi', 'forget'], 1),
#  (['got', 'netfilx', 'today', 'whoop', 'whoop'], 1),
#  (['always', 'hard', 'leaving', 'heart', "i'mo", 'sulk', 'day', 'today'], 0),
#  (["they're", 'addictive', 'beautiful', 'flowers', 'humphrey', 'cute'], 1),
#  (['love', 'big', '...', 'juicy', '...', 'selfies'], 1),
#  (['please', 'click', 'link', 'checkout'], 1),
#  (['hungry'], 0),
#  (['thought',
#    'today',
#    'pizza',
#    'day',
#    'sadly',
#    'none',
#    'managers',
#    'usually',
#    'buy'],
#   0),
#  (['lucky'], 0),
#  (['sorted', 'thanks', 'daaru', 'party', 'chaddi', 'bros'], 1),
#  (['visit', 'blog', 'thanks'], 1),
#  (['justin', 'come', 'scotland'], 0),
#  (['think', 'fifth', 'album', 'okay', 'fuck'], 1),
#  (['last',
#    'thing',
#    'labour',
#    'needs',
#    'leader',
#    'people',
#    'want',
#    'vote',
#    'read',
#    'brilliant',
#    ':-)'],
#   1),
#  (['get', 'see', 'glowing', 'sea', 'technically', 'fallout', 'played', 'see'],
#   1),
#  ([], 1),
#  (["i'm", 'sad'], 0),
#  (['happy', 'birthday'], 1),
#  (['sad', 'return', 'holiday', 'find', 'radio', 'morning', 'drive'], 0),
#  (["i'm", 'going', 'kailan', 'may', 'tix'], 0),
#  (['mon', '27july', 'thur', '30july', 'itv'], 1),
#  (['yes', 'course'], 1),
#  (['soul', 'rest', 'peace'], 0),
#  (['erm', "what's", 'like'], 0),
#  (['zayyyyyn'], 0),
#  (['happy', 'long', 'time'], 1),
#  (['thank', 'esai', ':-)'], 1),
#  (['seems', 'like', 'alot', 'something', 'like'], 1),
#  (['see', 'later'], 1),
#  (['ion', 'wanna', 'hear'], 0),
#  (['cute', 'thank'], 0),
#  (['hello', 'twitter', 'account', 'broken'], 1),
#  (['miss', 'hannah', 'montana', "that's", 'raven', 'sooo', 'much', ':-('], 0),
#  (['thankyou', 'treat', 'kanina', 'sorry', 'breakdown', 'sir', 'mags'], 0),
#  (['fuck', 'texting', 'funny', 'dudes', 'dudettes', 'costs', "i'm"], 1),
#  (['movnat', 'belgium', 'first', 'search', 'yields', 'nothing', '...', ':-('],
#   0),
#  (["i'm", 'fan', 'account', 'pitbull'], 1),
#  (['sunday',
#    'morning',
#    'stream',
#    'also',
#    'birthday',
#    'stream',
#    'follow',
#    'usual',
#    'birthday',
#    'procedure',
#    'play',
#    'grim',
#    'fandango'],
#   1),
#  (['ago',
#    'hogo',
#    'vishaya',
#    'adu',
#    'bjp',
#    'madatte',
#    'anta',
#    'vishwas',
#    'illa'],
#   0),
#  (['done', 'yun'], 1),
#  (['want', 'get', 'dota', 'fuck'], 0),
#  (['liked', 'video', 'subs', 'plz'], 0),
#  (['legs', 'hurt', 'bad'], 1),
#  (['screenshotting', 'proud'], 0),
#  (['gusto', "rodic's", 'someone', 'share', 'order', "one's", 'big'], 0),
#  (['yet', 'find', 'eventually'], 0),
#  (['also', 'new', 'layout', 'new'], 1),
#  (['please', 'put', 'spotify', 'please'], 1),
#  (['sorry', 'guys', 'new', 'video', 'week'], 0),
#  (['back', 'delhi'], 0),
#  (['achieving',
#    'excellence',
#    'music',
#    'music',
#    'producer',
#    'mind',
#    'boggling',
#    'fatiguing',
#    'job',
#    '...',
#    'baareeq',
#    '...'],
#   1),
#  (['aha', 'yesss', 'looking', 'forward', 'seeing'], 1),
#  (['thank'], 1),
#  (['loan', 'back', 'january'], 1),
#  (['cinema',
#    'shooting',
#    'mass',
#    'shootings',
#    'happen',
#    'regularly',
#    'sympathis',
#    'victims',
#    'families'],
#   0),
#  (['brian',
#    "i'll",
#    'get',
#    'shipped',
#    'today',
#    'take',
#    '2-3',
#    'weeks',
#    'australia',
#    'many',
#    'thanks'],
#   1),
#  (['wanna',
#    'watch',
#    'maybe',
#    'comeback',
#    'shows',
#    'korea',
#    '...',
#    'japan',
#    'wanna',
#    'visit',
#    'country'],
#   0),
#  (['girl', 'wardrobe', 'would'], 1),
#  (['love', 'much'], 0),
#  (['actually',
#    'tried',
#    'blend',
#    'really',
#    'good',
#    'also',
#    'good',
#    'health',
#    'benefits'],
#   1),
#  (['min', 'follback'], 0),
#  (['follow', 'back'], 1),
#  (['sure', 'done'], 1),
#  (['didnt', 'money', 'time', 'would'], 0),
#  (['friend'], 0),
#  (['please', 'follow', 'return', 'soon', 'follow'], 1),
#  (['feeling',
#    'sucky',
#    'running',
#    'nose',
#    'cough',
#    'sore',
#    'throat',
#    'fever',
#    ':-('],
#   0),
#  (['keeo',
#    'guessing',
#    'whats',
#    'behind',
#    'white',
#    'cover',
#    'special',
#    'happy',
#    'bday',
#    'darling'],
#   1),
#  (['aur', 'bhi', 'shamil'], 0),
#  (['horrible'], 0),
#  (['hence', 'expression', 'wot', 'racket', 'maybe'], 1),
#  (['didnt', 'took', 'photos', ':-('], 0),
#  (["i've", 'watch', 'cooking', 'tutorials', 'things', 'planned', 'summer'], 0),
#  (['smh', 'know'], 0),
#  (["i'll", 'sleep', 'better', 'tonight'], 0),
#  (['followed', 'thanks', 'please', 'followed'], 0),
#  (['great', 'view', 'shame', 'weather', 'though', ':-('], 0),
#  (['margo'], 0),
#  (['hope', 'miss', 'kita', 'crys'], 0),
#  (['want', 'meet'], 0),
#  (['genuinely', 'keep', 'nightmares', 'results', 'day', 'fam'], 0),
#  (['thank', 'mario', '...', 'wonderful', 'friday', '...'], 1),
#  (['follback', 'pls'], 0),
#  (["that's", 'goat', 'mino'], 0),
#  ([], 1),
#  (['sounds', 'cool', 'bet', 'float', 'though'], 0),
#  (['throwback', ':-)'], 1),
#  (['moar', 'kittehs', 'incoming'], 1),
#  (['lolliver'], 0),
#  (['maine',
#    'abhi',
#    'tak',
#    'movie',
#    'nhi',
#    'dekhi',
#    'promos',
#    'knew',
#    'best',
#    'movie',
#    'till',
#    'date'],
#   1),
#  (['jealous', 'want', 'miami'], 0),
#  (['ive', 'emailed', 'regarding', 'course', 'query'], 1),
#  (['stock', 'hour'], 0),
#  (['need', 'finish', 'hws', 'ugh'], 0),
#  (['ahh', 'thank', 'much', 'xxx'], 1),
#  (['people',
#    'point',
#    'inaccuracies',
#    'jokes',
#    'might',
#    'inaccurate',
#    'jokes',
#    'got',
#    'worried'],
#   0),
#  (['looking', 'way'], 0),
#  ([':-(', 'hahaahahahaha'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x17'],
#   1),
#  (['tired', 'fine'], 1),
#  (['tried', 'turning'], 1),
#  (['happy', 'birthday', 'bro', 'good', 'one'], 1),
#  (['finally', 'watching', 'last', 'episode', 'hopefully', 'end'], 0),
#  (['feel', 'free', 'share', 'others', ':-)'], 1),
#  (['interesting',
#    "i've",
#    'never',
#    'heard',
#    'reading',
#    'temporal',
#    'void',
#    'atm',
#    'stem',
#    'needs'],
#   1),
#  (['talking', 'one', 'person', '...', 'two', 'conversations'], 1),
#  (['fab',
#    'gav',
#    'lovely',
#    'lovely',
#    'lady',
#    'linda',
#    'talked',
#    'times',
#    'great',
#    'actress'],
#   1),
#  (['anyone',
#    'managed',
#    'get',
#    'yet',
#    'keep',
#    'getting',
#    'busy',
#    'messages',
#    'think',
#    'worse',
#    'tube',
#    'strike'],
#   0),
#  (['dat',
#    'tho',
#    'thank',
#    'much',
#    'guys',
#    'celebrating',
#    'one',
#    'month',
#    'partnership',
#    'raid'],
#   1),
#  (['add', 'kik', 'mork', '873'], 0),
#  (['car',
#    'suspemsion',
#    'cant',
#    'cope',
#    'offroading',
#    'adventures',
#    'theres',
#    'harvest',
#    'machinery',
#    'left',
#    'inapropriate',
#    'places',
#    'weave',
#    'around'],
#   0),
#  (['fair', 'pb.contestants', 'dreams', 'comes', 'true', 'time'], 0),
#  (["i'm", 'gonna', 'freak'], 1),
#  (['hey', 'dazzle', 'urself', 'double', 'flared', 'red', 'black', 'dress'], 1),
#  (['goodness', 'made', 'sad'], 0),
#  (['man', 'told', 'buy', 'gold', 'way', '1900', 'tell', 'sell'], 0),
#  (['like', 'eyes'], 1),
#  (['case', 'cat', 'videos', 'moods', 'swear'], 1),
#  ([':-('], 0),
#  (['love', 'thank', ':-)', 'exciting', 'plans'], 1),
#  (['unreal',
#    'training',
#    'boys',
#    'awesome',
#    'work',
#    'zaine',
#    'zac',
#    'isaac',
#    'oss'],
#   1),
#  (['updated', 'soon', "i'm", 'sure', 'sign', 'set', 'text', 'alerts'], 1),
#  (['know'], 0),
#  (['9/11',
#    'kinda',
#    'ruined',
#    'sound',
#    'makes',
#    'brace',
#    'hearing',
#    'plane',
#    'crash',
#    'every',
#    'time',
#    'bueno'],
#   0),
#  (['5sos',
#    'calum',
#    '5sos',
#    'luke',
#    '5sos',
#    'ashton',
#    '5sos',
#    'bet',
#    'friend',
#    'follow',
#    'chelny',
#    'disappoint'],
#   0),
#  (['house', 'scary', 'night'], 0),
#  (["i'm", 'start', 'grinding'], 1),
#  (['happy', 'friday', ':-)'], 1),
#  (['hello', 'ligao', 'city', 'albay', ':-)'], 1),
#  (['sir', 'please', 'announce', 'badly', 'waiting'], 0),
#  (['knew', 'give', 'crap', 'lol', 'need', 'burn'], 1),
#  (['one', 'word'], 1),
#  (['fuck', 'andy', '>:('], 0),
#  (['heritage', 'sword', 'made', 'wood'], 1),
#  (['learn', 'spell'], 1),
#  (['gym', 'monday', "can't", 'wait', 'likes'], 1),
#  (['need', 'find', 'boy', 'loves', 'fireball', 'much'], 1),
#  (['longer', 'like', 'toast'], 0),
#  (['con-graduation', 'gents'], 1),
#  (['hey',
#    "it'd",
#    'great',
#    'share',
#    'blog',
#    'started',
#    'writing',
#    'blogs',
#    'check',
#    'let',
#    'know',
#    "how's"],
#   1),
#  (['part', 'elite', 'group'], 1),
#  (['problem', "i'm"], 0),
#  (['nice', 'seeing', 'today', 'vidcon'], 1),
#  (['anyway', 'friday', 'looking', 'kinda', 'gooood'], 1),
#  (['thanks', 'following', 'ask', 'follow', 'back', ':-)', 'via'], 1),
#  (['sun',
#    'may',
#    'shining',
#    'least',
#    'nearly',
#    'weekend',
#    'happy',
#    'friday',
#    'people',
#    ':-)'],
#   1),
#  (['fair', '...', 'fans', 'like', 'abroad', 'get', 'hurt', '...'], 1),
#  (['happy', 'birthday', 'never', 'forget'], 1),
#  (['want', 'chocolate', 'lucozade'], 0),
#  (['bestfriend'], 1),
#  (['happy', 'ending', 'insyaallah'], 1),
#  (['goning',
#    'make',
#    'thos',
#    'positive',
#    'day',
#    'adult',
#    "can't",
#    'keep',
#    'acting',
#    'like',
#    'mom'],
#   1),
#  (['come', 'home', 'tonight', 'tho'], 0),
#  (['school', 'start', 'next', 'monday', 'ohgod'], 0),
#  (['great', 'news', 'thanks', 'letting', 'know', 'hope', 'good', 'weekend'],
#   0),
#  (['mashed', 'phone', 'lost', 'number', 'whattsap', 'avail'], 0),
#  (['miss', 'much'], 0),
#  (['yes', 'big', 'yes', 'finally', 'got', 'home', 'severe', 'rain', 'thanks'],
#   1),
#  (['first', 'time', 'travelling', 'expo', 'worse', 'part', 'ive', 'expo'], 0),
#  (['want', 'play', 'sims'], 0),
#  (['torture'], 0),
#  (['skye',
#    "i'm",
#    'sorry',
#    'hear',
#    'store',
#    'please',
#    'name',
#    'description',
#    'colleague',
#    'please'],
#   0),
#  (['hope', 'get', 'proper', 'rest', 'soon'], 0),
#  (['morning', 'twitter', 'people'], 1),
#  (['want', 'finish', 'death', 'parade', 'weekend'], 0),
#  (['physically', 'emotionally', 'mentally'], 0),
#  (["i've", 'talked', 'couple', 'times', 'seem', 'nice', 'funny'], 1),
#  (["i'm",
#    'watching',
#    "i'm",
#    'working',
#    "i'm",
#    'interested',
#    'man',
#    'city',
#    'anyway',
#    'hope',
#    'lose'],
#   0),
#  (['sheffield', 'miss', 'mych'], 0),
#  (['well', 'said', 'right', 'episode', 'fantastic', 'clap', 'clap', 'clap'],
#   1),
#  (["i'm", 'excited', 'definitely', 'meet'], 1),
#  (['could',
#    'pls',
#    'take',
#    'care',
#    'servers',
#    'befor',
#    'send',
#    'value',
#    'long',
#    "can't",
#    'get'],
#   0),
#  (['really', 'looking', 'forward', 'work', 'tonight', 'though'], 0),
#  (['yass'], 0),
#  (['honestly',
#    'blast',
#    'getting',
#    'shitfaced',
#    'chat',
#    'kind',
#    'souls',
#    'donating',
#    'tonight',
#    'singing',
#    'disney',
#    'songs'],
#   1),
#  (["i'm", 'getting', "we're", 'least', 'speaking'], 0),
#  (['turning', 'fair', 'meant', 'lot', 'people', 'came'], 1),
#  (['taxi', 'emptier', "ciara's", 'concert'], 0),
#  (['top', 'engaged', 'members', 'community', 'week'], 1),
#  (["can't", 'fry', 'chicken', 'woe', 'nigga'], 0),
#  (['excited', 'weekend', ':-)'], 1),
#  (['follow', 'follow', 'back'], 1),
#  (['anyway', ':-)'], 1),
#  (['hate', 'japanese', 'call', 'bani'], 0),
#  (['weekend', 'gonna', 'shoot', 'lovely', 'picture', 'made', 'last', 'time'],
#   1),
#  (['named'], 1),
#  (['yes',
#    'thank',
#    'damn',
#    'hella',
#    'sucks',
#    ':-(',
#    'least',
#    'really',
#    'good',
#    'time',
#    "that's",
#    'matters'],
#   0),
#  (['ate', 'whole', 'pizza', 'idk', 'feel'], 0),
#  (['take', 'back', 'dubai'], 0),
#  (["i'm",
#    'going',
#    'miss',
#    'baby',
#    'rancho',
#    'imperial',
#    'silang',
#    'subdivision'],
#   0),
#  (['aishhh', '...', 'stream', 'getting', 'slow', 'viewer', '...'], 0),
#  (['thank',
#    'sending',
#    'premium',
#    'writing',
#    'instrument',
#    'however',
#    'dastardly',
#    'swine',
#    'stole',
#    'envelope'],
#   0),
#  (['angry', 'grandpa', 'plays', 'minecraft', 'animation', 'click', 'aqui'], 1),
#  (['dog', 'pee', 'bag', ':-(', 'take'], 0),
#  (["i'd",
#    'planned',
#    'nice',
#    'scamper',
#    'slept',
#    'alarm',
#    'two',
#    'hours',
#    'suppose',
#    'needed',
#    'sleep',
#    "ain't",
#    'mad'],
#   1),
#  (['musicas'], 0),
#  (['want', 'white', 'french', 'bulldog'], 0),
#  (['know', 'dire', 'slow', 'look', 'likee', 'irl', 'could', 'minecon'], 0),
#  (['accurate', ':-('], 0),
#  (['summer', 'dragon', 'talks', 'projects', 'represents', 'slovenia'], 1),
#  (['noooooooooooooooooo', 'cannot', 'thing', ':-(', ':-('], 0),
#  (['every',
#    'night',
#    'take',
#    'hella',
#    'melatonin',
#    'every',
#    'night',
#    'take',
#    'like',
#    '2-4',
#    'hour',
#    'nap',
#    "i'm",
#    'wide',
#    'awake',
#    'next',
#    'day'],
#   0),
#  (["he's", 'always', 'gunna', 'former', 'leeds', 'manager'], 0),
#  (['nak', 'tgk', 'paper', 'townssssss', 'sigh'], 0),
#  (["i'm", 'playing', 'brain', 'dots'], 1),
#  (['like'], 1),
#  (['morning', 'lucky', 'friday', 'folks'], 1),
#  (['looking', 'fun', 'kik', 'slacke', '565'], 0),
#  (['thank', 'support'], 1),
#  (['mine'], 0),
#  (['wish',
#    'twitter',
#    'would',
#    'support',
#    'audio',
#    'recordings',
#    'would',
#    'send',
#    'yall',
#    'snippets',
#    'amazing'],
#   0),
#  ([':-(',
#    'us-iran',
#    'nuclear',
#    'deal',
#    "mit's",
#    'experts',
#    'size',
#    'deal',
#    'severely',
#    '...'],
#   0),
#  (['want', 'healthy', 'happy', 'know', "he's", 'gonna', 'make'], 0),
#  (['would', 'anyway', ':-)'], 1),
#  (['good',
#    'morning',
#    'sharon',
#    'really',
#    'hope',
#    'better',
#    'today',
#    'medicines',
#    'works',
#    'thank',
#    'ttyl'],
#   1),
#  (['sick'], 0),
#  (['happy',
#    'belated',
#    'birthday',
#    'cikaaa',
#    'wish',
#    'best',
#    'maaf',
#    'telat',
#    'ngucapinnya'],
#   1),
#  (['stats', 'day', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['stargate', 'atlantis', 'cool', 'show'], 1),
#  (['puff',
#    'pastry',
#    'egg',
#    'tarts',
#    'hot',
#    'fresh',
#    'oven',
#    'wan',
#    'chai',
#    'mtr'],
#   1),
#  (['eat', 'rest', 'well', 'tired'], 0),
#  (['reply', 'please', 'antagal'], 0),
#  (['already', 'clutching', 'shit', '...', 'foh', 'homie'], 1),
#  (['tbh', 'idk', 'ask', 'around'], 0),
#  (['cricket',
#    'world',
#    'cup',
#    'asian',
#    'cup',
#    'state',
#    'origin',
#    '...',
#    'wow',
#    'matt',
#    'lucky',
#    'boy',
#    ':-)',
#    'fun'],
#   1),
#  (['everyone', 'talking', 'rat', 'boy', 'today'], 0),
#  (['hello', 'get', 'youth', 'job', 'opportunities', 'follow'], 1),
#  (['rosidbinr', 'follback'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x18'],
#   1),
#  (['hands', 'incorrect', 'spelling', "i'm", 'apologist'], 1),
#  (['night',
#    'everybody',
#    'starts',
#    'remember',
#    'homework',
#    'due',
#    'tomorrow',
#    '...'],
#   0),
#  (['eyes', 'want', 'sleep', 'rest', 'bad'], 0),
#  (['please', 'follow'], 0),
#  (['spoile'], 1),
#  (["that's",
#    'true',
#    ':-(',
#    'trying',
#    'get',
#    'rid',
#    'katie',
#    'hopkins',
#    'avail'],
#   0),
#  (['username', 'changed'], 1),
#  ([], 1),
#  (['three',
#    'dreams',
#    'last',
#    'night',
#    'one',
#    'want',
#    'remember',
#    'two',
#    'want',
#    'remember'],
#   0),
#  (['whats', 'wrong'], 0),
#  (['miss', 'death'], 0),
#  (['make', 'smile'], 0),
#  (['yes',
#    "that's",
#    'scary',
#    'sight',
#    'seeing',
#    'frail',
#    'people',
#    'cars',
#    'lottery',
#    'riding',
#    'near',
#    'people',
#    'always',
#    'hold',
#    'breath'],
#   0),
#  (['sure',
#    'esp',
#    'ppl',
#    'talking',
#    'crap',
#    'millie',
#    '>:(',
#    "i'll",
#    'straight',
#    'page'],
#   0),
#  (['follow', 'follow', 'back'], 1),
#  (["i'm", 'craving', 'breakfast', 'food', 'badly', 'right'], 0),
#  (['guess', 'arresting', 'girlfriend'], 0),
#  (['usually', 'high', 'stool', 'three', 'kids', 'waiting', 'topple'], 1),
#  (['bad', 'boys'], 1),
#  (['excited',
#    'chalkhill',
#    'park',
#    'celebration',
#    'tomorrow',
#    'midday',
#    'come',
#    'join',
#    'fun',
#    ':-)'],
#   1),
#  (['maybe', 'ill', 'surprise', 'brill'], 0),
#  (['baby', 'worth', 'uhuh'], 1),
#  (['probs', ':-)', 'ill', 'message'], 1),
#  (['looking', 'forward', 'night', 'shift', 'tonight'], 0),
#  (['stream', 'pixelated'], 0),
#  (['...', 'shweta', 'tripathi', ':-)'], 1),
#  (['got', 'delayed', 'guests', 'sigh'], 0),
#  (['hey', 'fam', 'vote', 'already', 'gotta', 'win', 'boys'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x33'],
#   1),
#  (['want', 'flipping', 'belgium', 'waffle', 'thrown', 'face'], 0),
#  (["let's", 'got', 'facts'], 1),
#  (["let's"], 1),
#  (['maybe', 'younger', 'woman', 'stamina', 'tom'], 1),
#  (['jesus', 'loves'], 1),
#  (["i've",
#    'beer',
#    'talks',
#    "i'd",
#    'say',
#    'broken',
#    'arms',
#    'issue',
#    'testicle',
#    'light'],
#   1),
#  (['new', 'shoes', 'please'], 0),
#  (["that's", 'great', 'hear'], 1),
#  (['also',
#    'provide',
#    'pop',
#    'office',
#    "i'll",
#    'provide',
#    'required',
#    'service',
#    'smile'],
#   1),
#  (['omg',
#    'every',
#    'time',
#    'would',
#    'complain',
#    'skin',
#    'mom',
#    'everyone',
#    'gets',
#    'pimples',
#    'like',
#    'although'],
#   0),
#  (['yes',
#    'bath',
#    'bombs',
#    'back',
#    'two',
#    'great',
#    'new',
#    'products',
#    "can't",
#    'wait',
#    'order',
#    'mine',
#    'whip',
#    'bag',
#    'bombs',
#    '...'],
#   1),
#  (['everything'], 0),
#  (["here's", 'cute', 'panda', 'make', 'day'], 1),
#  (['bangalore'], 0),
#  (['guess',
#    "who's",
#    'spent',
#    'half',
#    'sitting',
#    'outside',
#    'apt',
#    'building',
#    'left',
#    'keys',
#    'work',
#    'hope',
#    'someone',
#    'needs',
#    'leave',
#    'bldg',
#    'soon'],
#   0),
#  (['like'], 0),
#  (['good', 'afternoon'], 1),
#  (['specific', 'dates', 'whenever', 'catch'], 0),
#  (['<--',
#    'face',
#    'every',
#    'guy',
#    'pull',
#    'getting',
#    'head',
#    'feel',
#    "bae's",
#    'teeth',
#    'dick'],
#   0),
#  (['one',
#    'whos',
#    'dont',
#    'see',
#    'sinse',
#    'trend',
#    'something',
#    'like',
#    'thats'],
#   0),
#  (['pleasure', 'let', 'know', "there's", 'anything', 'else', 'need'], 1),
#  (['miss', 'chris', 'voice'], 0),
#  (['makes', 'sad', 'back'], 0),
#  (['belgium'], 0),
#  (['idk', 'cant', 'wait', 'tonights', 'panel', 'people'], 1),
#  (['saran', 'drama', 'genre', 'romance', 'comedy'], 1),
#  (['rather',
#    'finding',
#    'bests',
#    'person',
#    'finding',
#    'worsts',
#    'makes',
#    'life',
#    'easy',
#    'others'],
#   1),
#  (['need', 'small', 'lady', 'walk', 'back', 'sore', '...'], 0),
#  (['greatly', 'appreciated'], 1),
#  (['easier', 'said', 'done'], 0),
#  (['everything',
#    'kids',
#    'section',
#    'ikea',
#    'cute',
#    'shame',
#    "i'm",
#    'nearly',
#    'months'],
#   0),
#  (['great', 'work', 'matt'], 1),
#  (['thanks'], 1),
#  (['yup', 'think', 'gotta', 'avoid', 'really', 'hope', 'repack'], 0),
#  (['might', ':-('], 0),
#  (['keep', 'forgetting', 'area', ':-(', 'want', 'visit', 'next', 'time'], 0),
#  (['stats', 'week', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['emotionally', 'tired'], 0),
#  (['feeling', 'well'], 0),
#  (['see', 'bot'], 1),
#  (['judgmental', 'hypocritical', 'narcissist', ':-)'], 1),
#  (['welcome', 'pop', 'heaven', "we're", 'glad', 'enjoying'], 1),
#  (['nakakapikon',
#    'yung',
#    'nagbabasa',
#    'blog',
#    'comments',
#    'info',
#    'full',
#    'people',
#    'asking',
#    'damned',
#    'questions',
#    'answered',
#    'post'],
#   0),
#  (['nixus',
#    'adventure',
#    'begun',
#    ':-)',
#    'time',
#    'make',
#    'flint',
#    'tools',
#    'haha'],
#   1),
#  (['want', 'friends', 'concerts'], 0),
#  (['lemme',
#    'know',
#    'ever',
#    'want',
#    'recs',
#    'likewise',
#    "i'm",
#    'always',
#    'open',
#    'expanding',
#    'inaccessible',
#    'music',
#    'library'],
#   1),
#  (['know',
#    'said',
#    'michael',
#    'jackson',
#    'obviously',
#    'little',
#    'boy',
#    'little',
#    'brother',
#    'listening',
#    'jackson',
#    'song'],
#   0),
#  (['goodmorning', 'smile', 'debit', 'orders', 'soon'], 1),
#  (['made', 'changes', 'design', 'hope', 'like'], 1),
#  (['one', 'constructive', 'criticism', 'welcomed'], 1),
#  (['abby', 'please', 'try', 'help', 'get', 'mum', 'come', 'see', 'london'], 0),
#  (['absolutely', 'true'], 1),
#  (['customer', 'years', 'internet', 'near', 'speed', 'slow'], 0),
#  (['pleasure', 'doll', 'thank', 'wonderful', 'energy', 'class'], 1),
#  (['jenna', ':-)', 'ask'], 1),
#  (['reunite', 'one', 'day'], 0),
#  (['summer', 'sleep', 'schedule', 'back'], 0),
#  (['thankful',
#    'someone',
#    'like',
#    'life',
#    'inspire',
#    'better',
#    'everyday',
#    'love',
#    'mind',
#    'following'],
#   1),
#  (['eunji', 'pretty'], 0),
#  (['new', 'kit', 'looking', 'good', '...', 'poor'], 0),
#  (['shoot', 'well', 'watching'], 1),
#  (['let', 'know', 'best', 'address'], 1),
#  (['tylers', 'hipster', 'glasses'], 1),
#  (['lolzz', 'unfortunately', 'dats'], 0),
#  (['someone', 'mention', 'usagi', 'loooooove'], 1),
#  (['exactly', 'mins', 'get', 'work', 'still', 'luas', 'right'], 1),
#  ([], 0),
#  (['read', 'story', 'thats', 'scary', 'hope', 'truth', 'revealed'], 0),
#  ([], 1),
#  (['watched', 'video', 'girl', 'allergic', 'sun', "that's", 'depressing'], 0),
#  (['thanks', 'guys'], 1),
#  (['browse', 'funny', 'facts', 'bored'], 1),
#  (['hahaha', '...', 'thus', '...', 'sneak', 'away', 'log'], 1),
#  (['missyou', 'bishes'], 0),
#  (['watching',
#    'baby',
#    'born',
#    'episode',
#    "can't",
#    'help',
#    'think',
#    'sweet',
#    'kind',
#    'caring',
#    'kids',
#    'keep'],
#   1),
#  (['sure', 'sorry'], 0),
#  (['wish', "could've", 'met'], 0),
#  (['awkward',
#    'moment',
#    'feel',
#    'got',
#    'abs',
#    "can't",
#    'stop',
#    'laughing',
#    'reading',
#    'tweets'],
#   1),
#  (['corbyn',
#    'must',
#    'understand',
#    "labour's",
#    'new',
#    'members',
#    'change',
#    "party's",
#    'fortunes',
#    'yet',
#    'another',
#    'rant',
#    'woman'],
#   0),
#  (['right', 'right', 'always', 'good', 'memories', 'guess'], 0),
#  (['noo', 'toni', 'deactivated'], 0),
#  (['long', 'distance'], 0),
#  ([], 1),
#  (['honey',
#    'ahead',
#    'fyi',
#    'still',
#    'dig',
#    'enjoy',
#    'voting',
#    'watch',
#    'side'],
#   1),
#  (['tio', 'know', 'must', 'follow', 'since', "i'm", 'sinaloa', 'arre'], 1),
#  (['thank'], 1),
#  (['new', 'bio', 'bodo', 'amat', ':-('], 0),
#  (['done', 'please'], 0),
#  (['thanks', 'following'], 1),
#  (['ahahah', "i'll"], 1),
#  (['lonely',
#    'moment',
#    'text',
#    'message',
#    'get',
#    'day',
#    'cell',
#    'phone',
#    'company'],
#   0),
#  (['aww', 'cuz', 'make', 'mistakes'], 1),
#  (['keeps', 'better', 'better', 'every', 'update'], 1),
#  (['snapchat', 'jillmill'], 1),
#  (['boo', 'counts', ':-('], 0),
#  (['hit', '10,000', 'plays', 'girlfriend', 'remix'], 1),
#  (['especially', 'like', "can't", 'song'], 0),
#  (['even', 'nate', 'think', 'dropped', 'places', 'already'], 0),
#  (['keep', 'inside', 'pocket', 'wripped', 'jeans'], 1),
#  (['hulk',
#    'hogan',
#    'news',
#    'racial',
#    'tirade',
#    'thought',
#    'couldnt',
#    'stoop',
#    'lower',
#    'role',
#    'thunder',
#    'paradise'],
#   0),
#  (['yeah', 'keys', 'guess', 'gave', 'mine'], 1),
#  (['first', 'attempt', 'sizing', 'unsuccessful', 'lil', 'earlobes', 'hurt'],
#   0),
#  (['cute'], 0),
#  (['ugh', "i've", 'never', 'fade', 'moaning', 'leeds', 'tweets'], 1),
#  (['cold', 'abi', 'house', 'dey', 'close', 'arctic', 'ocean', 'man', 'dying'],
#   0),
#  (['ready', 'eagerly', 'waiting', 'next', 'question', 'bring'], 1),
#  (['going', 'real'], 1),
#  (['pics', 'nash', 'coming'], 1),
#  (['please', 'leave'], 0),
#  (['massage',
#    'appointments',
#    'available',
#    'tomorrow',
#    'morning',
#    'give',
#    'call',
#    'book',
#    '01282',
#    '453',
#    '110'],
#   1),
#  (['barely', 'feel', 'boob'], 0),
#  (['home', 'alone'], 0),
#  (['top', 'supports', 'community', 'week'], 1),
#  (['schemes', 'schemes', 'planned', 'yet'], 0),
#  (['follow'], 0),
#  (['say', 'hello', 'viners', 'palembang', 'please'], 0),
#  (['done', 'thank', 'tweet'], 1),
#  (['goodluck', 'pocket', "i'm", 'moving', 'next', 'week'], 0),
#  (['follow', 'follow', 'back'], 1),
#  (['tfw',
#    'boyfriend',
#    'lol',
#    'jest',
#    'cooking',
#    'relaxes',
#    "i'm",
#    'sure',
#    "i'll",
#    'eat',
#    'lunch',
#    'tomorrow'],
#   0),
#  (['thanks', 'nice', 'finally', 'see', 'end', 'works', 'nearly', '...'], 1),
#  (['pleasure', 'kristin', 'enjoy', 'flight'], 1),
#  (['become', 'better', 'atrack', 'better'], 1),
#  (['gutted', 'one', 'people', 'able', 'finally', 'meet'], 0),
#  (["i'm", 'appreciating', 'body', 'feeding', 'needs', ':-)'], 1),
#  (['already', 'sold', 'like', 'weeks', 'ago'], 0),
#  (['ate'], 1),
#  (['hell', 'miss', 'idol'], 0),
#  (['visit',
#    'cultural',
#    'experience',
#    'try',
#    'whale',
#    'watching',
#    'aquatic',
#    'either',
#    'great'],
#   1),
#  (['heart', 'hurts', 'real', 'bad'], 0),
#  (['sent', 'try', 'make', 'sure', 'catch', ':-)'], 1),
#  (['tomorrow'], 0),
#  (['congratulations',
#    'winner',
#    'contest',
#    'please',
#    'address',
#    'contact',
#    'number'],
#   1),
#  (['could', 'please', 'info', "we'd", 'happy', 'help'], 1),
#  (['chillin', 'salmon'], 1),
#  (['smile', 'makes', 'smile'], 1),
#  (['airport'], 0),
#  (['love',
#    'much',
#    'beli̇eve',
#    'wi̇ll',
#    'follow',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15',
#    '335',
#    'ｓｅｅ'],
#   0),
#  (["i'm",
#    'gonna',
#    'get',
#    'high',
#    'blood',
#    'pressure',
#    'one',
#    'day',
#    'lol',
#    "i'm",
#    'eating',
#    'much',
#    'unhealthy',
#    'food'],
#   0),
#  (['snapchat', 'jennyjean'], 1),
#  (['could', 'anyone', 'resist', 'beautiful', 'smile', ':-)'], 1),
#  (['since',
#    'models',
#    'stopped',
#    'stocking',
#    'boots',
#    "can't",
#    'get',
#    "can't",
#    'even',
#    'order',
#    'online',
#    'telling',
#    'unsafe'],
#   0),
#  (['lamo',
#    'first',
#    'fangirl',
#    'hard',
#    "i'd",
#    'love',
#    'share',
#    'platonic',
#    'pics',
#    'know',
#    'science'],
#   1),
#  (['hope',
#    'one',
#    'day',
#    "he'll",
#    'fall',
#    'love',
#    'strong',
#    'woman',
#    'let',
#    'see',
#    'things',
#    'refuses',
#    'see'],
#   1),
#  (["let's", 'play'], 1),
#  (['thanks', 'trade'], 1),
#  (['miss', 'macho', 'man'], 0),
#  (["i'm", 'going', 'insane', 'wrong', 'account', 'away', 'open', 'account'],
#   0),
#  (['texted', 'dying', 'lurgy', 'jim'], 0),
#  (['one',
#    'little',
#    '50p',
#    'cheese',
#    'pizzas',
#    'grated',
#    'cheese',
#    'top',
#    'well',
#    'one',
#    'looking',
#    'little',
#    'sparse'],
#   0),
#  (['finished',
#    'bill',
#    "ted's",
#    'excellent',
#    'adventure',
#    'onto',
#    'bogus',
#    'journey'],
#   1),
#  (['wut', 'hell', "can't", 'sleep', '>:('], 0),
#  (['back', 'life'], 0),
#  (['deactivated'], 0),
#  (['followed', 'thanks', 'please', 'followed'], 0),
#  (['hate', 'late', 'wake', 'early', 'end', 'wasting', 'day'], 0),
#  (["i'm", 'really', 'excited', 'picnic', 'tmrw', ':-)'], 1),
#  (['dream'], 1),
#  (['craving', 'mcnuggets', ':-('], 0),
#  (['want', "alex's", 'house'], 0),
#  (['jaysus'], 0),
#  (['aztec', 'princess'], 1),
#  (['early'], 0),
#  (['jane', 'said', "i'm", 'welcome'], 0),
#  (['hello', 'playing', 'yello', 'race'], 1),
#  (['right', 'thx', 'andrew', 'great', 'day'], 1),
#  (['thank', 'beatriz'], 1),
#  (['dead'], 1),
#  (['look'], 1),
#  (['two', 'days', "i'm", 'buried', 'emails', '...'], 0),
#  (['wish', 'pleasant', 'time', 'on-board', 'raheel'], 1),
#  (['2015', 'still', 'linux', 'support', ':-('], 0),
#  (['reign', 'errors', 'example', 'inflation', 'rate', 'sic'], 0),
#  (['fuck', 'neil', 'ruined', '>:-('], 0),
#  (['hey',
#    'guys',
#    "i'll",
#    'live',
#    'mins',
#    'want',
#    'fun',
#    'low',
#    'ranked',
#    'games',
#    'subgames',
#    'faceit',
#    'today',
#    '...'],
#   1),
#  (['irene',
#    'unnie',
#    'bite',
#    'fingers',
#    'worriedly',
#    'stared',
#    'staff',
#    'okay',
#    'unnie'],
#   0),
#  (['want', 'wingstop', ':-('], 0),
#  (['ingat', 'din', 'man', 'godbless'], 1),
#  (['much', 'awaited', 'excitement', 'going', 'boring', 'friday', 'weekend'],
#   0),
#  (["i'm", 'stefanie', '...', 'real', 'one'], 1),
#  (['snow',
#    'cold',
#    'gross',
#    'big',
#    'mess',
#    'everyone',
#    'scrapes',
#    'piles',
#    'anyway'],
#   0),
#  (['recently', 'upgrades', 'might', 'see', 'new', 'picture', 'soon.thanks'],
#   1),
#  (['new',
#    'sandra',
#    'bland',
#    'footage',
#    'really',
#    'icing',
#    'cake',
#    'heartbreaking',
#    'dragged',
#    'lifeless',
#    'body',
#    'police',
#    'car'],
#   0),
#  (['join',
#    'see',
#    'make',
#    'every',
#    'wed',
#    'thurs',
#    'fri',
#    'july',
#    'aug',
#    'excl',
#    'aug',
#    'free',
#    'crafts',
#    "we'll",
#    'tidying'],
#   1),
#  (['whens', 'cat', 'coming'], 0),
#  (['start', 'loving', 'someone', 'hard', 'stop', 'bebeeeee'], 0),
#  (['nice', 'tweet', 'followed'], 1),
#  (['well', 'hurt', 'visit', 'doctor'], 0),
#  (['last', 'night', 'flipping', 'great', 'fun', 'learnt', 'backflip'], 1),
#  (['gonna', 'sarajevo', 'live', 'like', 'hours'], 0),
#  (['wishing', 'happy', 'friday', 'xxx'], 1),
#  (['love', 'much'], 0),
#  (['servus',
#    'alice',
#    'bonasio',
#    'happy',
#    "doido's",
#    'family',
#    'tell',
#    'task',
#    'want',
#    'delegate',
#    'today'],
#   1),
#  (['likewise', 'incredible', 'food', 'folks', 'keep', 'great', 'work'], 1),
#  ([], 0),
#  (['hope', 'goes', 'well', ':-)'], 1),
#  (['mashaket'], 0),
#  (['unless', 'one', 'students', 'light', 'reading'], 1),
#  (['talked', 'months'], 1),
#  (['get', 'follow', 'link', 'find', 'code', 'enjoy', 'tom'], 1),
#  (['oops'], 0),
#  (['thank'], 1),
#  (['wish', 'could', 'meet', 'boys', 'one', 'day'], 0),
#  (['jumma', 'kareem', 'friday', 'reminder', 'recite', 'surah', 'kahaf'], 1),
#  (['like',
#    '...',
#    'put',
#    'one',
#    'side',
#    '...',
#    'tell',
#    'staff',
#    '...',
#    'still',
#    'like',
#    'slotted',
#    'make',
#    'look',
#    'untouched'],
#   0),
#  (['anyone',
#    'pic',
#    "taeyeon's",
#    'derp',
#    'channel',
#    'snsd',
#    'hahahaha',
#    'zoom',
#    'lmao',
#    "sunny's",
#    'besst'],
#   0),
#  (['jazmin',
#    'bonilla',
#    'share',
#    'latest',
#    'secret',
#    '15000',
#    'stars',
#    'kim',
#    'hollywood',
#    'check',
#    'secret',
#    'bio'],
#   1),
#  (["i'm", 'bright', 'man'], 0),
#  (['thank', 'screenshots', 'let', 'take', 'care', 'spammer', 'proceed', '...'],
#   1),
#  (['end', 'state', 'last', 'night'], 0),
#  (['yess', 'dont', 'original', 'pic'], 0),
#  (['see',
#    'meet',
#    'greet',
#    'tour',
#    'coming',
#    'unfortunately',
#    'coming',
#    'brisbane'],
#   0),
#  (['dont', 'sad', 'ily'], 0),
#  (['agreed', 'suspicious', 'minds'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x25'],
#   1),
#  (['hope', "u'll", 'njoy', 'followingg'], 1),
#  (['listening',
#    'back',
#    'old',
#    'shows',
#    'know',
#    "i'm",
#    'weird',
#    'got',
#    'leaving',
#    'might',
#    'give',
#    'pale',
#    'imitation',
#    ':-('],
#   0),
#  (['mince'], 0),
#  (['yeah', 'try', 'looking'], 1),
#  (['two',
#    'comes',
#    'one',
#    'lessons',
#    'learn',
#    'make',
#    'realize',
#    'tough',
#    'life',
#    'get',
#    'nothing',
#    'lasts',
#    'forever',
#    'thing',
#    'ever',
#    'lasts'],
#   1),
#  (['forgot', 'like', 'people', "i'm", 'sorry'], 0),
#  (['yeey'], 1),
#  (['thanks', 'retweets', 'cool', 'weekend'], 1),
#  (['haha', 'thank'], 1),
#  (['today',
#    'job',
#    'another',
#    'facking',
#    'extra',
#    'mega',
#    'careful',
#    'get',
#    'bent',
#    'socket',
#    'pins',
#    ':-('],
#   0),
#  (['nice', 'one'], 1),
#  (['sad', "we're", 'losers'], 0),
#  (['celebrate',
#    'end',
#    'work',
#    'week',
#    'invite',
#    'friends',
#    'dine',
#    'experience',
#    'modern',
#    'korean',
#    'house'],
#   1),
#  (['yes',
#    'means',
#    "we're",
#    'stuck',
#    'striker',
#    'unless',
#    'lvg',
#    'plays',
#    'behind',
#    'one'],
#   0),
#  (['done'], 1),
#  (['pay', 'day', 'make', 'less', 'poor'], 0),
#  (["what's", 'snapchat'], 1),
#  (['great', 'weekend'], 1),
#  (['thanks',
#    'feedback',
#    'thinking',
#    'perhaps',
#    'mobitel',
#    'may',
#    'better',
#    'heck',
#    'guess'],
#   0),
#  (['mixture', 'proud', 'far', "they've", 'come', 'also', 'missing', 'days'],
#   0),
#  (['asked', 'first', 'pfb'], 0),
#  (['worried', ':-('], 0),
#  (['take', 'head', 'stopped'], 1),
#  (['well',
#    'travel',
#    'around',
#    'new',
#    'zealand',
#    'holidays',
#    'hopefully',
#    'could',
#    'meet'],
#   1),
#  (['imy'], 0),
#  (['thank'], 1),
#  (['love', 'matter'], 1),
#  (['fantastic', 'night'], 1),
#  (['one', 'sleep', 'til', 'wedding', ':-)'], 1),
#  (['team',
#    'hoping',
#    'find',
#    'beatport',
#    'collection',
#    'via',
#    'spotify',
#    'soon'],
#   1),
#  (['building', 'suite'], 0),
#  (['cheers'], 1),
#  (['great', 'roadtrip', 'wwat'], 1),
#  (['welcome'], 1),
#  (['make', 'tea', 'load', 'shedding', 'like', 'bheyps', 'ayemso', 'hacked'],
#   0),
#  (['moving', 'day'], 0),
#  (["that's", 'thinking', 'tbh'], 0),
#  (['mirror', 'selfie'], 1),
#  (['hello', 'get', 'youth', 'job', 'opportunities', 'follow'], 1),
#  (['chicks'], 1),
#  (['mark', 'followback'], 0),
#  (['know', 'find', 'balance'], 0),
#  (['get', 'sick'], 0),
#  (['many', 'many', 'congratulations', 'papa'], 1),
#  (["can't", 'see', 'difference', 'black', 'red', 'ink', '...'], 0),
#  (['fingers', 'crossed'], 1),
#  (['enjoy', 'short', 'hilly', 'cycle', 'last', 'day', 'england', 'trip'], 1),
#  (['6248108', '80khan', 'confidence', 'confined', 'limits', '...'], 1),
#  (['sunday',
#    'little',
#    'able',
#    'get',
#    'much',
#    'year',
#    'busy',
#    'looked',
#    'great',
#    'tho'],
#   0),
#  (["i'm", 'inactive'], 0),
#  (['thought',
#    'icepack',
#    'big',
#    'doses',
#    'pain',
#    'killers',
#    'board',
#    'feeling',
#    'painful',
#    'already',
#    'whimpers'],
#   0),
#  (['may', 'deploying', 'degree', 'sarcasm'], 1),
#  (['looking', 'fun', 'kik', 'goictived', '70685'], 1),
#  (['thanks',
#    'following',
#    'get',
#    'touch',
#    'like',
#    'info',
#    'project',
#    'youth@bipolaruk.org.uk'],
#   1),
#  (['5am', "i'm", 'wit', 'damn', 'headache'], 0),
#  (['404', 'found'], 0),
#  (['tell', 'whitey', 'culture', 'rules', 'world'], 1),
#  (['know', 'monica', 'miss', 'yeah', 'sounds', 'good'], 1),
#  (['sadly'], 0),
#  (["let's", 'take', 'look', 'please', 'chat'], 0),
#  (['ghost'], 1),
#  (['luv', 'urs', ':-)'], 1),
#  (['thank', 'much'], 1),
#  (['thanks'], 1),
#  (['add', 'snapchat', 'nicoleapage'], 0),
#  (['fault', 'sweedy'], 0),
#  (['bakit', 'facebook'], 0),
#  (['cont',
#    'line',
#    'online',
#    'reply',
#    'mention',
#    'watching',
#    'sorry',
#    'late',
#    'reply'],
#   0),
#  (['literally', 'crying', 'right'], 0),
#  (['sad'], 0),
#  (['theres', 'hours', 'till', 'prob', 'gonna', 'fall', 'asleep'], 1),
#  (['fish', 'dying', 'feel', 'like', 'crying'], 0),
#  (['used', 'flexible'], 0),
#  (['nope', 'hueeeee'], 0),
#  (['kinda',
#    'smug',
#    'know',
#    'stuff',
#    'marrickville',
#    'public',
#    'ten',
#    'years',
#    'ago',
#    ':-)'],
#   1),
#  (['want', 'chicken', 'nuggets'], 0),
#  (['still', 'green', 'tea', 'blends', 'flavors'], 1),
#  (['crazyyyy',
#    'thooo',
#    'airport',
#    'straight',
#    'away',
#    'soundcheck',
#    'concert'],
#   0),
#  (['...', 'rakyat', 'keep', 'visiting', 'blog', 'reading', 'writing'], 1),
#  (['make', 'way', 'days', 'share', 'version', 'beautiful'], 1),
#  (['unfollow'], 0),
#  (['add'], 1),
#  (['saw',
#    'follow',
#    'thought',
#    'might',
#    'like',
#    'dark',
#    'plz',
#    'let',
#    'know',
#    'think'],
#   1),
#  (['going', 'america', 'man', 'victims'], 0),
#  (['thanks', 'wish'], 1),
#  (['know',
#    'gave',
#    'white',
#    'dress',
#    'small',
#    'polka',
#    'dots',
#    'away',
#    'sigh',
#    'ndi',
#    'hacked'],
#   0),
#  (['thank'], 1),
#  (['sorry', 'sorry'], 0),
#  (['looking', 'beautiful', 'amazing', 'body', 'ooze', 'sex', 'appeal'], 1),
#  (['looks', 'like', 'customers', 'must', 'regular', 'readers', 'good', 'luck'],
#   1),
#  (['hate', 'see', 'sad'], 0),
#  (['gotta', 'like', 'crapple', 'agrees', 'android', 'ftw'], 0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x41'],
#   1),
#  (['apology', 'available', 'australia'], 0),
#  (['always', 'end', 'breaking', 'apologizing', 'fuck', 'nice', ':-)'], 1),
#  (["i'm",
#    'still',
#    'awake',
#    'feeling',
#    'like',
#    'need',
#    'delete',
#    'people',
#    'snap'],
#   0),
#  (['hey', 'buddy', 'thinking', 'anything'], 1),
#  (['great', 'hear', 'nice', 'day', 'thanks', 'visiting'], 1),
#  (['everyone', 'love', ':-)'], 1),
#  (['please', 'tell', 'everyone', 'didnt', 'vidcon'], 0),
#  (['still', 'work'], 0),
#  (['nightly', 'routine', 'simpin', ':-)'], 1),
#  (['gi-guilty', 'akooooooooooooooo', ":'(", 'mistake'], 0),
#  (["that's",
#    'laiten',
#    "that's",
#    'interesting',
#    'would',
#    'able',
#    'tell',
#    'card',
#    'looks',
#    'like',
#    '...'],
#   1),
#  (['followback', 'beautiful', 'girl', 'today'], 1),
#  (['happy',
#    'birthday',
#    'bes',
#    'enjoy',
#    'day',
#    'beb',
#    'love',
#    'miss',
#    'sooooo',
#    'muchie',
#    'see',
#    'soon',
#    'sana'],
#   0),
#  (['look',
#    'many',
#    'people',
#    'still',
#    'think',
#    'woman',
#    'sex',
#    'bigger',
#    'vagina',
#    'sigh'],
#   0),
#  (['hope', 'find', 'new', 'homes'], 0),
#  (['jumma', 'mubarak', 'stay', 'blessed'], 1),
#  (['trying',
#    'think',
#    'returning',
#    'spain',
#    'leaving',
#    'eldest',
#    'behind',
#    'already',
#    'one',
#    'cry'],
#   0),
#  (['feet', 'cold', 'point', 'taking', 'socks', 'okay', 'stop'], 0),
#  (['started', 'using', 'mine', 'weeks', 'ago', 'long', 'break'], 1),
#  (['havent', 'tweeting', 'years', 'kinda', 'miss'], 1),
#  (["can't", 'wait'], 0),
#  (['regret', 'getting', 'starbucks', 'want', 'sleep', "can't", '...'], 0),
#  (['funny',
#    'use',
#    'kuffar',
#    'computers',
#    'cell',
#    'phones',
#    'social',
#    'media',
#    'spread',
#    'diarrhea',
#    'though',
#    'immigrant',
#    'lice'],
#   1),
#  (['dipsatch'], 1),
#  (['thanks',
#    'following',
#    'need',
#    'anything',
#    'printed',
#    'personalised',
#    'gift',
#    'wrap',
#    'business',
#    'cards',
#    'stationery',
#    'get',
#    'touch'],
#   1),
#  (['really', 'missing', 'family', 'friends', 'bae', 'poopie'], 0),
#  (['must', 'video', 'stop', 'tho'], 0),
#  (['thank', 'coming', 'ladies', 'lovely', 'see', 'know', 'either'], 1),
#  (['welcome'], 1),
#  (['happen', 'weather', 'sensor', 'broker', 'weeks'], 0),
#  (['nawwwe',
#    'hang',
#    'love',
#    'yes',
#    'yes',
#    'chikka',
#    'kita',
#    'rata',
#    'soonest',
#    'mwamwa'],
#   0),
#  (['finding', 'old', 'pictures', 'long', 'hair', 'makes', 'sad'], 0),
#  (['ocean',
#    'without',
#    'water',
#    'vehicles',
#    'without',
#    'petrol',
#    'diesel',
#    'empty',
#    'wardrobe'],
#   0),
#  (['man', 'get', 'better', 'soon'], 0),
#  (['happy', 'burfday'], 1),
#  (['idaho',
#    'restrict',
#    'fishing',
#    'despite',
#    'regional',
#    'drought-linked',
#    'die-of',
#    '...',
#    ':-('],
#   0),
#  (['millz', 'askies', 'come', 'back', 'awusasho', ":'("], 0),
#  (['snapchat', 'shoshannavassil'], 1),
#  (['okay'], 1),
#  (['good', 'lucky', 'care'], 1),
#  (['makes',
#    'want',
#    'watch',
#    'whole',
#    'film',
#    'cgi',
#    'kicks',
#    'oops',
#    'pun',
#    'start',
#    'grumbling',
#    'turn'],
#   0),
#  (['okayy'], 1),
#  (['awh', 'good', 'hated', 'though', 'haha'], 1),
#  (['always', 'forget', 'tag', 'ppl'], 1),
#  (['know',
#    'average',
#    'takes',
#    'seconds',
#    'read',
#    'god',
#    'dam',
#    'mother',
#    'fucking',
#    'tweet'],
#   1),
#  (['get', 'well', 'soon', 'dan', 'big', 'hugs'], 1),
#  (['lovely',
#    'write',
#    'absolutely',
#    'adore',
#    'nva',
#    'lucky',
#    'enough',
#    'live',
#    'minuets',
#    'away',
#    'roll',
#    'gamecity'],
#   1),
#  (['month', 'tomorrow', 'since', 'luke', 'followed'], 0),
#  (['could', 'flat', 'abs', 'time', '...', 'gym', 'tayo'], 0),
#  (['sigh', 'bruhhh', 'call', 'daddy', 'one', 'time'], 1),
#  (['earth'], 1),
#  (['miss', 'days'], 0),
#  (['going', 'die', "i'm", 'sorry'], 0),
#  (['know',
#    'play',
#    'one',
#    'last',
#    'time',
#    'need',
#    'one',
#    'takes',
#    'home',
#    'piano',
#    'cant',
#    'rest',
#    'fml'],
#   0),
#  (["i'm", 'gonna', 'dead', 'tomorrow'], 0),
#  (['good', 'reasons', 'hope'], 1),
#  (['want', 'justin', 'let', 'know', "i'll", 'gladly', 'give'], 1),
#  (['well',
#    'kind',
#    'still',
#    'read',
#    'author',
#    'favorite',
#    'otherwise',
#    'tend',
#    'read',
#    "that's",
#    'crave',
#    'fics'],
#   1),
#  (['stats', 'day', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['time', 'twelvyy', 'got', 'rude'], 0),
#  (['worth', 'fifth', 'harmony', 'judge'], 1),
#  ([':-(', 'hope', 'works', '...', 'better', 'way'], 0),
#  (['still',
#    'tomorrow',
#    'work',
#    'colleague',
#    'interested',
#    'bringing',
#    'kid',
#    'along',
#    'point',
#    'page'],
#   1),
#  (['long', 'time', 'see'], 1),
#  (['photoset',
#    'katmtan',
#    'swan',
#    'queen',
#    'fandom',
#    'sorry',
#    'others',
#    'blurry',
#    'far',
#    'away',
#    '...'],
#   1),
#  (['walkin', 'around'], 1),
#  (['thanks', 'wishing', 'back', 'also'], 1),
#  (['could', 'get', 'black', '510', 'blue', 'silicon', 'cover'], 0),
#  (['unfortunately',
#    "i'm",
#    'sorry',
#    'say',
#    'thrilled',
#    'hear',
#    'love',
#    'sound',
#    'products',
#    'smell',
#    'amazing'],
#   1),
#  (['hahaha', 'okay', 'thank'], 1),
#  (['want',
#    'harry',
#    'wanna',
#    'give',
#    'surprise',
#    'friend',
#    'birthday',
#    'wanna',
#    'make',
#    'happy'],
#   1),
#  (['exclusive',
#    'germany',
#    'unfair',
#    'esp',
#    'regarding',
#    'current',
#    'bleak',
#    'german',
#    'charts',
#    'situation',
#    'still',
#    'entry',
#    'even',
#    'top',
#    '100',
#    'pfft'],
#   0),
#  (["i'm", 'working', 'next', 'saturday', 'well', 'gutted', 'wanted', 'pride'],
#   0),
#  (['haha', 'hope', 'got', 'work', 'tho', 'bout', 'quit'], 1),
#  (['beautiful'], 1),
#  (['miss', 'hahaha'], 0),
#  (['ahhhhh', 'last', 'stages'], 0),
#  (['smart', 'real', 'life', 'act', 'smart', 'webz', ':-)'], 1),
#  (['congrats', 'exciting'], 1),
#  (['wacky'], 1),
#  (['someone', 'txt'], 0),
#  (["i'm", 'inactive', 'wanna', 'cry'], 0),
#  (['followed', 'thanks', 'please', 'followed'], 0),
#  (['alex',
#    'heswifi',
#    'want',
#    'get',
#    'free',
#    'iphone',
#    'hurry',
#    'check',
#    'bi0',
#    'thx'],
#   1),
#  (['glad', 'lasted', 'one', 'day'], 1),
#  (['emu', 'stoked', 'thank'], 1),
#  (['great',
#    'got',
#    'php',
#    'mysql',
#    'libmysqlclient-dev',
#    'sync',
#    'broke',
#    'dev',
#    'server'],
#   0),
#  (['hopehousekids', 'pitmantraining', 'walkersmithway', "let's", 'try'], 1),
#  (['thank', 'glad', 'enjoyed', ':-)'], 1),
#  (['okay', 'thank'], 1),
#  (["that's", 'soph', 'positive', 'thoughts', ':-)'], 1),
#  (['sighs',
#    'dont',
#    'stupid',
#    'head',
#    'needed',
#    'urgently',
#    '...',
#    'pls',
#    'apply',
#    'within',
#    ':-)'],
#   1),
#  (['coconut', 'sambal', 'mussels', 'recipe', ':-)'], 1),
#  (['sweet', 'tooth'], 1),
#  (['make', 'hurry', '...', 'melting', 'taking', 'quick', 'store', 'run'], 0),
#  (['hope', 'feel', 'better'], 0),
#  (['nice', 'talking', 'someone', 'using'], 1),
#  (['follow', 'follow', 'back'], 1),
#  (['relate',
#    'sweet',
#    'sour',
#    'kind',
#    'bi-polar',
#    'people',
#    'life',
#    '...',
#    'cuz',
#    'life',
#    '...',
#    'full',
#    '...'],
#   0),
#  (['hello',
#    'info',
#    'possible',
#    'interest',
#    'jonathas',
#    'close',
#    'join',
#    'betis'],
#   0),
#  (['hate', 'see', '9:15'], 0),
#  (['sorry', "i'm", 'fully', 'booked', ':-('], 0),
#  (['bale'], 0),
#  (['give', 'minute', "i'll", 'take', 'look'], 1),
#  (['stats', 'week', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (["i'm",
#    'used',
#    'foot',
#    'injurys',
#    'lol',
#    'appendix',
#    'burst',
#    'ago',
#    'appendicitis',
#    'told',
#    'hernia'],
#   0),
#  (['cute'], 0),
#  (['delete'], 0),
#  (["i've",
#    'wanting',
#    'change',
#    'woohyun',
#    'one',
#    'sunggyu',
#    'makes',
#    'feel',
#    'guilty'],
#   0),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x46'],
#   1),
#  (['many',
#    'people',
#    'dying',
#    'returning',
#    'dhaka',
#    'celebrating',
#    'eid',
#    'guess',
#    'traffic',
#    'jam',
#    'fact',
#    '...'],
#   0),
#  (['hey', 'survived', 'train'], 1),
#  (['thanks'], 1),
#  (['stashed',
#    'closer-chasing',
#    'specs',
#    'league',
#    'chasing',
#    'saves',
#    '...',
#    'yes',
#    '...',
#    'walls',
#    'ears',
#    ':-)'],
#   1),
#  (['encouraged', 'employer', 'board', 'stuck', 'poster'], 1),
#  (['travel', 'style', ':-)'], 1),
#  (['want', 'myungsoo', 'gyu', 'hoya', 'yeol'], 0),
#  (['thx', 'android', 'support', 'xmas'], 1),
#  (["i'm", 'liking'], 1),
#  (['guys', 'ganas', 'face'], 0),
#  (['sorted', 'santorini', 'come'], 1),
#  (['बार',
#    'फिर',
#    'सेँ',
#    'धोखा',
#    '...',
#    '>:(',
#    'feeling',
#    'silly',
#    'chandauli',
#    'majhwar',
#    'railway',
#    'station'],
#   0),
#  (["panic's", 'new', 'album', 'come', '22nd'], 0),
#  (['...'], 1),
#  (['rage', 'quit'], 0),
#  (["can't", 'sleep', 'work', '1/2', 'hours'], 0),
#  (['cool', 'worked', 'cheers'], 1),
#  (['bff'], 1),
#  (['wow', 'thanks', 'glad', 'noticed'], 1),
#  (['thanks'], 1),
#  (["i'm", 'annoyed'], 0),
#  (['controversy'], 0),
#  (['need', 'manually', 'tweak', 'php', 'yeah'], 1),
#  (['glad', 'sonal', 'instagram', "what's"], 1),
#  (['poor', 'little', 'thing', 'cutie'], 1),
#  (['happy',
#    'princess',
#    'today',
#    'sighs',
#    'get',
#    'work',
#    'done',
#    'purple',
#    'princess',
#    'edits'],
#   0),
#  (['eff', 'like'], 1),
#  (['morning',
#    '...',
#    'judith',
#    'answer',
#    'district',
#    'council',
#    'related',
#    'questions',
#    'today',
#    ':-)'],
#   1),
#  (['really', 'feel', 'like', 'reading', ':-)'], 1),
#  (['check', 'ride', 'android', 'try', 'free', 'new', 'one'], 1),
#  ([], 0),
#  (['sure',
#    'would',
#    'good',
#    'thing',
#    'bottom',
#    'daring',
#    'say',
#    'miss',
#    'gonna',
#    'stubborn',
#    'mouth',
#    'soaping'],
#   1),
#  (['miss'], 0),
#  (['thankssss'], 0),
#  (['hope', 'good', 'day'], 1),
#  (['trending', 'follow', 'bobble', 'link'], 1),
#  (['yeap'], 1),
#  (['vidcon'], 0),
#  (['isco'], 0),
#  (['joking', 'headline', 'friends', 'pls', "dn't", 'brk', 'heart', ":'("], 0),
#  (['thank',
#    'always',
#    'putting',
#    'smile',
#    'face',
#    'mind',
#    'following',
#    'nice',
#    'day',
#    '1708'],
#   1),
#  (['instore', 'card', 'expired', 'june', 'havent', 'sent', 'new', 'one'], 0),
#  (['drew', 'pls'], 1),
#  (['get',
#    'second',
#    'quote',
#    'tweet',
#    'maybe',
#    'could',
#    'please',
#    'louis',
#    'please'],
#   1),
#  (['lesley'], 1),
#  (['wishing', 'colorado'], 1),
#  (['tried', 'sadly', 'code', 'attached', 'try', 'sign'], 0),
#  (['poorly', 'bed', 'netflix', 'today'], 0),
#  (["that's",
#    'excuse',
#    'launching',
#    'attack',
#    'lizardz',
#    'feel',
#    'like',
#    'shit',
#    'deeply',
#    'ashamed',
#    '>:('],
#   0),
#  (['wish',
#    'could',
#    'come',
#    'see',
#    'disability',
#    'pension',
#    'ptsd',
#    'makes',
#    'impossible',
#    'physically',
#    'financially'],
#   0),
#  (['collection'], 1),
#  (['followed', 'thanks', 'please', 'followed'], 0),
#  (['patty', ':-)'], 1),
#  (['bum', 'zara', 'trousers'], 0),
#  (['happened', 'gyu', ':-('], 0),
#  (['call', 'effect'], 1),
#  (['height', 'in-sensitiveness', '...', 'ridiculous', '...'], 0),
#  (['head', 'killing'], 0),
#  (['malese'], 1),
#  (['allergic', 'cats', '...', 'itchy', 'throat'], 0),
#  (['care', 'makes', 'diff'], 0),
#  (['tack'], 1),
#  (['great', 'marketing', 'campaign', 'shame', 'drivers', 'busy'], 0),
#  (['schools', 'shit'], 0),
#  (['ever', 'areal', "we'll", 'lunch', 'dinner'], 1),
#  (['rain', 'though'], 0),
#  (['interested',
#    'internship',
#    'program',
#    'sadly',
#    'cant',
#    'access',
#    'career',
#    'page',
#    'help',
#    'issue'],
#   1),
#  (['omg', 'whay', 'dis'], 0),
#  (['pretty', 'amazing', 'hell', 'yeah', 'playing', 'video', 'games'], 1),
#  (['isco', 'close'], 0),
#  (['first',
#    'day',
#    'sch',
#    'miss',
#    'sharing',
#    'class',
#    'jeslyn',
#    'already',
#    ':-('],
#   0),
#  (['getting',
#    'sick',
#    'tired',
#    'pipol',
#    'saying',
#    'short',
#    '...',
#    'short',
#    '...',
#    'tiny'],
#   0),
#  (["i've", 'always', 'wanted', 'see', 'two', 'door', 'cinema', 'club', 'live'],
#   0),
#  (['going', 'follow', 'nah', 'waitting'], 0),
#  (['even', 'know', 'still', 'existed', 'haha', 'text', '626-430-8715'], 0),
#  (['thanks', 'yots', 'labyo', 'miss'], 0),
#  (['cotton', 'candy', 'favourite', 'time', 'stock'], 0),
#  (['nothing', 'like', 'little', 'team', 'photo', 'thursday', 'smiles', 'even'],
#   1),
#  (['alright'], 0),
#  (['supposed', 'august'], 0),
#  (['science', 'students', 'side', 'please'], 1),
#  (['listening',
#    'rick',
#    'ross',
#    'feeling',
#    'like',
#    'balling',
#    'knowing',
#    'damn',
#    'well',
#    'wallet',
#    'hella',
#    'empty'],
#   0),
#  (['neither', 'looked', 'rain', 'app'], 1),
#  (['followed', 'thanks', 'please', 'followed'], 0),
#  (['glad', 'like'], 1),
#  (["i'm", 'sure', 'worth', 'wait', 'exciting', ':-)'], 1),
#  (['need', 'relax', ':-(', '...'], 0),
#  (['بندر',
#    'العنزي',
#    'heiyo',
#    'visit',
#    'website',
#    'free',
#    '50.000',
#    'coins',
#    'ball',
#    'pool',
#    'thanks'],
#   1),
#  (['bored', 'acads', 'scheduled', 'nowwww'], 0),
#  (['beautiful',
#    'got',
#    'blackfly',
#    'courgette',
#    'flowers',
#    'year',
#    'ideas',
#    'hopefully',
#    'wont',
#    'affect',
#    'fruit'],
#   1),
#  (['also', "tonight's", 'show'], 1),
#  (['skin', 'thinks', 'still', 'decides', 'break', ':-)', 'cool'], 1),
#  (['wow', 'roux', 'tweeted', 'sweet'], 1),
#  (['play',
#    'bahay',
#    'bahayan',
#    'kid',
#    'yes',
#    '...',
#    'yes',
#    'pero',
#    'magisa',
#    'lang'],
#   0),
#  (['sobs',
#    "that's",
#    'really',
#    'sweet',
#    "i'll",
#    'busier',
#    'next',
#    'week',
#    'onwards',
#    'idk',
#    "i'll",
#    'find',
#    'time',
#    'anymore'],
#   0),
#  (['thank', '...', 'loved', 'cakes', 'bear', 'hug', 'end'], 1),
#  (["that's", 'disgusting', 'glad', 'acc', 'back', 'hope', 'get', 'deserve'],
#   1),
#  (['everytime',
#    'look',
#    'clock',
#    '3:02',
#    'something',
#    'weird',
#    'happens',
#    'finished',
#    'coughing',
#    'blood',
#    'started',
#    '3:02',
#    'nice'],
#   1),
#  (['work', 'today', 'better', 'tomorrow'], 1),
#  (['enter',
#    'purchase',
#    'specially-marked',
#    'first',
#    'choice',
#    'custard',
#    'pack',
#    'enter',
#    'via',
#    'sms',
#    'on-pack',
#    'instructions',
#    'good',
#    'luck'],
#   1),
#  (['sad', 'today', 'girls', 'day', 'goodbye', 'stage'], 0),
#  (['stats', 'day', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['least',
#    'green',
#    'fingers',
#    'ever',
#    'even',
#    'keep',
#    'basil',
#    'plant',
#    'alive'],
#   0),
#  (['good', 'night'], 1),
#  (['nope', 'himachal'], 1),
#  (['thank', 'much', 'sharing', 'delighted', 'enjoyed', 'day', ':-)'], 1),
#  (['look', 'made', 'final', 'design', 'hope', 'like'], 1),
#  (['sighs', 'dreamily', 'pout', 'come', 'bath', 'eyes', ':-)'], 1),
#  (["m's", 'voice', 'lord', 'help'], 0),
#  (['problem', 'rhys', 'good', 'day'], 1),
#  (['planning',
#    'send',
#    'email',
#    "chippy's",
#    'vessel',
#    'monday',
#    'happy',
#    'anniversary',
#    'haha'],
#   1),
#  (['kat', 'office', 'client'], 0),
#  (['wanna',
#    'dancer',
#    'wanna',
#    'choregrapher',
#    'cant',
#    'whyyyyyyyyyyyy',
#    'life',
#    'unfair'],
#   0),
#  (['way', 'common', ':-('], 0),
#  (['sleepovers',
#    'jesse',
#    'awesome',
#    'work',
#    '5:30',
#    'morning',
#    'bebe',
#    'come',
#    'back'],
#   0),
#  (['missed', 'goal', '1-0', 'real'], 0),
#  (['feet', 'hurt'], 0),
#  (['perfect', 'thing', 'pick'], 1),
#  (['spiritual',
#    'ritual',
#    'festival',
#    'népal',
#    'beginning',
#    'line-up',
#    'left',
#    'line-up',
#    'see',
#    '...'],
#   1),
#  (['ekk', 'giriboy'], 0),
#  (['summer',
#    'style',
#    'stack',
#    'pandora',
#    'rings',
#    'ladies',
#    ':-)',
#    'rings',
#    'favourite'],
#   1),
#  (['official', 'account', 'couldnt', 'find', 'one'], 1),
#  (['ass'], 1),
#  (['glad',
#    'hear',
#    'dan',
#    "we're",
#    'mega',
#    'excited',
#    'retail',
#    'launch',
#    'forget',
#    'look',
#    'boots',
#    'whsmith'],
#   1),
#  (["we're", 'isolating', 'fas'], 1),
#  (['sure'], 1),
#  (["i'll", 'give', 'liam', 'solo', 'dylan', 'pls'], 0),
#  (['put', 'due', 'release'], 1),
#  (['course',
#    "i've",
#    'cited',
#    'academic',
#    'paper',
#    'feel',
#    "i've",
#    'arrived',
#    ':-)'],
#   1),
#  (["i've", 'happy', 'lately'], 1),
#  (['around', 'tom'], 0),
#  (['haha', 'japan', 'sorry', 'love'], 0),
#  (['twitter',
#    'help',
#    'center',
#    'follow',
#    'people',
#    'via',
#    'really',
#    'really',
#    'sorry',
#    'following',
#    'evry',
#    'one'],
#   0),
#  (['gutted',
#    'never',
#    'went',
#    'distant',
#    'worlds',
#    'london',
#    "i'm",
#    'well',
#    'long'],
#   0),
#  (['students',
#    'around',
#    'globe',
#    'miss',
#    'enjoy',
#    'summer',
#    "we'll",
#    'see',
#    'soon',
#    ':-)'],
#   1),
#  (['gutted', '20th', 'anniversary', 'shows', 'next', 'year', 'clash'], 0),
#  (['ghanton', 'light', 'nahi'], 1),
#  (['fugly', 'school', ':-('], 0),
#  (['knows',
#    'exactly',
#    'want',
#    'get',
#    'paralyzed',
#    'anxiety',
#    'sadness',
#    'lol'],
#   1),
#  (['hopefully', "i'll"], 1),
#  (['wish', 'good', 'makeup', 'thing', 'good', 'eyeliner'], 0),
#  (['contact', 'whatsoever', 'anybody'], 0),
#  (["he's", 'cute'], 0),
#  (['mean', 'offering'], 0),
#  (['aaaaaaaaaaaaa', 'need', 'decide', 'waifu', 'like', 'tomorrow'], 0),
#  (['wants'], 1),
#  (['cycling'], 1),
#  (['new',
#    'video',
#    'week',
#    'updated',
#    'face',
#    'brows',
#    'routine',
#    'oily',
#    'skin',
#    'maricarljanah',
#    'via'],
#   1),
#  (['joining', 'today'], 1),
#  (['hope', 'great', 'time', 'full', 'happiness', 'love', '...', '80x'], 1),
#  (['wiellys', 'follback'], 1),
#  (['cries', 'miss', 'mingming', 'much', ':-('], 0),
#  (['maybe',
#    '...',
#    "i'll",
#    'listen',
#    'like',
#    "i'll",
#    'stay',
#    'old',
#    'btob',
#    'songs'],
#   0),
#  (['nicki', 'follow', 'please'], 0),
#  (['nice', 'see', 'emulation', 'brought'], 1),
#  (['bam',
#    'follow',
#    'bestfriend',
#    'loves',
#    'lot',
#    'see',
#    'warsaw',
#    'love',
#    'x31'],
#   1),
#  (['fun'], 1),
#  (["we're",
#    'sorry',
#    'longer',
#    'able',
#    'access',
#    'site',
#    'automatically',
#    'redirected',
#    'local',
#    'site'],
#   0),
#  (['top', 'twoofs', 'wooftastic', 'wkend', 'guys'], 1),
#  (['popular',
#    'charismatic',
#    'man.he',
#    'thrive',
#    'long',
#    'economy',
#    'bubbles',
#    'bursts',
#    'georgie'],
#   1),
#  (['money', 'money', ':-('], 0),
#  (['good', 'luck', 'couples', 'getting', 'married', 'weekend'], 1),
#  (['geer', 'bat', 'yang', 'deennya', 'jehwan'], 1),
#  (['tack', ':-)'], 1),
#  (['happen', 'kaussies'], 0),
#  (['really', 'code', 'monkey'], 0),
#  (['would', 'love', 'treats', 'little', 'furry', 'friend', 'bruce'], 1),
#  (['actually', 'going', 'yayayayay', 'gonna', 'first', 'convention'], 1),
#  (['19:30', 'apple', 'store', 'ifc', "we'll", 'pick', 'place', ':-)'], 1),
#  (['drew'], 1),
#  (['snapchat', 'guys', 'sexyjane'], 0),
#  (['mum', 'says', 'done', 'leaving', 'step', 'dad', ':-('], 0),
#  (['happy',
#    'birthday',
#    'amazingly',
#    'talanted',
#    'hope',
#    'year',
#    'brings',
#    'happiness',
#    'success',
#    'deserve',
#    'cheers'],
#   1),
#  (['thank'], 1),
#  (['photo',
#    'randy',
#    '9bis',
#    'beautiful',
#    'physique',
#    'shaved',
#    'uncut',
#    'tattoo',
#    'sexy',
#    'boi',
#    ':-)'],
#   1),
#  (['itong', 'shirt', 'want', 'thaaaat', 'ctto'], 0),
#  (["i'am", 'elf', 'hbu'], 1),
#  (['hello', 'need', '2.5', 'g2a', 'code', 'pls'], 0),
#  (['good', 'dream', 'sign', 'going', 'get', 'along', 'unknown', 'roomie'], 1),
#  (['twist',
#    'defined',
#    'hell',
#    'feel',
#    'like',
#    'youve',
#    'made',
#    'break',
#    '...'],
#   1),
#  (['come', 'man'], 1),
#  (['payday', 'feels', 'like', 'payhour', 'gone', 'bills', 'immediately'], 0),
#  (['wisdom', 'teeth', 'giving', 'much', 'ache'], 0),
#  (['need', 'clear', 'head'], 0),
#  (['probably', 'gonna', 'though'], 1),
#  (["i'm", 'back', 'sorry', 'many', 'problems'], 1),
#  (['time', 'right', 'yes', 'yunnie', 'serious'], 0),
#  (['wifi', 'steroids', 'today'], 1),
#  (['thanks', 'shaaaa', 'miss', 'super'], 0),
#  (["t'was", 'great', 'thank'], 1),
#  (['try',
#    'stay',
#    'possitve',
#    'hun',
#    'sending',
#    'hugs',
#    'hopeyou',
#    'sweetie',
#    'xxxx'],
#   1),
#  (['know',
#    'right',
#    '...',
#    'hope',
#    'worth',
#    'really',
#    'wanna',
#    'see',
#    'hugh',
#    'wolverine'],
#   0),
#  (["california's",
#    'powerful',
#    'influential',
#    'air',
#    'pollution',
#    'watchdog',
#    'califor',
#    '...',
#    ':-('],
#   0),
#  (['want', 'ihop'], 0),
#  (['waiting', 'defend', 'new', 'fashion', 'atrocity'], 1),
#  (["i'll", 'write', 'bunch', 'ugly', 'setter', 'functions', '...'], 0),
#  (['fback'], 1),
#  (['nhe', 'yar'], 0),
#  (['hello',
#    'info',
#    'possible',
#    'interest',
#    'jonathas',
#    'hes',
#    'close',
#    'betis'],
#   0),
#  (['nobody', 'picking', 'one', 'right'], 0),
#  (['agreed', 'haha'], 1),
#  (['miss', 'much'], 0),
#  (['rly', 'wanna', 'spend', 'christmas', 'relatives'], 0),
#  (['hardly', 'respond', ':-('], 0),
#  (['beloved', 'grandmother'], 0),
#  (['cat',
#    'super',
#    'nice',
#    'cuddly',
#    'suddenly',
#    'scratches',
#    'tries',
#    'bite',
#    'like',
#    'trust',
#    'anymore'],
#   0),
#  (['nooooooooo', 'last', 'day', 'today'], 0),
#  (['last',
#    'day',
#    'working',
#    'munchkin',
#    'today',
#    '...',
#    '...',
#    'bought',
#    'little',
#    'parting',
#    'gift',
#    '...',
#    'far'],
#   0),
#  (['lovely', 'looking', 'cake', 'bet', 'tastes', 'good', ':-)'], 1),
#  (['thought', 'might', 'like'], 1),
#  (['stats', 'week', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['witnessed'], 0),
#  ([], 0),
#  (['jgh', 'bonding', 'niggs'], 1),
#  (['delve'], 1),
#  (['fall',
#    'love',
#    'canopy',
#    'maple',
#    'leaves',
#    'secrets',
#    'maple',
#    'syrup',
#    'farm',
#    'happy',
#    'friday'],
#   1),
#  (['honestly', "i've", 'idea', 'thing', 'could', 'explain'], 1),
#  (['5sos',
#    'calum',
#    '5sos',
#    'luke',
#    '5sos',
#    'ashton',
#    '5sos',
#    'hey',
#    'guys',
#    'please',
#    'follow',
#    'chelny'],
#   1),
#  (['sure', 'mate', 'worry', 'thanks'], 1),
#  (['thanks', 'everyone', 'came', 'show', 'tipped'], 1),
#  (['update', 'finished', 'packing', 'fly', 'stuck', 'room'], 1),
#  ([], 0),
#  (["that's", 'spirit'], 1),
#  (['watching', 'disney', 'channel'], 0),
#  (['canadian',
#    'family',
#    'best',
#    'dinner',
#    'holiday',
#    'last',
#    'night',
#    'well',
#    'done',
#    'enjoyed',
#    "we're",
#    'holiday'],
#   0),
#  (['drank'], 1),
#  (['homie', 'dassy', 'fwm'], 1),
#  (['friday', '...'], 1),
#  (['seem',
#    'burned',
#    'everything',
#    'apart',
#    'tea',
#    'morning',
#    'bravo',
#    'friday',
#    'richard',
#    ':-('],
#   0),
#  (['wanna', 'house', 'give', 'big', 'big', 'hug'], 0),
#  (['want', 'play', 'video', 'games', 'watch', 'movies', 'someone'], 0),
#  (['lots', 'people', 'chat', ':-)'], 1),
#  (['please', 'read', 'reply', 'please'], 1),
#  (['gosh', 'say', 'hun', 'cuddles'], 0),
#  (['finally',
#    'got',
#    'time',
#    'catch',
#    'games',
#    'wish',
#    'could',
#    'say',
#    'let',
#    'games',
#    'begin',
#    '...',
#    'sigh',
#    'ps3',
#    'working'],
#   0),
#  (['forget',
#    'every',
#    'year',
#    'summer',
#    'hols',
#    'hard',
#    '...',
#    'spend',
#    'days',
#    'days',
#    'never',
#    'really',
#    'conversations',
#    'grown',
#    'ups'],
#   0),
#  (['stats', 'week', 'arrived', 'new', 'followers', 'unfollowers', 'via'], 1),
#  (['ugh', 'want', 'right', 'right', 'need', 'tay', 'one', 'understands'], 0),
#  (['cast', 'vote', 'next', 'elections'], 1),
#  (['wanna', 'see', 'face', 'miss', 'much', 'years', 'hopefully'], 0),
#  (['cheers', 'mike', 'love', 'pics'], 1),
#  (["i'm", 'fucking', 'great', 'fuck', 'think', 'less', ':-)'], 1),
#  (['told', 'gorgeous', 'extremely', 'sweaty', 'walk', 'work', 'made', 'day'],
#   1),
#  (['never', 'call'], 0),
#  (['poor', 'baby'], 0),
#  (['going',
#    'stop',
#    'breakfast',
#    'early',
#    'might',
#    'want',
#    'remove',
#    '11am',
#    'website',
#    'even',
#    "mcd's",
#    'pull',
#    'trick'],
#   0),
#  (['bye', 'wellington', 'awesome', 'hope', 'meet'], 1),
#  (['hope', 'clears', 'wkend', 'good', 'one'], 1),
#  (['okay', 'miss'], 0),
#  (['hell',
#    'yes',
#    'donington',
#    'park',
#    '24/25',
#    'hoping',
#    'see',
#    'team',
#    'season'],
#   1),
#  (['rm35', 'still', 'negooo', 'male'], 1),
#  (['god'], 0),
#  (['retweet', 'pleaaase'], 0),
#  (['yeah',
#    "that's",
#    'last',
#    'time',
#    'planning',
#    'file',
#    'police',
#    'complaint',
#    'much',
#    'yelling',
#    'switch',
#    'places'],
#   0),
#  (['unlucky', 'would', 'dying', 'passed', 'away', 'came', 'stage', ':-('], 0),
#  (['good', 'nigth', 'estoy', 'escuchando', 'enemy', 'god'], 1),
#  (['everyone', 'drop', 'follow', 'stream'], 1),
#  (['old', 'one', 'day', '...'], 0),
#  (['stomachache', 'slice', 'cake'], 0),
#  (['going', 'sleep', 'goodnight'], 1),
#  (['something', 'great', 'playing', 'perfect'], 0),
#  (['nowt', 'worse', 'sad', 'looking', 'willy'], 0),
#  (['please', 'okay', 'tho', 'sooooooooo', 'soooo', 'hard', 'get', 'follow'],
#   0),
#  (['number'], 0),
#  (['otp'], 0),
#  (['stats', 'day', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['sleep',
#    'stay',
#    'entire',
#    'thing',
#    'tmw',
#    'uwu',
#    '...',
#    'well',
#    'younger',
#    'jinki',
#    'older',
#    'taems',
#    'one',
#    'gifs'],
#   0),
#  (['please',
#    'follow',
#    'please',
#    'follow',
#    'love',
#    'always',
#    'forever',
#    "i'm",
#    'belieber',
#    'love'],
#   1),
#  (['get', 'follow', 'please', 'vikk', 'fna'], 1),
#  (['get', 'want', 'record', 'grrrr'], 0),
#  (['cold', 'office', 'huhu', 'tasks', "i'll", '9pm', 'hahaah'], 0),
#  (['nope', 'nope', 'better', 'keep', 'quiet'], 1),
#  (['love',
#    'much',
#    'beli̇eve',
#    'wi̇ll',
#    'follow',
#    'please',
#    'follow',
#    'please',
#    'justi̇n',
#    'x15',
#    '348',
#    'ｓｅｅ'],
#   0),
#  (['top', 'influencers', 'community', 'week'], 1),
#  (['full',
#    'breakdown',
#    'materials',
#    'used',
#    'thorin',
#    'time',
#    'hunt',
#    'materials',
#    'work',
#    'project'],
#   1),
#  (['problem'], 1),
#  (['new', 'favorite', 'editing', 'app', 'someone', 'pls', 'translate'], 0),
#  (['watching',
#    'abusive',
#    'relationship',
#    'videos',
#    'fucking',
#    'hard',
#    "i'm",
#    'trying',
#    'cry',
#    'like',
#    '...'],
#   0),
#  (['woah', 'okay', 'expect', 'tweets', 'fucker', 'dies'], 1),
#  (['need', 'nate', 'ruess', 'album'], 0),
#  (['miss', ':-('], 0),
#  (['current', 'playlist'], 1),
#  (['dudeeeeeee', "i'm", 'happy', 'like', 'tell', 'favorites'], 1),
#  (['yeah',
#    "they're",
#    'giving',
#    'subtle',
#    'hints',
#    'also',
#    'tip',
#    'use',
#    'community',
#    'last',
#    'years',
#    ':-)',
#    'prim',
#    'algorithm',
#    'iii'],
#   1),
#  (['ouucchhh', 'one', 'wisdom', 'teeth', 'coming'], 0),
#  (['ima', 'leave', 'right', ':-)'], 1),
#  (['appreciate',
#    'weekly',
#    'update',
#    'weapons',
#    'ever',
#    'way',
#    'nowhere',
#    'put',
#    'one',
#    'already'],
#   0),
#  (["i'm", 'best', 'perfect', 'promise', 'love', 'whole', 'heart'], 1),
#  (['got',
#    'stung',
#    'wasp',
#    'crying',
#    'hard',
#    'tweak',
#    'keeps',
#    'getting',
#    'bigger',
#    'ive',
#    'never',
#    'stung',
#    'one',
#    'hope',
#    'allergic'],
#   0),
#  (['came', 'crashing', 'hurts', 'inside'], 0),
#  (['rude', 'gonna', 'put', 'candle', 'away'], 0),
#  (['far',
#    'lfc',
#    'fan',
#    'makes',
#    'expert',
#    'spotting',
#    'mental',
#    'weakness',
#    'lack',
#    'consistency',
#    ':-)'],
#   1),
#  (['happened'], 0),
#  (['stats', 'day', 'arrived', 'new', 'follower', 'unfollowers', 'via'], 1),
#  (['follow', 'follow', 'back'], 1),
#  (['awwhh', 'good', 'friday', 'everyone'], 1),
#  (['kidding', 'kaaaa'], 1),
#  (['jisung', 'kid', 'sunshine'], 1),
#  (['pcy', 'mine', ':-('], 0),
#  (['ate', 'know', 'loves', 'much', 'maybe', 'hard', 'time', 'right'], 0),
#  (['lovely', 'daaay'], 1),
#  (['careful', 'actually', 'black', 'box'], 0),
#  (['guys', 'great', 'weekend'], 1),
#  (['neobytes',
#    'universal',
#    'pictures',
#    'seeds',
#    'pirated',
#    'movie',
#    'copy',
#    'files',
#    'takedown',
#    'notice'],
#   1),
#  (['ohh',
#    'sucks',
#    'hands',
#    'jackets',
#    'way',
#    'warm',
#    'making',
#    'sleepy',
#    '24/7'],
#   0),
#  (['people', 'wished', 'birthday'], 0),
#  (['heck', 'follow'], 0),
#  (['member', 'හෙල', 'හවුල', 'chance'], 1),
#  (['manage',
#    'sort',
#    'ticket',
#    'issue',
#    'mate',
#    'nobody',
#    'picked',
#    'rang',
#    'box',
#    'office'],
#   0),
#  (['please', 'ask', 'upvotes'], 0),
#  ([':-('], 0),
#  (['jumma', 'mubbarak'], 1),
#  (['heyy', 'miss'], 0),
#  (['spotify', 'finally', 'figured', "i'm", 'let', 'listen', 'anymore'], 0),
#  (['bam', 'follow', 'bestfriend', 'loves', 'lot', 'see', 'warsaw', 'love'], 1),
#  (['want', 'sausage', 'roll', ':-('], 0),
#  (['hey', 'follow', 'back', 'average', "joe's", 'love'], 1),
#  ...]

# %%
# Training the Naive Bayes classifier
training_set = nltk.classify.apply_features(extract_features,tweets)
classifier = nltk.NaiveBayesClassifier.train(training_set)
#classifier = nltk.classify.DecisionTreeClassifier(training_set)

# %%
neg_cnt = 0
pos_cnt = 0
for obj in test_neg:
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 0):
        neg_cnt = neg_cnt + 1
for obj in test_pos:
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 1):
        pos_cnt = pos_cnt + 1

print('[Negative]: %s/%s '  % (len(test_neg),neg_cnt))
print('[Positive]: %s/%s '  % (len(test_pos),pos_cnt))
# Out:
# [Negative]: 527/513
# [Positive]: 473/454

# %% [markdown]
# ## Useful links to start NLP
# <br>
# https://realpython.com/python-nltk-sentiment-analysis/

# %%
# prompt: print confusion matrix

from sklearn.metrics import confusion_matrix

# Create lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

for obj in test['Tweet']:
    true_labels.append(test.loc[test['Tweet'] == obj, 'Sentiment'].iloc[0])
    predicted_labels.append(classifier.classify(extract_features(obj.split())))

# Calculate and print the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[513  14]
#  [ 19 454]]

# %%
tweets

# %%
#measure F1 score, and recall, and precision
#build other model, e.g. random forest for this task

# %%
# prompt: measure F1 score, and recall, and precision

from sklearn.metrics import f1_score, recall_score, precision_score

# Calculate F1 score
f1 = f1_score(true_labels, predicted_labels, average='weighted')  # Use 'weighted' for multi-class problems
print("F1 Score:", f1)

# Calculate recall
recall = recall_score(true_labels, predicted_labels, average='weighted')
print("Recall:", recall)

# Calculate precision
precision = precision_score(true_labels, predicted_labels, average='weighted')
print("Precision:", precision)
# Out:
# F1 Score: 0.9669902309940904
# Recall: 0.967
# Precision: 0.9670289987789988

# %%
tweets
# Out:
# [(['shit', ':('], 0),
#  (['are', 'u', 'there', 'too', '?', ':(', 'http://t.co/P4Of3dpGXi'], 0),
#  (['Only',
#    'my',
#    'bad',
#    'would',
#    'remind',
#    'me',
#    'to',
#    'exercise',
#    'at',
#    '1:12',
#    'in',
#    'the',
#    'am',
#    ':-)',
#    '.',
#    'I',
#    'miss',
#    'her',
#    '.',
#    'She',
#    'needs',
#    'to',
#    'come',
#    'back',
#    '.',
#    'Now',
#    '.'],
#   1),
#  (['lols', '.', ':D'], 1),
#  (['thank', 'you', ':)'], 1),
#  (['My',
#    'sisters',
#    'are',
#    'the',
#    'best',
#    '!',
#    '!',
#    '!',
#    'Best',
#    'pre',
#    'bday',
#    'celebration',
#    ':)',
#    ')',
#    ')'],
#   1),
#  (['Aw', 'no', '...', 'was', 'just', 'about', 'to', 'switch', 'over', ':-('],
#   0),
#  (['This',
#    'is',
#    'so',
#    'beautiful',
#    ':)',
#    'via',
#    'disney.arts',
#    'by',
#    'the',
#    'talented',
#    'elmoprinssi',
#    ':)',
#    '_',
#    "Don't",
#    'forget',
#    'to',
#    '…',
#    'https://t.co/UwsFDaeyzB'],
#   1),
#  (['got', 'netfilx', 'today', '!', 'whoop', 'whoop', '!', ':D'], 1),
#  (["It's",
#    'always',
#    'hard',
#    'leaving',
#    'my',
#    'heart',
#    ':(',
#    "I'mo",
#    'sulk',
#    'all',
#    'day',
#    'today',
#    '.'],
#   0),
#  (["They're",
#    'so',
#    'addictive',
#    "aren't",
#    'they',
#    '!',
#    'Beautiful',
#    'flowers',
#    ':)',
#    'and',
#    'Humphrey',
#    'is',
#    'very',
#    'cute',
#    '!'],
#   1),
#  (['Who',
#    "Wouldn't",
#    'Love',
#    'These',
#    'Big',
#    '...',
#    'Juicy',
#    '...',
#    'Selfies',
#    ':)',
#    'http://t.co/RpE0HsCtDQ',
#    'http://t.co/SGKbE2jWRh'],
#   1),
#  (['Here',
#    'you',
#    'go',
#    ':',
#    'http://t.co/nGJ1vzhsj1',
#    ',',
#    'please',
#    'click',
#    'on',
#    'the',
#    'link',
#    'and',
#    'checkout',
#    '!',
#    ':)'],
#   1),
#  (['Hungry', ':('], 0),
#  (['We',
#    'thought',
#    'today',
#    'was',
#    'pizza',
#    'day',
#    '.',
#    'Sadly',
#    'none',
#    'of',
#    'the',
#    'managers',
#    'are',
#    'in',
#    'that',
#    'usually',
#    'buy',
#    'it',
#    ':('],
#   0),
#  (['lucky', ':('], 0),
#  (['Sorted',
#    ':)',
#    '.',
#    'Thanks',
#    '.',
#    'Daaru',
#    'party',
#    'in',
#    'my',
#    'chaddi',
#    ',',
#    'bros',
#    '.'],
#   1),
#  (['Visit', 'my', 'blog', 'http://t.co/UzOAqroWKx', 'thanks', ':D'], 1),
#  (['why', "won't", 'justin', 'come', 'to', 'Scotland', ':('], 0),
#  (['I',
#    'THINK',
#    'THIS',
#    'IS',
#    'FROM',
#    'THEIR',
#    'FIFTH',
#    'ALBUM',
#    'IM',
#    ':)',
#    'OKAY',
#    ':)',
#    'FUCK',
#    ':)',
#    'https://t.co/qzT5Zsm8RE'],
#   1),
#  (['The',
#    'last',
#    'thing',
#    'Labour',
#    'needs',
#    'is',
#    'a',
#    'leader',
#    'people',
#    'want',
#    'to',
#    'vote',
#    'for',
#    'http://t.co/7zicZ1G0mb',
#    '#jeremy4leader',
#    '#jezwecan',
#    'Do',
#    'read',
#    '-',
#    'brilliant',
#    '!',
#    ':-)'],
#   1),
#  (['In',
#    '#Fallout4',
#    'we',
#    'get',
#    'to',
#    'see',
#    'the',
#    'Glowing',
#    'Sea',
#    '.',
#    'Again',
#    '.',
#    'Technically',
#    'did',
#    'in',
#    'Fallout',
#    '3',
#    '.',
#    'I',
#    'just',
#    'played',
#    'again',
#    'to',
#    'see',
#    ':D',
#    'http://t.co/zRP17qI0qT'],
#   1),
#  (['I', "won't", ':)'], 1),
#  (["I'm", 'so', 'sad', '.', ':('], 0),
#  (['Happy', 'Birthday', ':)'], 1),
#  (['Very',
#    'sad',
#    'to',
#    'return',
#    'from',
#    'holiday',
#    'to',
#    'find',
#    'not',
#    'on',
#    'my',
#    'radio',
#    'in',
#    'the',
#    'morning',
#    'and',
#    'not',
#    'doing',
#    'BC',
#    'drive',
#    ':('],
#   0),
#  (["i'm", 'not', 'going', ':(', 'kailan', 'ba', '?', 'may', 'tix', 'ka', '?'],
#   0),
#  (['#YourNaturalLeaders',
#    'and',
#    '#YoungNaturalLeaders',
#    'Mon',
#    '27July',
#    '#Cumbria',
#    'UK',
#    ':)',
#    '&',
#    '#Flockstars',
#    'Thur',
#    '30July',
#    'ITV',
#    'http://t.co/lYxDIByo2o'],
#   1),
#  (['Yes',
#    ',',
#    'of',
#    'course',
#    ':)',
#    '#TeamPositive',
#    'https://t.co/SaIX1VpFJF'],
#   1),
#  (['#RIPRishikeshwari', '.', 'Your', 'soul', 'rest', 'in', 'peace', '.', ':('],
#   0),
#  (['erm', ',', "what's", 'that', 'like', 'then', ':('], 0),
#  (['ZAYYYN', ':('], 0),
#  (['I',
#    'have',
#    'not',
#    'been',
#    'this',
#    'happy',
#    'for',
#    'such',
#    'a',
#    'long',
#    'time',
#    ':)'],
#   1),
#  (['Thank', 'you', 'Esai', ':-)'], 1),
#  (['"',
#    ':',
#    'Seems',
#    'like',
#    'you',
#    'go',
#    'out',
#    'alot',
#    '"',
#    'something',
#    'like',
#    'that',
#    '..',
#    ':)'],
#   1),
#  (['see', 'you', 'later', ':)'], 1),
#  ([':(', 'ion', 'wanna', 'hear', 'that'], 0),
#  (['u', 'are', 'so', 'cute', 'thank', 'u', ':('], 0),
#  (['AND',
#    'HELLO',
#    'TWITTER',
#    ',',
#    'MY',
#    'ACCOUNT',
#    'IS',
#    'BROKEN',
#    'AGAIN',
#    ':)'],
#   1),
#  (['i',
#    'miss',
#    'hannah',
#    'montana',
#    'and',
#    "that's",
#    'so',
#    'raven',
#    'sooo',
#    'much',
#    ':-(',
#    '(',
#    '('],
#   0),
#  (['Thankyou',
#    'sa',
#    'treat',
#    'kanina',
#    'and',
#    'sorry',
#    'sa',
#    'breakdown',
#    'bc',
#    'of',
#    'Sir',
#    'Mags',
#    ':(',
#    '('],
#   0),
#  (['Fuck',
#    'texting',
#    'you',
#    'funny',
#    'dudes',
#    '+',
#    'dudettes',
#    ':)',
#    'Costs',
#    'me',
#    'a',
#    '~',
#    '#Flippin',
#    "'",
#    '~',
#    '#Fortune500',
#    "I'm",
#    'in',
#    '~',
#    '#DivineDiscontent',
#    ';}',
#    '~',
#    'the',
#    '~',
#    '#AmNotness',
#    '}',
#    '~'],
#   1),
#  (['is',
#    'there',
#    'MovNat',
#    'in',
#    'Belgium',
#    '?',
#    'First',
#    'search',
#    'yields',
#    'nothing',
#    '...',
#    ':-(',
#    '#NBHeroes'],
#   0),
#  (["I'm", 'a', 'fan', 'account', 'for', 'pitbull', ':)'], 1),
#  (['This',
#    'Sunday',
#    'Morning',
#    'stream',
#    'will',
#    'also',
#    'be',
#    'a',
#    'birthday',
#    'stream',
#    ',',
#    'so',
#    'I',
#    'will',
#    'follow',
#    'my',
#    'usual',
#    'birthday',
#    'procedure',
#    'and',
#    'play',
#    'Grim',
#    'Fandango',
#    '!',
#    ':D'],
#   1),
#  (['ago',
#    'hogo',
#    'vishaya',
#    'all',
#    'adu',
#    '.',
#    'BJP',
#    'madatte',
#    'anta',
#    'vishwas',
#    'ne',
#    'illa',
#    '.',
#    ':('],
#   0),
#  (['done', 'yun', ':)'], 1),
#  (['I',
#    'want',
#    'to',
#    'get',
#    'into',
#    'Dota',
#    'but',
#    'fuck',
#    'me',
#    "it's",
#    'just',
#    'not',
#    'for',
#    'me',
#    ':('],
#   0),
#  (['I',
#    'liked',
#    'a',
#    'video',
#    'http://t.co/2JcBiswDW9',
#    'More',
#    'subs',
#    'plz',
#    ':('],
#   0),
#  (['My', 'legs', 'hurt', 'so', 'bad', ':)', ')', ')'], 1),
#  (['IM',
#    'NOT',
#    'SCREENSHOTTING',
#    'IM',
#    'SO',
#    'PROUD',
#    'OF',
#    'MYSELF',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['Gusto',
#    'ko',
#    'ng',
#    "Rodic's",
#    ':(',
#    'someone',
#    'share',
#    'an',
#    'order',
#    'with',
#    'me',
#    'because',
#    "one's",
#    'big'],
#   0),
#  (['not', 'yet', ':(', 'did', 'they', 'find', 'yours', 'eventually', '?'], 0),
#  (['Also', ',', 'new', 'layout', 'new', 'me', ':)'], 1),
#  (['please', 'put', 'it', 'on', 'spotify', 'too', 'please', '?', ':)'], 1),
#  (['Sorry', 'guys', ',', 'no', 'new', 'video', 'this', 'week', '!', ':('], 0),
#  (['back', 'to', 'Delhi', ':('], 0),
#  (['Achieving',
#    'excellence',
#    'in',
#    'Music',
#    'as',
#    'a',
#    'Music',
#    'Producer',
#    'is',
#    'a',
#    'Mind',
#    'Boggling',
#    '&',
#    'Fatiguing',
#    'Job',
#    '...',
#    'Baareeq',
#    '...',
#    ':)',
#    ':)',
#    ':)'],
#   1),
#  (['aha',
#    'yesss',
#    '!',
#    'Who',
#    'are',
#    'you',
#    'most',
#    'looking',
#    'forward',
#    'to',
#    'seeing',
#    '?',
#    ':)'],
#   1),
#  (['thank', 'you', ',', 'you', 'too', '!', ':)'], 1),
#  (['Loan', 'back', 'until', 'January', ':D'], 1),
#  (['#louisiana',
#    'cinema',
#    'shooting',
#    ':',
#    'Why',
#    'do',
#    'mass',
#    'shootings',
#    'happen',
#    'so',
#    'regularly',
#    'in',
#    'US',
#    '?',
#    'Sympathis',
#    'to',
#    'victims',
#    "'",
#    'families',
#    ':('],
#   0),
#  (['Hi',
#    'Brian',
#    "I'll",
#    'get',
#    'it',
#    'shipped',
#    'today',
#    'for',
#    'you',
#    'and',
#    'it',
#    'can',
#    'take',
#    'between',
#    '2-3',
#    'weeks',
#    'to',
#    'Australia',
#    '.',
#    'Many',
#    'thanks',
#    ':)',
#    'http://t.co/IBoe0e1aXt'],
#   1),
#  (['I',
#    'wanna',
#    'watch',
#    'them',
#    'again',
#    'too',
#    ':(',
#    'maybe',
#    'when',
#    'they',
#    'do',
#    'comeback',
#    'shows',
#    'in',
#    'Korea',
#    '...',
#    'or',
#    'in',
#    'Japan',
#    '.',
#    'I',
#    'wanna',
#    'visit',
#    'your',
#    'country'],
#   0),
#  (['A5',
#    '.',
#    'If',
#    'I',
#    'was',
#    'a',
#    'Girl',
#    ',',
#    'My',
#    'Wardrobe',
#    'would',
#    'only',
#    'and',
#    'only',
#    'have',
#    '"',
#    'W',
#    '"',
#    'in',
#    'it',
#    ':)',
#    ')',
#    '#WSaleLove'],
#   1),
#  (['i', 'love', 'you', 'so', 'so', 'so', 'so', 'so', 'so', 'much', ':('], 0),
#  (['I',
#    'actually',
#    'tried',
#    'that',
#    'blend',
#    "it's",
#    'really',
#    'good',
#    '!',
#    'Also',
#    'has',
#    'good',
#    'health',
#    'benefits',
#    'too',
#    '.',
#    ':)'],
#   1),
#  (['min', 'follback', ':('], 0),
#  (['follow', 'back', ':)'], 1),
#  (['sure', '.', 'Done', '.', ':)'], 1),
#  (['didnt',
#    'have',
#    'the',
#    'money',
#    'at',
#    'the',
#    'time',
#    ':(',
#    'but',
#    'would',
#    'have'],
#   0),
#  (["she's", 'my', 'friend', ':('], 0),
#  (['Please',
#    'follow',
#    'me',
#    ',',
#    'I',
#    'will',
#    'return',
#    'it',
#    'soon',
#    'follow',
#    ':)',
#    '#TuitUtil',
#    'http://t.co/Fw5JKPrVxt'],
#   1),
#  (['Feeling',
#    'very',
#    'sucky',
#    'w',
#    'this',
#    'running',
#    'nose',
#    'cough',
#    'sore',
#    'throat',
#    'and',
#    'fever',
#    ':-('],
#   0),
#  (['Keeo',
#    'guessing',
#    'whats',
#    'behind',
#    'that',
#    'white',
#    'cover',
#    ':)',
#    'special',
#    'for',
#    'you',
#    '..',
#    'happy',
#    'bday',
#    'once',
#    'again',
#    'my',
#    'darling',
#    '…',
#    'https://t.co/TyFcTnM59u'],
#   1),
#  (['Aur', 'ap', 'bhi', 'is', 'me', 'shamil', 'ho', ':('], 0),
#  (['This', 'is', 'horrible', '.', ':(', 'http://t.co/6G6C7ewfpf'], 0),
#  (['Hence',
#    'the',
#    'expression',
#    ':',
#    'wot',
#    'a',
#    'racket',
#    '!',
#    '?',
#    '!',
#    'Maybe',
#    '?',
#    ':p'],
#   1),
#  (['didnt', 'took', 'photos', 'with', 'you', ':-('], 0),
#  (['All',
#    "I've",
#    'been',
#    'doing',
#    'is',
#    'watch',
#    'cooking',
#    'tutorials',
#    ':(',
#    'these',
#    'are',
#    'not',
#    'the',
#    'things',
#    'I',
#    'had',
#    'planned',
#    'for',
#    'summer'],
#   0),
#  (['Smh', 'I', 'know', ':('], 0),
#  (["I'll", 'sleep', 'better', 'tonight', ':('], 0),
#  (['FOLLOWED',
#    'ME',
#    'THANKS',
#    ',',
#    'AND',
#    'PLEASE',
#    'FOLLOWED',
#    'ME',
#    'TOO',
#    ':('],
#   0),
#  (['Great',
#    'view',
#    '!',
#    "It's",
#    'a',
#    'shame',
#    'about',
#    'the',
#    'weather',
#    'though',
#    ':-('],
#   0),
#  (['ME', 'TOO', ':(', '(', '(', 'wHERE', 'IS', 'MARGO'], 0),
#  (['i', 'hope', 'so', 'miss', 'na', 'kita', 'crys', 'why', 'so', 'ia', ':('],
#   0),
#  (['i', 'want', 'to', 'meet', 'you', ':('], 0),
#  (['I',
#    'genuinely',
#    'keep',
#    'having',
#    'nightmares',
#    'about',
#    'results',
#    'day',
#    'Fam',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['..',
#    'Thank',
#    'you',
#    'Mario',
#    '...',
#    'Have',
#    'a',
#    'wonderful',
#    'Friday',
#    '...',
#    ':)',
#    ')'],
#   1),
#  (['follback', 'me', 'pls', ':('], 0),
#  (['BECAUSE', "THAT'S", 'YOUR', 'GOAT', 'MINO', ':', '('], 0),
#  (['My',
#    '#TeenChoice',
#    'for',
#    '#ChoiceInternationalArtist',
#    'is',
#    '#SuperJunior',
#    '!',
#    ':)'],
#   1),
#  (['that',
#    'sounds',
#    'cool',
#    '!',
#    '!',
#    'Bet',
#    'it',
#    "doesn't",
#    'float',
#    'though',
#    ':('],
#   0),
#  (['Throwback', ':-)', ')', ')', 'http://t.co/Tf4pHYRUDB'], 1),
#  (['moar', 'kittehs', 'will', 'be', 'incoming', ':D'], 1),
#  (['Lolliver', '!', '!', '!', ':('], 0),
#  (['Maine',
#    'Abhi',
#    'tak',
#    'Ye',
#    'movie',
#    'nhi',
#    'dekhi',
#    'but',
#    'promos',
#    'se',
#    'hi',
#    'i',
#    'knew',
#    'that',
#    "it's",
#    'his',
#    'best',
#    'movie',
#    'till',
#    'date',
#    ':)'],
#   1),
#  (['Jealous', '!', 'I', 'want', 'to', 'be', 'in', 'Miami', ':('], 0),
#  (['ive', 'emailed', 'you', 'regarding', 'course', 'query', '!', ':)'], 1),
#  (['Stock', 'up', 'sa', 'for', '1', 'hour', '.', ':('], 0),
#  (['Need', 'to', 'finish', 'all', 'hws', 'ugh', ':('], 0),
#  (['ahh', 'I', 'did', 'thank', 'you', 'so', 'much', ':)', 'xxx'], 1),
#  (['.',
#    'Because',
#    'people',
#    'who',
#    'point',
#    'out',
#    'inaccuracies',
#    'in',
#    'jokes',
#    'might',
#    'be',
#    'inaccurate',
#    'jokes',
#    '.',
#    'I',
#    'got',
#    'worried',
#    ':('],
#   0),
#  (['looking', 'that', 'way', ':('], 0),
#  (['ok', ':-(', 'i', 'only', 'have', 'my', 'd', '&', 'w', 'hahaahahahaha'], 0),
#  (['Hi',
#    'BAM',
#    '!',
#    'Can',
#    'you',
#    'follow',
#    'my',
#    'bestfriend',
#    '?',
#    'She',
#    'loves',
#    'you',
#    'a',
#    'lot',
#    ':)',
#    'See',
#    'you',
#    'in',
#    'Warsaw',
#    '<3',
#    'Love',
#    'you',
#    '<3',
#    'x17'],
#   1),
#  (['tired', '.', 'But', 'fine', ':)', 'you', '?', '?'], 1),
#  (['have', 'you', 'tried', 'turning', 'it', 'off', 'and', 'on', '?', ':)'], 1),
#  (['happy', 'birthday', 'bro', ':)', 'have', 'a', 'good', 'one'], 1),
#  (['Finally',
#    'watching',
#    'the',
#    'last',
#    '#TopGear',
#    'episode',
#    ',',
#    'hopefully',
#    'it',
#    "won't",
#    'end',
#    ':(',
#    'http://t.co/75IDDesHD0'],
#   0),
#  (['Feel',
#    'free',
#    'to',
#    'share',
#    'with',
#    'others',
#    '.',
#    ':-)',
#    'http://t.co/c2W7znBQ0P'],
#   1),
#  (['interesting',
#    '.',
#    "I've",
#    'never',
#    'heard',
#    'of',
#    'it',
#    'before',
#    '.',
#    'Reading',
#    'Temporal',
#    'Void',
#    'atm',
#    '.',
#    'To',
#    'stem',
#    'my',
#    'SF',
#    'needs',
#    ':)'],
#   1),
#  (['Talking',
#    'to',
#    'One',
#    'person',
#    '...',
#    'Having',
#    'Two',
#    'Conversations',
#    ':)',
#    ')',
#    ')'],
#   1),
#  (['Oh',
#    'fab',
#    'Gav',
#    "she's",
#    'a',
#    'lovely',
#    'lovely',
#    'lady',
#    'Linda',
#    'talked',
#    'to',
#    'her',
#    'a',
#    'few',
#    'times',
#    'on',
#    'here',
#    'great',
#    'actress',
#    ':D',
#    'X'],
#   1),
#  (['Has',
#    'anyone',
#    'managed',
#    'to',
#    'get',
#    'an',
#    '#UberIceCream',
#    'yet',
#    '?',
#    'We',
#    'keep',
#    'getting',
#    'busy',
#    'messages',
#    '.',
#    'I',
#    'think',
#    'this',
#    'is',
#    'worse',
#    'than',
#    'the',
#    'tube',
#    'strike',
#    ':('],
#   0),
#  (['DAT',
#    'RP',
#    'THO',
#    '.',
#    'thank',
#    'you',
#    'so',
#    'much',
#    'you',
#    'guys',
#    'for',
#    'celebrating',
#    'one',
#    'month',
#    'of',
#    'partnership',
#    'with',
#    'me',
#    '!',
#    '!',
#    '!',
#    'ty',
#    'for',
#    'the',
#    'raid',
#    '!',
#    ':D'],
#   1),
#  (['Add',
#    'me',
#    'on',
#    'KIK',
#    '-',
#    'mork',
#    '873',
#    '#kik',
#    '#kikgirl',
#    '#kikhorny',
#    '#snapchat',
#    '#addmeonsnapchat',
#    '#premiostumundo',
#    '#hotspotwithdanris',
#    ':(',
#    'http://t.co/r5fMnyWyUf'],
#   0),
#  (['Car',
#    '&',
#    'suspemsion',
#    'cant',
#    'cope',
#    'with',
#    'all',
#    'these',
#    'offroading',
#    'adventures',
#    'now',
#    'theres',
#    'harvest',
#    'machinery',
#    'left',
#    'in',
#    'inapropriate',
#    'places',
#    'to',
#    'weave',
#    'around',
#    ':(',
#    '('],
#   0),
#  (['Not',
#    'fair',
#    'with',
#    'us',
#    'from',
#    'Pb.contestants',
#    'our',
#    'dreams',
#    'not',
#    'comes',
#    'true',
#    'this',
#    'time',
#    ':('],
#   0),
#  (["I'm", 'not', 'gonna', 'freak', 'out', '::', ':)'], 1),
#  (['#FlipkartFashionFriday',
#    'Hey',
#    'Dazzle',
#    'urself',
#    'with',
#    'this',
#    'Double',
#    'Flared',
#    'Red',
#    'and',
#    'Black',
#    'Dress',
#    ':)',
#    'http://t.co/Ri8cSxz6Uq'],
#   1),
#  (['oh',
#    'my',
#    'goodness',
#    'this',
#    'made',
#    'me',
#    'so',
#    'sad',
#    ':(',
#    '#finddjderek'],
#   0),
#  (['Man',
#    'they',
#    'told',
#    'me',
#    'to',
#    'buy',
#    'gold',
#    'all',
#    'the',
#    'way',
#    'down',
#    'from',
#    '1900',
#    '..',
#    'and',
#    'now',
#    'they',
#    'tell',
#    'me',
#    'to',
#    'sell',
#    ':(',
#    '?'],
#   0),
#  (['I', 'like', 'your', 'eyes', ':D'], 1),
#  (['in',
#    'that',
#    'case',
#    ',',
#    'cat',
#    'videos',
#    'are',
#    'for',
#    'all',
#    'moods',
#    '.',
#    'I',
#    'swear',
#    'by',
#    'them',
#    '.',
#    ':D'],
#   1),
#  (['I', 'did', ':-('], 0),
#  (['Ha',
#    'ha',
#    'love',
#    'it',
#    '!',
#    'Thank',
#    'you',
#    ',',
#    'same',
#    'to',
#    'you',
#    ':-)',
#    'any',
#    'exciting',
#    'plans',
#    '?',
#    '#TGIF'],
#   1),
#  (['Unreal',
#    'training',
#    'boys',
#    '!',
#    'Awesome',
#    'work',
#    'Zaine',
#    ',',
#    'Zac',
#    'and',
#    'Isaac',
#    '!',
#    ':)',
#    'Oss',
#    '!',
#    'http://t.co/jisayDDWve'],
#   1),
#  (['It',
#    'will',
#    'be',
#    'updated',
#    'soon',
#    "I'm",
#    'sure',
#    '.',
#    'If',
#    'you',
#    'sign',
#    'in',
#    'you',
#    'can',
#    'set',
#    'up',
#    'text',
#    'alerts',
#    ':)',
#    '|',
#    'DA'],
#   1),
#  (['you', 'know', ':('], 0),
#  (['9/11',
#    'kinda',
#    'ruined',
#    'it',
#    'for',
#    'me',
#    '.',
#    'The',
#    'sound',
#    'makes',
#    'me',
#    'brace',
#    'myself',
#    'for',
#    'hearing',
#    'the',
#    'plane',
#    'crash',
#    'every',
#    'time',
#    '.',
#    'No',
#    'bueno',
#    '.',
#    ':('],
#   0),
#  (['5SOS',
#    'Calum',
#    '5SOS',
#    'Luke',
#    '5SOS',
#    'Ashton',
#    '5SOS',
#    'I',
#    'bet',
#    '$',
#    '20',
#    'to',
#    'a',
#    'friend',
#    'that',
#    'you',
#    'will',
#    'follow',
#    '✧',
#    '｡',
#    'Chelny',
#    '｡',
#    '✧',
#    'Do',
#    'NOT',
#    'disappoint',
#    'me',
#    '.',
#    ':('],
#   0),
#  (['My', 'house', 'scary', 'AF', 'at', 'night', ':('], 0),
#  (["I'm", 'about', 'to', 'start', 'grinding', 'YT', ':)'], 1),
#  (['Happy', 'Friday', ':-)', 'http://t.co/3LSjM4xy5N'], 1),
#  (['Hello',
#    'Ligao',
#    'City',
#    ',',
#    'Albay',
#    '!',
#    ':-)',
#    '#Concert',
#    '#BCYC',
#    '#LNHS',
#    'https://t.co/3Lzz3xvAYp'],
#   1),
#  (['sir',
#    ',',
#    'please',
#    'announce',
#    'don',
#    '3',
#    '!',
#    '!',
#    '!',
#    'i',
#    'am',
#    'badly',
#    'waiting',
#    'for',
#    'it',
#    '!',
#    '!',
#    ':('],
#   0),
#  (['i',
#    'knew',
#    "you'd",
#    'give',
#    'me',
#    'crap',
#    'about',
#    'it',
#    'lol',
#    '.',
#    'Need',
#    'to',
#    'burn',
#    'it',
#    ':p'],
#   1),
#  (['One', 'word', '?', ':p', 'https://t.co/pfxsm8w3eT'], 1),
#  (['where', 'the', 'FUCK', 'is', 'Andy', '?', '!', '?', '!', '?', '!', '>:('],
#   0),
#  (['It',
#    'was',
#    'a',
#    'heritage',
#    'sword',
#    'made',
#    'of',
#    'wood',
#    ',',
#    'so',
#    'no',
#    ':D'],
#   1),
#  (['learn', 'how', 'to', 'spell', '::', ')', ')'], 1),
#  (['Gym', 'Monday', "can't", 'wait', ':)', '.', 'Likes'], 1),
#  (['I',
#    'need',
#    'to',
#    'find',
#    'a',
#    'boy',
#    'that',
#    'loves',
#    'fireball',
#    'just',
#    'as',
#    'much',
#    'as',
#    'I',
#    'do',
#    ':)'],
#   1),
#  (['I', 'no', 'longer', 'like', 'toast', ':('], 0),
#  (['Con-Graduation', 'Gents', '!', ':)', 'CC', '.'], 1),
#  (['Hey',
#    "it'd",
#    'be',
#    'great',
#    'if',
#    'you',
#    'share',
#    'my',
#    'blog',
#    '..',
#    'I',
#    'started',
#    'writing',
#    'blogs',
#    ':)',
#    'check',
#    'it',
#    'out',
#    'and',
#    'let',
#    'me',
#    'know',
#    "how's",
#    'it',
#    'https://t.co/gGs070b6BH'],
#   1),
#  (["You're", 'part', 'of', 'an', 'elite', 'group', ':)'], 1),
#  (['problem',
#    'is',
#    '1',
#    '.',
#    "I'm",
#    'from',
#    'UK',
#    'so',
#    "it's",
#    '£',
#    'not',
#    '$',
#    'and',
#    '2',
#    '.',
#    'I',
#    "don't",
#    'have',
#    '$',
#    '25',
#    ':('],
#   0),
#  (['it', 'was', 'nice', 'seeing', 'today', 'at', 'vidcon', ':)'], 1),
#  (['Anyway', 'my', 'Friday', 'is', 'looking', 'kinda', 'goood', ':)'], 1),
#  (['#welcomeTweet',
#    'hi',
#    '!',
#    'thanks',
#    'for',
#    'following',
#    '!',
#    'just',
#    'ask',
#    'for',
#    'a',
#    'follow',
#    'back',
#    ':-)',
#    'via',
#    'http://t.co/ubXKOjpBez'],
#   1),
#  (['The',
#    'sun',
#    'may',
#    'not',
#    'be',
#    'shining',
#    'here',
#    ',',
#    'but',
#    'at',
#    'least',
#    'its',
#    'nearly',
#    'the',
#    'weekend',
#    '!',
#    '!',
#    '!',
#    'Happy',
#    'Friday',
#    'People',
#    ':-)',
#    'http://t.co/T1x9Cl7NE8'],
#   1),
#  (['Its',
#    'not',
#    'fair',
#    '...',
#    'what',
#    'about',
#    'us',
#    '?',
#    '?',
#    '?',
#    'Fans',
#    'like',
#    'us',
#    'from',
#    'Abroad',
#    'will',
#    'get',
#    'hurt',
#    '...',
#    ':)'],
#   1),
#  (['Happy',
#    'Birthday',
#    '!',
#    'Never',
#    'forget',
#    '.',
#    ':)',
#    '#pglcsgo',
#    'https://t.co/qM8J919s8x'],
#   1),
#  (['All',
#    'i',
#    'want',
#    'is',
#    'some',
#    'chocolate',
#    'and',
#    'a',
#    'lucozade',
#    ':(',
#    ':(',
#    ':(',
#    ':(',
#    ':('],
#   0),
#  (['your', 'bestfriend', ':)', ')', '😌'], 1),
#  (['Will', 'you', 'be', 'my', 'happy', 'ending', '?', 'insyaAllah', ':)'], 1),
#  (['Goning',
#    'to',
#    'make',
#    'thos',
#    'a',
#    'positive',
#    'day',
#    ':)',
#    "you're",
#    'an',
#    'adult',
#    'and',
#    'i',
#    "can't",
#    'keep',
#    'on',
#    'acting',
#    'like',
#    'your',
#    'mom',
#    '..'],
#   1),
#  (['ty', ',', 'come', 'home', 'tonight', 'tho', ':(', '(', '('], 0),
#  (['school', 'start', 'next', 'Monday', 'ohgod', ':('], 0),
#  (['Great',
#    'news',
#    ',',
#    'thanks',
#    'for',
#    'letting',
#    'us',
#    'know',
#    ':(',
#    'We',
#    'hope',
#    'you',
#    'have',
#    'a',
#    'good',
#    'weekend',
#    '!'],
#   0),
#  (['I',
#    'mashed',
#    'up',
#    'my',
#    'phone',
#    'lost',
#    'your',
#    'number',
#    '..',
#    ':(',
#    'Whattsap',
#    'me',
#    'if',
#    'avail'],
#   0),
#  ([':(', '(', 'I', 'miss', 'you', 'so', 'much'], 0),
#  (['YES',
#    '!',
#    'A',
#    'very',
#    'big',
#    'yes',
#    ',',
#    'finally',
#    'got',
#    'home',
#    'from',
#    'this',
#    'severe',
#    'rain',
#    'thanks',
#    ':)'],
#   1),
#  (['First',
#    'time',
#    'travelling',
#    'to',
#    'expo',
#    'by',
#    'myself',
#    '.',
#    '&',
#    'the',
#    'worse',
#    'part',
#    'is',
#    ',',
#    'ive',
#    'not',
#    'been',
#    'to',
#    'expo',
#    'before',
#    ':('],
#   0),
#  (['i', 'want', 'to', 'play', 'sims', '4', ':('], 0),
#  (['this', 'is', 'torture', ':('], 0),
#  (['Hi',
#    'Skye',
#    '!',
#    "I'm",
#    'sorry',
#    'to',
#    'hear',
#    'this',
#    '!',
#    ':(',
#    'Can',
#    'you',
#    'DM',
#    'which',
#    'store',
#    'this',
#    'is',
#    'please',
#    'and',
#    'a',
#    'name',
#    '/',
#    'description',
#    'of',
#    'the',
#    'colleague',
#    'please',
#    '?',
#    '(',
#    '1',
#    ')'],
#   0),
#  (['hope',
#    'bb',
#    'can',
#    'get',
#    'some',
#    'proper',
#    'rest',
#    'soon',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['Morning', 'Twitter', 'People', ':D'], 1),
#  (['i',
#    'want',
#    'to',
#    'finish',
#    'death',
#    'parade',
#    'by',
#    'this',
#    'weekend',
#    ':('],
#   0),
#  (['Physically', ',', 'emotionally', ',', 'mentally', ',', '#TIERD', ':('], 0),
#  (['👱🏽',
#    '👽',
#    '🌳',
#    '😂',
#    '😂',
#    '😂',
#    "I've",
#    'talked',
#    'to',
#    'u',
#    'only',
#    'a',
#    'couple',
#    'times',
#    'but',
#    'u',
#    'seem',
#    'very',
#    'nice',
#    'and',
#    'funny',
#    ':)'],
#   1),
#  (["I'm",
#    'not',
#    'watching',
#    'because',
#    "I'm",
#    'working',
#    ':(',
#    'but',
#    "I'm",
#    'not',
#    'interested',
#    'in',
#    'man',
#    'city',
#    'anyway',
#    '😂',
#    'hope',
#    'they',
#    'lose'],
#   0),
#  (['This',
#    'was',
#    'in',
#    'Sheffield',
#    ':(',
#    'I',
#    'miss',
#    'him',
#    'so',
#    'mych',
#    'http://t.co/kgpUCPTdAx'],
#   0),
#  (['well',
#    'said',
#    ',',
#    'your',
#    'right',
#    'this',
#    'episode',
#    'was',
#    'fantastic',
#    '..',
#    ':)',
#    '#BATB',
#    'clap',
#    'clap',
#    'clap'],
#   1),
#  (["I'm",
#    'so',
#    'excited',
#    ',',
#    'we',
#    'should',
#    'definitely',
#    'meet',
#    'up',
#    ':)'],
#   1),
#  (['could',
#    'you',
#    'pls',
#    'take',
#    'care',
#    'of',
#    'the',
#    'servers',
#    'befor',
#    'you',
#    'send',
#    'that',
#    '?',
#    'We',
#    'have',
#    'no',
#    'value',
#    'in',
#    'it',
#    ',',
#    'as',
#    'long',
#    'as',
#    'we',
#    "can't",
#    'get',
#    'in',
#    ':('],
#   0),
#  (['Really',
#    'not',
#    'looking',
#    'forward',
#    'to',
#    'work',
#    'tonight',
#    'though',
#    ':('],
#   0),
#  (['yass', ':(', ':'], 0),
#  (['I',
#    'honestly',
#    'had',
#    'a',
#    'blast',
#    'getting',
#    'shitfaced',
#    'with',
#    'the',
#    'chat',
#    'and',
#    'with',
#    'all',
#    'you',
#    'kind',
#    'souls',
#    'donating',
#    'over',
#    '70',
#    '$',
#    'tonight',
#    ',',
#    'singing',
#    'disney',
#    'songs',
#    'was',
#    ':D'],
#   1),
#  (["i'm", 'getting', 'there', ':(', "we're", 'at', 'least', 'speaking', 'now'],
#   0),
#  (['And',
#    'by',
#    'turning',
#    'up',
#    ',',
#    'to',
#    'be',
#    'fair',
#    '!',
#    'It',
#    'meant',
#    'a',
#    'lot',
#    'that',
#    'people',
#    'came',
#    '.',
#    ':)'],
#   1),
#  (['This', 'taxi', 'is', 'emptier', 'than', "Ciara's", 'concert', ':('], 0),
#  (['#FollowFriday',
#    'for',
#    'being',
#    'top',
#    'engaged',
#    'members',
#    'in',
#    'my',
#    'community',
#    'this',
#    'week',
#    ':)'],
#   1),
#  (['but',
#    'i',
#    "can't",
#    'fry',
#    'chicken',
#    ',',
#    'woe',
#    'is',
#    'me',
#    'my',
#    'nigga',
#    ':('],
#   0),
#  (['Excited', 'for', 'the', 'weekend', ':-)'], 1),
#  (['follow', '&', 'http://t.co/RCvcYYO0Iq', 'follow', 'u', 'back', ':)'], 1),
#  (['anyway', ':-)'], 1),
#  (['I', 'hate', 'Japanese', 'call', 'him', '"', 'bani', '"', ':(', ':('], 0),
#  (['This',
#    'weekend',
#    'I',
#    'am',
#    'gonna',
#    'shoot',
#    'the',
#    'lovely',
#    'again',
#    '<3',
#    '!',
#    'Here',
#    'a',
#    'picture',
#    'I',
#    'made',
#    'of',
#    'her',
#    'last',
#    'time',
#    ':D',
#    'http://t.co/s3e2dmpt24'],
#   1),
#  (['GZ', ':D', 'what', 'did', 'you', 'named', 'it', '=', '^', '.', '^', '='],
#   1),
#  (['yes',
#    'thank',
#    'u',
#    '!',
#    '!',
#    'Oh',
#    'damn',
#    'that',
#    'hella',
#    'sucks',
#    ':-(',
#    'but',
#    'at',
#    'least',
#    'u',
#    'had',
#    'a',
#    'really',
#    'good',
#    'time',
#    "that's",
#    'all',
#    'that',
#    'matters'],
#   0),
#  (['I',
#    'just',
#    'ate',
#    'a',
#    'whole',
#    'pizza',
#    ':(',
#    'idk',
#    'how',
#    'to',
#    'feel',
#    'about',
#    'that'],
#   0),
#  (['Take', 'me', 'back', 'to', 'Dubai', ':('], 0),
#  (["I'm",
#    'going',
#    'to',
#    'miss',
#    'you',
#    'baby',
#    '!',
#    ':(',
#    '(',
#    '@',
#    'Rancho',
#    'Imperial',
#    'de',
#    'Silang',
#    'Subdivision',
#    'https://t.co/b5JvTqpm4N'],
#   0),
#  (['Aishhh',
#    '...',
#    'the',
#    'stream',
#    'getting',
#    'slow',
#    'and',
#    'more',
#    'viewer',
#    '...',
#    ':(',
#    '(',
#    '*'],
#   0),
#  (['Thank',
#    'you',
#    'for',
#    'sending',
#    'premium',
#    'writing',
#    'instrument',
#    ',',
#    'however',
#    'some',
#    'dastardly',
#    'swine',
#    'stole',
#    'it',
#    'from',
#    'envelope',
#    '!',
#    ':(',
#    'http://t.co/xNe3cD6dvk'],
#   0),
#  (['ANGRY',
#    'GRANDPA',
#    'PLAYS',
#    'MINECRAFT',
#    '(',
#    'ANIMATION',
#    ')',
#    '#Minecraft',
#    'http://t.co/RYHE6sKiJ2',
#    '←',
#    'Click',
#    'Aqui',
#    ':D',
#    'http://t.co/pVzUoAaPIO'],
#   1),
#  (['Oh',
#    '.',
#    'Dog',
#    'has',
#    'pee',
#    '’',
#    'd',
#    'in',
#    'my',
#    'bag',
#    '.',
#    ':-(',
#    'So',
#    'I',
#    'can',
#    '’',
#    't',
#    'take',
#    'it',
#    'to',
#    '#NewWine15'],
#   0),
#  (["I'd",
#    'planned',
#    'to',
#    'do',
#    'a',
#    'nice',
#    'scamper',
#    'but',
#    'I',
#    'slept',
#    'through',
#    'my',
#    'alarm',
#    '.',
#    'For',
#    'two',
#    'hours',
#    '.',
#    'I',
#    'suppose',
#    'I',
#    'needed',
#    'the',
#    'sleep',
#    'so',
#    'I',
#    "ain't",
#    'mad',
#    ':)'],
#   1),
#  (['musicas', ':(', '(', '('], 0),
#  (['I', 'WANT', 'A', 'WHITE', 'FRENCH', 'BULLDOG', ':(', '(', '('], 0),
#  (['Now',
#    'i',
#    'know',
#    'how',
#    'Dire',
#    'and',
#    'Slow',
#    'look',
#    'likee',
#    'IRL',
#    'because',
#    'i',
#    'could',
#    'not',
#    'go',
#    'to',
#    'minecon',
#    ':('],
#   0),
#  (['why', 'is', 'this', 'so', 'accurate', ':-(', '(', '('], 0),
#  (['Summer',
#    'of',
#    'the',
#    'Dragon',
#    '!',
#    'talks',
#    'about',
#    'his',
#    'projects',
#    'and',
#    'represents',
#    'Slovenia',
#    '!',
#    ':)',
#    'http://t.co/YmvJF2Atld',
#    '#slovenia',
#    '#nba',
#    '#basketball'],
#   1),
#  (['nooo', '.', 'This', 'cannot', 'be', 'a', 'thing', '.', ':-(', ':-(', 'x'],
#   0),
#  (['Every',
#    'night',
#    'I',
#    'take',
#    'hella',
#    'melatonin',
#    '&',
#    'every',
#    'night',
#    'I',
#    'take',
#    'like',
#    'a',
#    '2-4',
#    'hour',
#    'nap',
#    'until',
#    "I'm",
#    'wide',
#    'awake',
#    '&',
#    "it's",
#    'the',
#    'next',
#    'day',
#    'again',
#    ':('],
#   0),
#  (["he's", 'always', 'gunna', 'be', 'a', 'former', 'Leeds', 'manager', ':('],
#   0),
#  (['Nak', 'tgk', 'paper', 'townsss', 'sigh', ':('], 0),
#  (["I'm",
#    'playing',
#    'Brain',
#    'Dots',
#    ':',
#    ')',
#    '#BrainDots',
#    'http://t.co/pM64zaogPN',
#    'http://t.co/IGg9sNMM1O'],
#   1),
#  (['I', 'like', 'u', ':)'], 1),
#  (['morning', '!', 'Have', 'a', 'lucky', 'Friday', 'folks', ':)'], 1),
#  (['Looking',
#    'for',
#    'fun',
#    '?',
#    'KIK',
#    ':',
#    'slacke',
#    '565',
#    '#kik',
#    '#kikmeguys',
#    '#blonde',
#    '#kikchat',
#    '#sexy',
#    '#mpoints',
#    '#kiksexting',
#    ':(',
#    'http://t.co/LReixn2h5o'],
#   0),
#  (['thank',
#    'you',
#    'for',
#    'your',
#    'support',
#    ':)',
#    '#KunoriforCEO',
#    '#CEO1Month'],
#   1),
#  (['Mine', 'too', '!', ':('], 0),
#  (['I',
#    'wish',
#    'Twitter',
#    'would',
#    'support',
#    'audio',
#    'recordings',
#    '.',
#    'I',
#    'would',
#    'send',
#    'yall',
#    'snippets',
#    ',',
#    'these',
#    'are',
#    'amazing',
#    ':('],
#   0),
#  (['#Iran',
#    '#IranDeal',
#    ':-(',
#    'The',
#    'US-Iran',
#    'nuclear',
#    'deal',
#    ':',
#    "MIT's",
#    'experts',
#    'size',
#    'it',
#    'up',
#    ':',
#    'This',
#    'deal',
#    'severely',
#    'li',
#    '...',
#    'http://t.co/GbL15aoCW4',
#    '#UniteBlue',
#    '#Tcot'],
#   0),
#  (['I',
#    'want',
#    'him',
#    'to',
#    'be',
#    'healthy',
#    'and',
#    'happy',
#    'again',
#    ',',
#    'but',
#    'I',
#    "don't",
#    'know',
#    'if',
#    "he's",
#    'gonna',
#    'make',
#    'it',
#    '.',
#    ':('],
#   0),
#  (['We', 'would', 'anyway', 'with', 'them', 'in', 'there', ':-)'], 1),
#  (['Good',
#    'morning',
#    'Sharon',
#    '.',
#    'I',
#    'really',
#    'hope',
#    'she',
#    'is',
#    'doing',
#    'better',
#    'today',
#    'too',
#    '&',
#    'that',
#    'her',
#    'medicines',
#    'works',
#    '.',
#    'Thank',
#    'you',
#    ',',
#    'I',
#    'will',
#    ':)',
#    'ttyl',
#    'x'],
#   1),
#  (['SICK', ':('], 0),
#  (['happy',
#    'belated',
#    'birthday',
#    'cikaaa',
#    '☺',
#    'wish',
#    'you',
#    'all',
#    'the',
#    'best',
#    'o',
#    ':)',
#    'maaf',
#    'telat',
#    'ngucapinnya',
#    ':D'],
#   1),
#  (['Stats',
#    'for',
#    'the',
#    'day',
#    'have',
#    'arrived',
#    '.',
#    '1',
#    'new',
#    'follower',
#    'and',
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/lrUwXe378i',
#    '.'],
#   1),
#  (['Is',
#    'that',
#    'Stargate',
#    'Atlantis',
#    '?',
#    'Such',
#    'a',
#    'cool',
#    'show',
#    ':)'],
#   1),
#  (['Puff',
#    'pastry',
#    'egg',
#    'tarts',
#    '.',
#    'Hot',
#    'and',
#    'fresh',
#    'from',
#    'the',
#    'oven',
#    '.',
#    ':)',
#    '@',
#    'Wan',
#    'Chai',
#    'MTR',
#    'https://t.co/HLkgHwatJM'],
#   1),
#  (['eat', 'and', 'rest', 'well', ':(', "you're", 'too', 'tired', '..'], 0),
#  (['Reply', 'please', 'antagal', ':('], 0),
#  (['an', 'already', 'clutching', 'shit', '...', 'foh', 'homie', ':)'], 1),
#  (['tbh', 'idk', ':(', 'ask', 'around'], 0),
#  (['Cricket',
#    'World',
#    'Cup',
#    ',',
#    'Asian',
#    'cup',
#    'state',
#    'of',
#    'origin',
#    '...',
#    'now',
#    'this',
#    '?',
#    '!',
#    'Wow',
#    'Matt',
#    'is',
#    'a',
#    'lucky',
#    'boy',
#    ':-)',
#    'have',
#    'fun',
#    '!'],
#   1),
#  (['Is', 'everyone', 'talking', 'about', 'rat', 'boy', 'today', 'bc', ':('],
#   0),
#  (['Hello', ':)', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', '>', '>'],
#   1),
#  (['rosidbinr', 'Follback', 'ya', ':)'], 1),
#  (['Hi',
#    'BAM',
#    '!',
#    'Can',
#    'you',
#    'follow',
#    'my',
#    'bestfriend',
#    '?',
#    'She',
#    'loves',
#    'you',
#    'a',
#    'lot',
#    ':)',
#    'See',
#    'you',
#    'in',
#    'Warsaw',
#    '<3',
#    'Love',
#    'you',
#    '<3',
#    'x18'],
#   1),
#  (["it's",
#    'not',
#    'my',
#    'hands',
#    'or',
#    'incorrect',
#    'spelling',
#    '.',
#    "I'm",
#    'just',
#    'the',
#    'apologist',
#    ':D'],
#   1),
#  (['The',
#    'night',
#    'when',
#    'everybody',
#    'starts',
#    'to',
#    'remember',
#    'they',
#    'have',
#    'homework',
#    'that',
#    'is',
#    'due',
#    'tomorrow',
#    '...',
#    ':('],
#   0),
#  (['my',
#    'eyes',
#    'want',
#    'to',
#    'sleep',
#    'but',
#    'the',
#    'rest',
#    'of',
#    'me',
#    "doesn't",
#    '.',
#    ':(',
#    'This',
#    'is',
#    'bad',
#    '.'],
#   0),
#  (['PLEASE', 'FOLLOW', 'ME', ':('], 0),
#  (['spoile', ':)'], 1),
#  (["that's",
#    'true',
#    ':-(',
#    "it's",
#    'trying',
#    'to',
#    'get',
#    'rid',
#    'of',
#    'Katie',
#    'Hopkins',
#    'to',
#    'no',
#    'avail'],
#   0),
#  (['Username', 'Changed', '!', ':D'], 1),
#  (['me', 'too', ':)', ')'], 1),
#  (['I',
#    'had',
#    'three',
#    'dreams',
#    'last',
#    'night',
#    'and',
#    'the',
#    'one',
#    'I',
#    "don't",
#    'want',
#    'to',
#    'remember',
#    'I',
#    'do',
#    'and',
#    'the',
#    'two',
#    'I',
#    'want',
#    'to',
#    'remember',
#    'I',
#    "don't",
#    ':('],
#   0),
#  (['whats', 'wrong', '?', ':('], 0),
#  (['i', 'miss', 'you', 'to', 'death', ':(', '(', 'http://t.co/7Hal7PTTAN'], 0),
#  (['make', 'me', 'smile', ':(', '('], 0),
#  (['yes',
#    "that's",
#    'a',
#    'scary',
#    'sight',
#    'seeing',
#    'frail',
#    'people',
#    'in',
#    'cars',
#    '.',
#    "It's",
#    'a',
#    'lottery',
#    'riding',
#    'near',
#    'those',
#    'people',
#    ',',
#    'I',
#    'always',
#    'hold',
#    'my',
#    'breath',
#    ':('],
#   0),
#  (['They',
#    'sure',
#    'do',
#    ',',
#    'esp',
#    'now',
#    'when',
#    'ppl',
#    'are',
#    'talking',
#    'crap',
#    'about',
#    'Millie',
#    '!',
#    '!',
#    '>:(',
#    "I'll",
#    'go',
#    'straight',
#    'to',
#    'that',
#    'FB',
#    'page',
#    ':)'],
#   0),
#  (['follow', '&', 'http://t.co/RCvcYYO0Iq', 'follow', 'u', 'back', ':)'], 1),
#  (["I'm",
#    'craving',
#    'breakfast',
#    'food',
#    'so',
#    'badly',
#    'right',
#    'now',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['i', 'guess', 'im', 'arresting', 'my', 'girlfriend', ':(', '('], 0),
#  (['Usually',
#    'just',
#    'a',
#    'high',
#    'stool',
#    'with',
#    'three',
#    'kids',
#    'waiting',
#    'for',
#    'me',
#    'to',
#    'topple',
#    'over',
#    '.',
#    ':D'],
#   1),
#  (['Bad',
#    'Boys',
#    ':)',
#    '#burgers',
#    '#melbourneburgers',
#    'https://t.co/TyD88wr40d'],
#   1),
#  (['Excited',
#    'about',
#    'the',
#    'Chalkhill',
#    'Park',
#    'Celebration',
#    'tomorrow',
#    'from',
#    'midday',
#    '.',
#    'Come',
#    'join',
#    'the',
#    'fun',
#    ':-)'],
#   1),
#  ([':(', 'maybe', 'ill', 'surprise', 'you', 'and', 'be', 'brill'], 0),
#  (['baby', 'Im', 'worth', 'it', 'uhuh', ':)', '🎵', '🎵', '🎵'], 1),
#  (['no', 'probs', ':-)', 'ill', 'message', 'you', 'xx'], 1),
#  (['Not',
#    'looking',
#    'forward',
#    'to',
#    'this',
#    'night',
#    'shift',
#    'tonight',
#    ':('],
#   0),
#  (['MY', 'STREAM', 'IS', 'SO', 'PIXELATED', ':(', '(', '('], 0),
#  (['!',
#    '#MasaanToday',
#    '#MasaanToday',
#    'A4',
#    '...',
#    'Shweta',
#    'Tripathi',
#    '!',
#    '#MasaanToday',
#    '#MasaanToday',
#    '-',
#    '.',
#    ':-)',
#    '.',
#    '-',
#    '..',
#    ','],
#   1),
#  (['I', 'got', 'delayed', 'by', 'guests', '.', 'Sigh', ':('], 0),
#  (['Hey',
#    'Fam',
#    '!',
#    'Vote',
#    'for',
#    'if',
#    'you',
#    "haven't",
#    'already',
#    ':)',
#    'WE',
#    'GOTTA',
#    'WIN',
#    'THIS',
#    'FOR',
#    'OUR',
#    'BOYS',
#    '!',
#    '#TeenChoice',
#    '-',
#    'S',
#    'http://t.co/zBZvXC0v5y'],
#   1),
#  (['Hi',
#    'BAM',
#    '!',
#    'Can',
#    'you',
#    'follow',
#    'my',
#    'bestfriend',
#    '?',
#    'She',
#    'loves',
#    'you',
#    'a',
#    'lot',
#    ':)',
#    'See',
#    'you',
#    'in',
#    'Warsaw',
#    '<3',
#    'Love',
#    'you',
#    '<3',
#    'x33'],
#   1),
#  (['I',
#    'want',
#    'a',
#    'flipping',
#    'Belgium',
#    'waffle',
#    'thrown',
#    'in',
#    'my',
#    'face',
#    ':('],
#   0),
#  (['#다쇼', '#GOT7', "Let's", 'have', 'got', '7', 'facts', ':)'], 1),
#  (["Let's", 'do', 'this', 'again', ':)', 'http://t.co/fa56o6DOlq'], 1),
#  (['Maybe',
#    'a',
#    'younger',
#    'woman',
#    'has',
#    'more',
#    'stamina',
#    'than',
#    'you',
#    'Tom',
#    '>',
#    ':)'],
#   1),
#  (['Gn', ':)', 'Jesus', 'loves', 'u', 'all'], 1),
#  (["I've",
#    'not',
#    'been',
#    'to',
#    'your',
#    'beer',
#    'talks',
#    'but',
#    "I'd",
#    'say',
#    'that',
#    'having',
#    '2',
#    'broken',
#    'arms',
#    'is',
#    'more',
#    'of',
#    'a',
#    'issue',
#    'than',
#    'being',
#    'being',
#    '1',
#    'testicle',
#    'light',
#    ':)'],
#   1),
#  (['New', 'shoes', 'please', ':('], 0),
#  (["That's", 'great', 'to', 'hear', ':D'], 1),
#  (['I',
#    'can',
#    'also',
#    'provide',
#    'this',
#    ',',
#    'just',
#    'pop',
#    'over',
#    'to',
#    'my',
#    'office',
#    'and',
#    "i'll",
#    'provide',
#    'the',
#    'required',
#    'service',
#    ',',
#    'with',
#    'a',
#    'smile',
#    '!',
#    ':D'],
#   1),
#  (['omg',
#    ':(',
#    'every',
#    'time',
#    'I',
#    'would',
#    'complain',
#    'about',
#    'my',
#    'skin',
#    'to',
#    'my',
#    'mom',
#    'she',
#    'was',
#    'all',
#    '"',
#    'everyone',
#    'gets',
#    'pimples',
#    '"',
#    'like',
#    'NO',
#    'they',
#    "don't",
#    '.',
#    'although',
#    'she'],
#   0),
#  (['Yes',
#    '!',
#    'Bath',
#    'Bombs',
#    'are',
#    'back',
#    'two',
#    'great',
#    'new',
#    'products',
#    '!',
#    'I',
#    "can't",
#    'wait',
#    'to',
#    'order',
#    'mine',
#    ':)',
#    'Whip',
#    'me',
#    'up',
#    'Bag',
#    'of',
#    'Bombs',
#    '...',
#    'http://t.co/lvWKZFdFW8'],
#   1),
#  (['Everything', 'and', 'all', ':('], 0),
#  (["Here's",
#    'a',
#    'cute',
#    'panda',
#    'to',
#    'make',
#    'your',
#    'day',
#    '!',
#    ':)',
#    'http://t.co/WRhMpnLpq3',
#    'http://t.co/RsCxtwKaeI'],
#   1),
#  (['Why', 'no', 'Bangalore', '?', ':('], 0),
#  (['guess',
#    "who's",
#    'spent',
#    'half',
#    'an',
#    'hr',
#    'sitting',
#    'outside',
#    'her',
#    'apt',
#    'building',
#    'bc',
#    'she',
#    'left',
#    'her',
#    'keys',
#    'at',
#    'work',
#    '?',
#    'I',
#    'hope',
#    'someone',
#    'needs',
#    'to',
#    'leave',
#    'this',
#    'bldg',
#    'soon',
#    ':('],
#   0),
#  (['because', 'you', "don't", 'like', 'me', ':(', '('], 0),
#  ([':)',
#    'Good',
#    'Afternoon',
#    ':D',
#    '#TwitterFollowersWhatsUp',
#    '#HappyFriedDay',
#    '#KeepSafeAlways',
#    '#LoveYeah',
#    '#emojasp_here'],
#   1),
#  (['No',
#    'specific',
#    'dates',
#    ',',
#    'just',
#    'whenever',
#    'we',
#    'catch',
#    'each',
#    'other',
#    ':('],
#   0),
#  (['😫',
#    '<--',
#    'this',
#    'has',
#    'to',
#    'be',
#    'the',
#    'face',
#    'every',
#    'guy',
#    'pull',
#    'when',
#    'getting',
#    'head',
#    'but',
#    'can',
#    'feel',
#    'your',
#    "bae's",
#    'teeth',
#    'in',
#    'his',
#    'dick',
#    ':('],
#   0),
#  (['Am',
#    'I',
#    'the',
#    'one',
#    'whos',
#    'dont',
#    'see',
#    'sinse',
#    'to',
#    'trend',
#    'something',
#    'like',
#    'thats',
#    '?',
#    ':(',
#    '#ZaynIsComingBackOnJuly26'],
#   0),
#  (['our',
#    'pleasure',
#    '!',
#    'Let',
#    'us',
#    'know',
#    'if',
#    "there's",
#    'anything',
#    'else',
#    'you',
#    'need',
#    ':)'],
#   1),
#  (['"',
#    ':',
#    'I',
#    'miss',
#    'Chris',
#    "'",
#    'voice',
#    ':(',
#    '"',
#    'same',
#    'http://t.co/5houV3sq5l'],
#   0),
#  (['Makes', 'me', 'sad', 'he', 'has', 'to', 'go', 'back', ':(', '(', '('], 0),
#  (['Belgium', ':('], 0),
#  (['idk',
#    'but',
#    'cant',
#    'wait',
#    'for',
#    'tonights',
#    'panel',
#    'to',
#    'be',
#    'up',
#    'for',
#    'people',
#    ':)'],
#   1),
#  (['#am', 'saran', 'drama', 'genre', 'romance', 'comedy', '?', '?', ':)'], 1),
#  (['U',
#    'should',
#    'rather',
#    'be',
#    'finding',
#    'the',
#    '"',
#    'BESTS',
#    '"',
#    'of',
#    'a',
#    'person',
#    'than',
#    'finding',
#    'WORSTS',
#    ',',
#    'this',
#    'makes',
#    'ur',
#    'life',
#    'easy',
#    'n',
#    'the',
#    'others',
#    'too',
#    '#WayToLiveAHappyLife',
#    ':)'],
#   1),
#  (['Need',
#    'a',
#    'small',
#    'lady',
#    'to',
#    'walk',
#    'over',
#    'my',
#    'back',
#    '.',
#    'So',
#    'sore',
#    '...',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['all', 'greatly', 'appreciated', '!', ':)'], 1),
#  (['Easier', 'said', 'than', 'done', ':(', 'https://t.co/7HTgd85HfF'], 0),
#  (['Everything',
#    'in',
#    'the',
#    'kids',
#    'section',
#    'of',
#    'IKEA',
#    'is',
#    'so',
#    'cute',
#    '.',
#    'Shame',
#    "I'm",
#    'nearly',
#    '19',
#    'in',
#    '2',
#    'months',
#    ':('],
#   0),
#  (['Great', 'work', 'Matt', ':)'], 1),
#  ([':)', 'Thanks'], 1),
#  (['yup',
#    '.',
#    'i',
#    'think',
#    'so',
#    'too',
#    '.',
#    'gotta',
#    'avoid',
#    'BB',
#    'and',
#    'IC',
#    '.',
#    'I',
#    'really',
#    'hope',
#    'they',
#    'have',
#    'a',
#    'repack',
#    ':('],
#   0),
#  (['MIGHT', '?', ':-('], 0),
#  (['I',
#    'keep',
#    'forgetting',
#    "you're",
#    'in',
#    'the',
#    'area',
#    '.',
#    ':-(',
#    'but',
#    'want',
#    'to',
#    'visit',
#    '.',
#    'Next',
#    'time',
#    'xx'],
#   0),
#  (['Stats',
#    'for',
#    'the',
#    'week',
#    'have',
#    'arrived',
#    '.',
#    '1',
#    'new',
#    'follower',
#    'and',
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/dRArgTzKeh',
#    '.'],
#   1),
#  (['Emotionally', 'tired', ':(', '(', '('], 0),
#  (['Again', 'not', 'feeling', 'well', ':('], 0),
#  (['If', 'you', 'see', '#ZephBot', ',', 'this', 'is', 'a', 'bot', ':p'], 1),
#  (["You're", 'a', 'judgmental', 'hypocritical', 'narcissist', ':-)'], 1),
#  (['Welcome',
#    'to',
#    'pop',
#    'heaven',
#    '.',
#    "We're",
#    'glad',
#    "you're",
#    'enjoying',
#    'it',
#    '!',
#    ':)'],
#   1),
#  (['Nakakapikon',
#    'yung',
#    'nagbabasa',
#    'ka',
#    'ng',
#    'blog',
#    'comments',
#    'for',
#    'info',
#    'and',
#    "it's",
#    'full',
#    'of',
#    'people',
#    'asking',
#    'the',
#    'same',
#    'damned',
#    'questions',
#    'answered',
#    'in',
#    'the',
#    'post',
#    '.',
#    ':('],
#   0),
#  (['The',
#    'Nixus',
#    'adventure',
#    'has',
#    'begun',
#    ':-)',
#    'time',
#    'to',
#    'make',
#    'some',
#    'flint',
#    'tools',
#    'haha'],
#   1),
#  (['I',
#    'want',
#    'to',
#    'be',
#    'friends',
#    'with',
#    'them',
#    'and',
#    'go',
#    'to',
#    'concerts',
#    ':(',
#    '(',
#    '(',
#    'http://t.co/TtBSmyLS2N'],
#   0),
#  (['Lemme',
#    'know',
#    'if',
#    'you',
#    'ever',
#    'want',
#    'any',
#    'more',
#    'recs',
#    '.',
#    'Likewise',
#    ',',
#    "I'm",
#    'always',
#    'open',
#    'to',
#    'expanding',
#    'my',
#    'inaccessible',
#    'music',
#    'library',
#    ':D'],
#   1),
#  (['"',
#    'I',
#    'know',
#    'you',
#    'said',
#    'this',
#    'is',
#    'Michael',
#    'Jackson',
#    ',',
#    'but',
#    'this',
#    'is',
#    'obviously',
#    'a',
#    'little',
#    'boy',
#    '"',
#    '-',
#    'my',
#    'little',
#    'brother',
#    'while',
#    'listening',
#    'to',
#    'a',
#    'Jackson',
#    '5',
#    'song',
#    ':('],
#   0),
#  (['Goodmorning',
#    '.',
#    'Just',
#    'smile',
#    'through',
#    'the',
#    'debit',
#    'orders',
#    ':)',
#    'it',
#    'will',
#    'all',
#    'soon',
#    'be',
#    'over',
#    '.'],
#   1),
#  (['hi',
#    'we',
#    'made',
#    'some',
#    'changes',
#    'in',
#    'our',
#    'design',
#    ',',
#    'hope',
#    'you',
#    'like',
#    'it',
#    ':)',
#    'https://t.co/EXt098Yq1b'],
#   1),
#  (['On',
#    'this',
#    'one',
#    'constructive',
#    'criticism',
#    'welcomed',
#    ':)',
#    '#ganesha',
#    '#texture',
#    '#photography',
#    '#art',
#    '#hinduism',
#    '#hindugod',
#    '#elephantgod',
#    'http://t.co/QFhF2zUKib'],
#   1),
#  (['Abby',
#    'can',
#    'you',
#    'please',
#    'try',
#    'help',
#    'me',
#    'get',
#    'my',
#    'mum',
#    'to',
#    'come',
#    'see',
#    'you',
#    'with',
#    'me',
#    'in',
#    'London',
#    '!',
#    ':('],
#   0),
#  (['Absolutely', 'True', ':)', ':)', ':)'], 1),
#  (['I',
#    'have',
#    'been',
#    'a',
#    'customer',
#    'for',
#    '20',
#    'years',
#    '.',
#    'My',
#    'Internet',
#    'is',
#    'no',
#    'why',
#    'near',
#    'the',
#    'speed',
#    'it',
#    'should',
#    'be',
#    '.',
#    "It's",
#    'so',
#    'so',
#    'slow',
#    ':('],
#   0),
#  (['my',
#    'pleasure',
#    'doll',
#    '!',
#    'Thank',
#    'you',
#    'for',
#    'your',
#    'wonderful',
#    'energy',
#    'in',
#    'class',
#    '!',
#    ':)'],
#   1),
#  (['hi',
#    'jenna',
#    '.',
#    ':-)',
#    'can',
#    'I',
#    'ask',
#    'is',
#    'your',
#    '#BellyButton',
#    'an',
#    '#Innie',
#    'or',
#    'an',
#    '#Outie',
#    '?'],
#   1),
#  (['we', 'will', 'reunite', 'again', 'one', 'day', ':('], 0),
#  (['My', 'summer', 'sleep', 'schedule', 'is', 'back', ':(', '(', '('], 0),
#  (['im',
#    'thankful',
#    'to',
#    'have',
#    'someone',
#    'like',
#    'you',
#    'in',
#    'my',
#    'life',
#    'to',
#    'inspire',
#    'me',
#    'to',
#    'be',
#    'better',
#    'everyday',
#    '.',
#    'i',
#    'love',
#    'you',
#    ',',
#    'mind',
#    'following',
#    'me',
#    '?',
#    ':)'],
#   1),
#  (['eunji', ':(', '(', '(', 'so', 'pretty'], 0),
#  (['New', 'kit', 'is', 'not', 'looking', 'good', '...', 'Poor', '.', ':('], 0),
#  (['oh', 'shoot', ',', 'well', 'i', 'am', 'watching', 'it', 'now', ':D'], 1),
#  (['Just', 'let', 'us', 'know', 'the', 'best', 'address', 'for', 'you', ':)'],
#   1),
#  (['tylers', 'hipster', 'glasses', ':D'], 1),
#  (['lolzz', ',', 'unfortunately', 'dats', 'how', 'it', 'is', ':('], 0),
#  (['someone', 'mention', 'Usagi', '?', 'Looove', 'him', '!', '!', ':D'], 1),
#  (['I',
#    'have',
#    'exactly',
#    '6',
#    'mins',
#    'to',
#    'get',
#    'to',
#    'work',
#    'and',
#    'I',
#    'am',
#    'still',
#    'on',
#    'the',
#    'luas',
#    'right',
#    'now',
#    ':)'],
#   1),
#  (['i', 'was', 'in', 'it', ':('], 0),
#  (['Just',
#    'read',
#    'the',
#    '#SandraBland',
#    'story',
#    '.',
#    'Thats',
#    'so',
#    'scary',
#    ',',
#    'hope',
#    'the',
#    'truth',
#    'will',
#    'be',
#    'revealed',
#    ':('],
#   0),
#  (['its', 'up', ':D', 'http://t.co/9CEbRspBdJ'], 1),
#  (['I',
#    'just',
#    'watched',
#    'a',
#    'video',
#    'about',
#    'a',
#    'girl',
#    'being',
#    '"',
#    'allergic',
#    '"',
#    'to',
#    'the',
#    'sun',
#    ':(',
#    "that's",
#    'depressing'],
#   0),
#  (['Thanks', 'guys', '!', ':)'], 1),
#  (['Browse',
#    'our',
#    'funny',
#    'facts',
#    'if',
#    'you',
#    'are',
#    'bored',
#    ':)',
#    'http://t.co/6WLyQMJ2nl'],
#   1),
#  (['hahaha',
#    '...',
#    'and',
#    'thus',
#    '...',
#    'I',
#    'sneak',
#    'away',
#    'to',
#    'log',
#    'on',
#    'to',
#    '#niteflirt',
#    ':D'],
#   1),
#  (['Missyou', 'bishes', ':('], 0),
#  (['I',
#    'was',
#    'just',
#    'watching',
#    '"',
#    'A',
#    'baby',
#    'is',
#    'born',
#    '!',
#    '"',
#    'Episode',
#    'and',
#    'I',
#    "can't",
#    'help',
#    'but',
#    'think',
#    'is',
#    'sweet',
#    ',',
#    'kind',
#    ',',
#    'caring',
#    'and',
#    'has',
#    'had',
#    '5',
#    'kids',
#    '.',
#    'Keep',
#    'it',
#    'up',
#    ':)'],
#   1),
#  (['sure', '!', '!', '!', 'Sorry', ':(', 'x'], 0),
#  (['I', 'wish', 'I', "could've", 'met', 'you', ':('], 0),
#  (['That',
#    'awkward',
#    'moment',
#    'when',
#    'you',
#    'feel',
#    'that',
#    'you',
#    'got',
#    'abs',
#    'Because',
#    'you',
#    "can't",
#    'stop',
#    'laughing',
#    'reading',
#    "'",
#    's',
#    'tweets',
#    ':D'],
#   1),
#  (['Corbyn',
#    'must',
#    'understand',
#    "Labour's",
#    'new',
#    'members',
#    'to',
#    'change',
#    'the',
#    "party's",
#    'fortunes',
#    'http://t.co/7JhaSTESp8',
#    'And',
#    'yet',
#    'another',
#    'rant',
#    'from',
#    'this',
#    'woman',
#    ':('],
#   0),
#  (['Right',
#    'right',
#    '?',
#    '?',
#    ':(',
#    'We',
#    'will',
#    'always',
#    'have',
#    'good',
#    'memories',
#    'I',
#    'guess',
#    '.',
#    '😔'],
#   0),
#  (['noo', 'toni', 'deactivated', 'too', '?', '?', ':('], 0),
#  (['Long', 'distance', ':(', 'Why', '?', '💔'], 0),
#  (['With', 'them', ':)'], 1),
#  (['ha',
#    'ha',
#    '.',
#    'Ok',
#    'honey',
#    '.',
#    'Go',
#    'ahead',
#    '.',
#    'FYI',
#    '-',
#    'still',
#    'dig',
#    'ya',
#    '.',
#    'Enjoy',
#    'voting',
#    '.',
#    'And',
#    'then',
#    'watch',
#    'as',
#    'he',
#    'will',
#    'have',
#    'me',
#    'by',
#    'his',
#    'side',
#    ':)'],
#   1),
#  (['es',
#    'mi',
#    'tio',
#    ':)',
#    'you',
#    'know',
#    'its',
#    'a',
#    'must',
#    'to',
#    'follow',
#    'him',
#    'since',
#    "I'm",
#    'from',
#    'Sinaloa',
#    '..',
#    'Arre',
#    '!'],
#   1),
#  (['Thank', 'you', ':)'], 1),
#  (['New', 'bio', '.', 'Bodo', 'amat', ':-('], 0),
#  (['done', ',', 'please', 'me', ':('], 0),
#  (['thanks', 'for', 'following', ':)'], 1),
#  (['Ahahah', "I'll", 'do', 'that', 'too', '!', '!', '!', ':)'], 1),
#  (['That',
#    'lonely',
#    'moment',
#    'when',
#    'the',
#    'only',
#    'text',
#    'message',
#    'you',
#    'get',
#    'all',
#    'day',
#    'is',
#    'from',
#    'your',
#    'cell',
#    'phone',
#    'company',
#    '.',
#    ':('],
#   0),
#  (['AWW', 'BUT', 'ITS', 'OK', 'CUZ', 'WE', 'MAKE', 'MISTAKES', 'TOO', ':)'],
#   1),
#  (['it', 'keeps', 'better', 'and', 'better', 'every', 'update', ':)'], 1),
#  (['MY',
#    'snapchat',
#    '-',
#    'JillMill',
#    '19',
#    '#snapchat',
#    '#kikmeboys',
#    '#hot',
#    '#webcam',
#    '#teens',
#    '#elfindelmundo',
#    '#sexi',
#    ':)',
#    'http://t.co/HFYIeohQZv'],
#   1),
#  (['Boo', 'on', 'both', 'counts', ':-('], 0),
#  (['Just',
#    'hit',
#    'over',
#    '10,000',
#    'plays',
#    'of',
#    'my',
#    "'",
#    "'",
#    'Girlfriend',
#    "'",
#    "'",
#    'remix',
#    'https://t.co/POj6JqNvza',
#    ':)'],
#   1),
#  (['especially',
#    'when',
#    'you',
#    "don't",
#    'like',
#    'it',
#    ':(',
#    'I',
#    "can't",
#    'do',
#    'the',
#    'same',
#    'song',
#    'over',
#    'and',
#    'over',
#    'again',
#    ':/'],
#   0),
#  (['even',
#    'on',
#    'nate',
#    'i',
#    'think',
#    ':(',
#    '(',
#    'they',
#    'dropped',
#    'places',
#    'already'],
#   0),
#  (['So',
# ...
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/MfsVECw1bW',
#    '.'],
#   1),
#  (['Witnessed',
#    '!',
#    '#family',
#    '#trip',
#    'to',
#    '#goa',
#    ':(',
#    'https://t.co/u13lmgymTH'],
#   0),
#  (['what', 'about', 'me', '?', ':(', '#EidWithGrofers'], 0),
#  (['Jgh',
#    'bonding',
#    'with',
#    'ma',
#    'niggs',
#    ':)',
#    ')',
#    'http://t.co/7uiVxbZNMp'],
#   1),
#  (['We', "won't", 'delve', 'in', 'to', 'that', 'here', ':)'], 1),
#  (['Fall',
#    'in',
#    'love',
#    'under',
#    'a',
#    'canopy',
#    'of',
#    'maple',
#    'leaves',
#    '!',
#    'Secrets',
#    'at',
#    'Maple',
#    'Syrup',
#    'Farm',
#    'is',
#    'out',
#    'now',
#    ':)',
#    'Happy',
#    'Friday',
#    ',',
#    'all',
#    '!',
#    'xx',
#    'http://t.co/fQeQlpk32A'],
#   1),
#  (['@commonculture',
#    '@connorfranta',
#    'honestly',
#    "I've",
#    'no',
#    'idea',
#    'about',
#    'what',
#    'this',
#    'thing',
#    'is',
#    ',',
#    'could',
#    'you',
#    'explain',
#    'me',
#    '?',
#    ':)'],
#   1),
#  (['5SOS',
#    'Calum',
#    '5SOS',
#    'Luke',
#    '5SOS',
#    'Ashton',
#    '5SOS',
#    'Hey',
#    'guys',
#    '!',
#    'PLEASE',
#    'follow',
#    '✧',
#    '｡',
#    'Chelny',
#    '｡',
#    '✧',
#    ':)'],
#   1),
#  (['Sure',
#    'mate',
#    'i',
#    'will',
#    "don't",
#    'worry',
#    ':D',
#    'thanks',
#    '!',
#    'https://t.co/H5bWUM9S3u'],
#   1),
#  (['Thanks',
#    'to',
#    'everyone',
#    'who',
#    'came',
#    'to',
#    'the',
#    'show',
#    'and',
#    'tipped',
#    ':)',
#    'http://t.co/fZHtA3JEnq'],
#   1),
#  (['Update',
#    ':',
#    'just',
#    'finished',
#    'packing',
#    'and',
#    'now',
#    'the',
#    'fly',
#    'is',
#    'stuck',
#    'in',
#    'my',
#    'room',
#    ':)',
#    ')',
#    ')'],
#   1),
#  (['same', ':('], 0),
#  (["that's", 'the', 'spirit', ':)', '#WsaleLove'], 1),
#  (['Im', 'watching', 'disney', 'channel', 'by', 'myself', ':('], 0),
#  (['So',
#    'this',
#    'Canadian',
#    'family',
#    'had',
#    'the',
#    'best',
#    'dinner',
#    'of',
#    'their',
#    'holiday',
#    'last',
#    'night',
#    '.',
#    'Well',
#    'done',
#    '!',
#    'Enjoyed',
#    'ours',
#    'too',
#    'but',
#    "we're",
#    'not',
#    'on',
#    'holiday',
#    ':('],
#   0),
#  (['You', 'drank', 'because', 'of', 'it', '?', ':)'], 1),
#  (['#tracerequest', 'with', 'my', 'homie', 'dassy', '!', 'Fwm', '!', ':D'], 1),
#  (['Only', 'because', "it's", 'Friday', '...', ':D'], 1),
#  (['I',
#    'seem',
#    'to',
#    'have',
#    'burned',
#    'everything',
#    'apart',
#    'from',
#    'the',
#    'tea',
#    'this',
#    'morning',
#    '.',
#    'Bravo',
#    'Friday',
#    'to',
#    'you',
#    'too',
#    ',',
#    'Richard',
#    '.',
#    ':-('],
#   0),
#  (['I',
#    'just',
#    'wanna',
#    'go',
#    'to',
#    'your',
#    'house',
#    'rn',
#    'and',
#    'give',
#    'you',
#    'a',
#    'big',
#    'big',
#    'hug',
#    '.',
#    ':(',
#    '(',
#    '('],
#   0),
#  (['just',
#    'want',
#    'to',
#    'play',
#    'video',
#    'games',
#    '/',
#    'watch',
#    'movies',
#    'with',
#    'someone',
#    ':('],
#   0),
#  (['Jk',
#    'I',
#    'have',
#    'lots',
#    'of',
#    'people',
#    'to',
#    'chat',
#    'with',
#    'so',
#    'ha',
#    ':-)',
#    ')',
#    ')'],
#   1),
#  (['please', 'read', 'and', 'reply', 'my', 'dm', 'please', '..', ':)'], 1),
#  (['oh',
#    'gosh',
#    'what',
#    'did',
#    'you',
#    'say',
#    '?',
#    'And',
#    'aw',
#    'hun',
#    ':(',
#    '*',
#    'cuddles',
#    '*'],
#   0),
#  (['Finally',
#    'got',
#    'some',
#    'time',
#    'to',
#    'catch',
#    'up',
#    'on',
#    'games',
#    '..',
#    'Wish',
#    'i',
#    'could',
#    'say',
#    '"',
#    'Let',
#    'the',
#    'games',
#    'begin',
#    '"',
#    '...',
#    'sigh',
#    '*',
#    '..',
#    'PS3',
#    "isn't",
#    'working',
#    ':(',
#    'http://t.co/nwriRgSq8v'],
#   0),
#  (['I',
#    'forget',
#    'every',
#    'year',
#    'why',
#    'the',
#    'summer',
#    'hols',
#    'are',
#    'so',
#    'hard',
#    '...',
#    'I',
#    'spend',
#    'days',
#    '&',
#    'days',
#    'never',
#    'really',
#    'having',
#    'conversations',
#    'with',
#    'grown',
#    'ups',
#    ':(',
#    '#isolated'],
#   0),
#  (['Stats',
#    'for',
#    'the',
#    'week',
#    'have',
#    'arrived',
#    '.',
#    '3',
#    'new',
#    'followers',
#    'and',
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/VHA72j8cqp',
#    '.'],
#   1),
#  (['UGH',
#    ',',
#    'I',
#    'JUST',
#    'WANT',
#    'TO',
#    'BE',
#    'WITH',
#    'YOU',
#    'RIGHT',
#    'HERE',
#    'AND',
#    'RIGHT',
#    'NOW',
#    ',',
#    'I',
#    'NEED',
#    'YA',
#    'TAY',
#    '.',
#    'You',
#    'are',
#    'the',
#    'only',
#    'one',
#    'who',
#    'understands',
#    'me',
#    '.',
#    ':('],
#   0),
#  (['i',
#    'will',
#    'not',
#    'cast',
#    'my',
#    'vote',
#    'in',
#    'next',
#    'elections',
#    ':)',
#    '#JCReport'],
#   1),
#  (['I',
#    'just',
#    'wanna',
#    'see',
#    'her',
#    'face',
#    'again',
#    ',',
#    'I',
#    'miss',
#    'her',
#    'so',
#    'much',
#    ':(',
#    'in',
#    '2',
#    'years',
#    'hopefully',
#    'http://t.co/uCSqlApqoX'],
#   0),
#  (['Cheers', 'Mike', '-', 'love', 'the', 'pics', ':)'], 1),
#  (["I'm",
#    'fucking',
#    'great',
#    ',',
#    'fuck',
#    'you',
#    'if',
#    'you',
#    'think',
#    'less',
#    'of',
#    'me',
#    ':-)'],
#   1),
#  (['being',
#    'told',
#    'im',
#    'gorgeous',
#    'on',
#    'my',
#    'extremely',
#    'sweaty',
#    'walk',
#    'into',
#    'work',
#    'has',
#    'made',
#    'my',
#    'day',
#    ':)'],
#   1),
#  (['u', 'never', 'call', ':('], 0),
#  (['“',
#    ':',
#    'oh',
#    'poor',
#    'baby',
#    ':(',
#    '😁',
#    'https://t.co/JQwjFTnppG',
#    '”',
#    '😭'],
#   0),
#  (['If',
#    'going',
#    'to',
#    'stop',
#    'breakfast',
#    'early',
#    'you',
#    'might',
#    'want',
#    'to',
#    'remove',
#    'the',
#    '11am',
#    'from',
#    'your',
#    'website',
#    '.',
#    'Even',
#    "McD's",
#    "doesn't",
#    'pull',
#    'that',
#    'trick',
#    '.',
#    ':('],
#   0),
#  (['Bye',
#    'Wellington',
#    ',',
#    "you've",
#    'been',
#    'awesome',
#    ',',
#    'I',
#    'hope',
#    'we',
#    'meet',
#    'again',
#    '.',
#    ':)',
#    'http://t.co/m7p3IvKggR'],
#   1),
#  (['#FridayDownpour',
#    '-',
#    'hope',
#    'it',
#    'clears',
#    'for',
#    'the',
#    'wkend',
#    ',',
#    'have',
#    'a',
#    'good',
#    'one',
#    ':)'],
#   1),
#  (['okay', 'i', 'miss', 'you', ':(', '(', 'http://t.co/So3zOCWfiA'], 0),
#  (['Hell',
#    'yes',
#    '!',
#    '!',
#    'Will',
#    'be',
#    'at',
#    'Donington',
#    'Park',
#    'on',
#    '24/25',
#    'hoping',
#    'to',
#    'see',
#    'you',
#    'and',
#    'the',
#    'team',
#    'again',
#    '!',
#    'Season',
#    '2',
#    'is',
#    'OURS',
#    ':D'],
#   1),
#  (['rm35', 'but', 'still', 'can', 'negooo', ',', 'male', ':)'], 1),
#  (['My', 'God', ':(', ':(', ':(', 'https://t.co/daFvzOR5qt'], 0),
#  (['Retweet', 'this', 'pleaaase', ':(', '(', '(', '👆🏻', '👆🏻'], 0),
#  (['yeah',
#    ',',
#    "that's",
#    'why',
#    "'",
#    'last',
#    'time',
#    "'",
#    '.',
#    'They',
#    'were',
#    'planning',
#    'to',
#    'file',
#    'police',
#    'complaint',
#    '.',
#    'So',
#    'much',
#    'yelling',
#    '.',
#    'Can',
#    'we',
#    'switch',
#    'places',
#    '?',
#    ':('],
#   0),
#  (['How',
#    'unlucky',
#    'would',
#    'it',
#    'be',
#    'if',
#    'I',
#    'was',
#    'dying',
#    'and',
#    'passed',
#    'away',
#    'just',
#    'before',
#    'ed',
#    'came',
#    'on',
#    'stage',
#    '#',
#    ':-('],
#   0),
#  ([':',
#    '3',
#    '!',
#    'Good',
#    'nigth',
#    ':)',
#    ':',
#    'estoy',
#    'escuchando',
#    'a',
#    'Enemy',
#    'of',
#    'God'],
#   1),
#  (['Everyone',
#    'should',
#    'go',
#    'drop',
#    'a',
#    'follow',
#    'on',
#    'her',
#    'stream',
#    ':D',
#    'http://t.co/WMAZJqO51K'],
#   1),
#  (["You'll", 'be', 'this', 'old', 'one', 'day', '...', ':('], 0),
#  (['Stomachache',
#    'bc',
#    'of',
#    'a',
#    'slice',
#    'of',
#    'cake',
#    '_',
#    ':(',
#    '´',
#    'ཀ',
#    '`',
#    '」',
#    '∠',
#    '):',
#    '_',
#    '…'],
#   0),
#  (['So', 'Im', 'going', 'to', 'sleep', 'Goodnight', ':)'], 1),
#  (['something', 'great', 'is', 'playing', '.', 'PERFECT', '!', '!', '!', ':('],
#   0),
#  (['Nowt', 'worse', 'than', 'a', 'sad', 'looking', 'willy', ':('], 0),
#  (['please',
#    '?',
#    'If',
#    'its',
#    'okay',
#    'tho',
#    '.',
#    'Its',
#    'just',
#    'sooo',
#    'sooo',
#    'hard',
#    'to',
#    'get',
#    'a',
#    'follow',
#    'from',
#    'him',
#    ':('],
#   0),
#  (['number', '13', ':('], 0),
#  (['o', 'otp', ':(', 'http://t.co/EVislmNp5V'], 0),
#  (['Stats',
#    'for',
#    'the',
#    'day',
#    'have',
#    'arrived',
#    '.',
#    '1',
#    'new',
#    'follower',
#    'and',
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/CcAoyyAGJ7',
#    '.'],
#   1),
#  (['go',
#    'sleep',
#    "don't",
#    'stay',
#    'up',
#    'for',
#    'the',
#    'entire',
#    'thing',
#    'u',
#    'can',
#    'do',
#    'more',
#    'tmw',
#    '!',
#    'uwu',
#    '...',
#    'well',
#    'the',
#    'younger',
#    'jinki',
#    'and',
#    'older',
#    'taems',
#    'one',
#    ':(',
#    '(',
#    '(',
#    'all',
#    'those',
#    'gifs'],
#   0),
#  (['can',
#    'you',
#    'please',
#    'follow',
#    'me',
#    '♡',
#    '♡',
#    '♡',
#    'please',
#    'jb',
#    'follow',
#    'me',
#    'I',
#    'love',
#    'you',
#    'always',
#    'and',
#    'forever',
#    '.',
#    "I'm",
#    'a',
#    'belieber',
#    '♡',
#    '♡',
#    '♡',
#    ':)',
#    'I',
#    'love',
#    'u'],
#   1),
#  (['#StarSquad',
#    '⭐',
#    'Can',
#    'I',
#    'get',
#    'a',
#    'follow',
#    '?',
#    'Please',
#    'Vikk',
#    'I',
#    'fna',
#    ':)'],
#   1),
#  (['Can',
#    'not',
#    'get',
#    'on',
#    '#hypixel',
#    ':(',
#    'want',
#    'to',
#    'record',
#    'grrr',
#    '#thestruggleisreal',
#    '#geek',
#    '#gamer',
#    '#gamers',
#    '#youtube'],
#   0),
#  (['So',
#    'cold',
#    'here',
#    'in',
#    'the',
#    'office',
#    'huhu',
#    ':(',
#    'No',
#    'more',
#    'tasks',
#    'to',
#    'do',
#    'but',
#    "I'll",
#    'be',
#    'here',
#    'until',
#    '9pm',
#    'hahaah',
#    '!',
#    '!'],
#   0),
#  (['nope', 'nope', ',', "it's", 'better', 'to', 'keep', 'quiet', ':)'], 1),
#  (['♛',
#    '♛',
#    '♛',
#    '》',
#    '》',
#    '》',
#    'I',
#    'LOVE',
#    'YOU',
#    'SO',
#    'MUCH',
#    '.',
#    'I',
#    'BELİEVE',
#    'THAT',
#    'HE',
#    'WİLL',
#    'FOLLOW',
#    '.',
#    'PLEASE',
#    'FOLLOW',
#    'ME',
#    'PLEASE',
#    'JUSTİN',
#    ':(',
#    'x15',
#    '.',
#    '348',
#    '》',
#    '》',
#    '》',
#    'ＳＥＥ',
#    'ＭＥ',
#    '♛',
#    '♛',
#    '♛'],
#   0),
#  (['#FollowFriday',
#    'for',
#    'being',
#    'top',
#    'influencers',
#    'in',
#    'my',
#    'community',
#    'this',
#    'week',
#    ':)'],
#   1),
#  (['Have',
#    'a',
#    'full',
#    'breakdown',
#    'of',
#    'the',
#    'materials',
#    'used',
#    'for',
#    'Thorin',
#    'now',
#    '.',
#    ':D',
#    'Time',
#    'to',
#    'hunt',
#    'down',
#    'the',
#    'materials',
#    'and',
#    'work',
#    'myself',
#    'through',
#    'the',
#    'project',
#    '.'],
#   1),
#  (['no', 'problem', ':)'], 1),
#  (['new',
#    'favorite',
#    'editing',
#    'app',
#    '.',
#    'jk',
#    'someone',
#    'pls',
#    'translate',
#    'this',
#    ':(',
#    'http://t.co/n3aIIfaBAP'],
#   0),
#  (['Watching',
#    'abusive',
#    'relationship',
#    'videos',
#    'is',
#    'so',
#    'fucking',
#    'hard',
#    '.',
#    "I'm",
#    'trying',
#    'not',
#    'to',
#    'cry',
#    'but',
#    "it's",
#    'like',
#    '...',
#    ':('],
#   0),
#  (['Woah',
#    '.',
#    'Okay',
#    '.',
#    'Expect',
#    'tweets',
#    'when',
#    'this',
#    'fucker',
#    'dies',
#    'again',
#    '!',
#    ':)'],
#   1),
#  (['i', 'need', 'nate', 'ruess', "'", 'album', ':('], 0),
#  (['Why', 'do', 'i', 'miss', 'this', ':-(', 'http://t.co/FZvRFAi1YN'], 0),
#  (['Current', 'playlist', ':D', 'http://t.co/PYKQLD4KHr'], 1),
#  (['dudeee',
#    "I'm",
#    'so',
#    'happy',
#    'you',
#    'like',
#    'them',
#    ':)',
#    ')',
#    ')',
#    'tell',
#    'me',
#    'which',
#    'are',
#    'your',
#    'favorites'],
#   1),
#  (['yeah',
#    "they're",
#    'giving',
#    'me',
#    'subtle',
#    'hints',
#    '.',
#    'also',
#    'tip',
#    '#',
#    '2',
#    ':',
#    "don't",
#    'use',
#    'it',
#    'all',
#    'and',
#    'the',
#    'community',
#    'these',
#    'last',
#    'few',
#    'years',
#    '.',
#    ':-)',
#    'Prim',
#    '’',
#    's',
#    'Algorithm',
#    'III'],
#   1),
#  (['Ouucchhh',
#    'one',
#    'of',
#    'my',
#    'wisdom',
#    'teeth',
#    'are',
#    'coming',
#    'through',
#    ':('],
#   0),
#  (['ima',
#    'leave',
#    'this',
#    '.',
#    'right',
#    '.',
#    'here',
#    '.',
#    ':-)',
#    'http://t.co/VlGObizVhd'],
#   1),
#  (['I',
#    'appreciate',
#    'the',
#    'weekly',
#    'update',
#    'but',
#    'more',
#    'weapons',
#    'than',
#    'ever',
#    'before',
#    'are',
#    'on',
#    'the',
#    'way',
#    '?',
#    'we',
#    'have',
#    'nowhere',
#    'to',
#    'put',
#    'the',
#    'one',
#    'we',
#    'already',
#    'own',
#    ':('],
#   0),
#  (["I'm",
#    'not',
#    'the',
#    'best',
#    ',',
#    'not',
#    'the',
#    'most',
#    'perfect',
#    ',',
#    'but',
#    'I',
#    'promise',
#    'to',
#    'love',
#    'you',
#    'with',
#    'my',
#    'whole',
#    'heart',
#    '.',
#    ':)'],
#   1),
#  (['i',
#    'got',
#    'stung',
#    'by',
#    'a',
#    'wasp',
#    'im',
#    'crying',
#    'so',
#    'hard',
#    'the',
#    'tweak',
#    'keeps',
#    'getting',
#    'bigger',
#    'ive',
#    'never',
#    'been',
#    'stung',
#    'by',
#    'one',
#    'before',
#    'i',
#    'hope',
#    'im',
#    'not',
#    'allergic',
#    'to',
#    'it',
#    ':('],
#   0),
#  (['it', 'came', 'crashing', 'down', 'and', 'it', 'hurts', 'inside', ':('], 0),
#  (['rude', 'af', ',', 'im', 'gonna', 'put', 'my', 'candle', 'away', ':('], 0),
#  (['far',
#    'from',
#    'it',
#    '.',
#    'Being',
#    'LFC',
#    'fan',
#    'makes',
#    'me',
#    'expert',
#    'in',
#    'spotting',
#    'mental',
#    'weakness',
#    'and',
#    'lack',
#    'consistency',
#    ':-)'],
#   1),
#  (['what', 'happened', '?', ':('], 0),
#  (['Stats',
#    'for',
#    'the',
#    'day',
#    'have',
#    'arrived',
#    '.',
#    '1',
#    'new',
#    'follower',
#    'and',
#    'NO',
#    'unfollowers',
#    ':)',
#    'via',
#    'http://t.co/NctwyoltIQ',
#    '.'],
#   1),
#  (['follow', '&', 'http://t.co/RCvcYYO0Iq', 'follow', 'u', 'back', ':)'], 1),
#  (['Awwhh',
#    '#cute',
#    '#bulldog',
#    '#Friday',
#    '#happy',
#    'Have',
#    'a',
#    'good',
#    'friday',
#    'everyone',
#    ':)',
#    'x',
#    'http://t.co/cJ1t3JPqvE'],
#   1),
#  (['just', 'kidding', 'kaaa', ':p'], 1),
#  (['and',
#    'jisung',
#    'is',
#    'the',
#    'kid',
#    'sunshine',
#    ':)',
#    'https://t.co/LBjXDWIAPE'],
#   1),
#  (['pcy', 'mine', ':-('], 0),
#  (['hi',
#    'ate',
#    ':(',
#    'i',
#    'know',
#    'she',
#    'loves',
#    'you',
#    'so',
#    'much',
#    'but',
#    'maybe',
#    "she's",
#    'having',
#    'a',
#    'hard',
#    'time',
#    'right',
#    'now',
#    '.'],
#   0),
#  (['LOVELY', 'DAAAY', '!', ':D'], 1),
#  (['How',
#    'careful',
#    'do',
#    'you',
#    'actually',
#    'have',
#    'to',
#    'be',
#    'with',
#    'a',
#    'black',
#    'box',
#    '?',
#    ':('],
#   0),
#  (['you', 'guys', 'have', 'a', 'great', 'weekend', 'too', '!', ':)'], 1),
#  (['NeoBytes',
#    ':)',
#    'Universal',
#    'Pictures',
#    'seeds',
#    'pirated',
#    'movie',
#    'copy',
#    ',',
#    'files',
#    'takedown',
#    'notice',
#    'against',
#    'itself',
#    'http://t.co/4ESrPPRXCA'],
#   1),
#  (['ohh',
#    'that',
#    'sucks',
#    ':(',
#    '(',
#    '(',
#    'hands',
#    'you',
#    'all',
#    'my',
#    'jackets',
#    '!',
#    '!',
#    "it's",
#    'way',
#    'too',
#    'warm',
#    'here',
#    'and',
#    "it's",
#    'making',
#    'me',
#    'sleepy',
#    '24/7'],
#   0),
#  (['Only',
#    'a',
#    'few',
#    'people',
#    'have',
#    'wished',
#    'my',
#    'birthday',
#    '.',
#    ':('],
#   0),
#  (['what', 'the', 'heck', ':(', 'you', "don't", 'follow', 'her', '?'], 0),
#  (['are',
#    'you',
#    'a',
#    'member',
#    'of',
#    'හෙල',
#    'හවුල',
#    'by',
#    'any',
#    'chance',
#    '?',
#    ':D'],
#   1),
#  (['did',
#    'they',
#    'manage',
#    'to',
#    'sort',
#    'your',
#    'ticket',
#    'issue',
#    'mate',
#    '?',
#    'Nobody',
#    'picked',
#    'up',
#    'when',
#    'i',
#    'rang',
#    'the',
#    'box',
#    'office',
#    ':('],
#   0),
#  (['please', "don't", 'ask', 'for', 'upvotes', ':(', 'http://t.co/MT1tFymZGU'],
#   0),
#  (['ya', 'i', 'did', ':-(', 'https://t.co/peQqNxkDj0'], 0),
#  (['Jumma', 'Mubbarak', ':)', 'To', 'all', '❤', '❤'], 1),
#  (['heyy', 'i', 'miss', 'you', ':('], 0),
#  (['Spotify',
#    'finally',
#    'figured',
#    'out',
#    'that',
#    "I'm",
#    'not',
#    'in',
#    'the',
#    'US',
#    'and',
#    "won't",
#    'let',
#    'me',
#    'listen',
#    'anymore',
#    ':('],
#   0),
#  (['Hi',
#    'BAM',
#    '!',
#    'Can',
#    'you',
#    'follow',
#    'my',
#    'bestfriend',
#    '?',
#    'She',
#    'loves',
#    'you',
#    'a',
#    'lot',
#    ':)',
#    'See',
#    'you',
#    'in',
#    'Warsaw',
#    '<3',
#    'Love',
#    'you',
#    '<3',
#    'x2'],
#   1),
#  (['i', 'want', 'a', 'sausage', 'roll', ':-('], 0),
#  (['Hey',
#    'do',
#    'you',
#    'follow',
#    'back',
#    'average',
#    "joe's",
#    'that',
#    'love',
#    'the',
#    '#BlueJays',
#    ':)'],
#   1),
#  ...]

# %%
# prompt: add another metric for assesing the model

from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.967
