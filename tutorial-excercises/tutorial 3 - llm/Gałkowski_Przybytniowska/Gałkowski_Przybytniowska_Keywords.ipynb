# %% [markdown]
# # Tutorial task - Keywords
#
# Authors:
# - Mikołaj Gałkowski
# - Julia Przybytniowska
#
# We decided to use the following models:
#
# - "google/gemma-2-9b-it",
# - "Qwen/Qwen2.5-7B-Instruct",
# - "meta-llama/Llama-3.1-8B-Instruct",
# - "ministral-8b-latest",

# %% [markdown]
# ### Requirements
#
# 1. Identifying Product Data with LLMs
# 2. Defining similarity between products from the dataset and reviews

# %%
from dotenv import load_dotenv

load_dotenv() # loading api keys
# Out:
# True

# %%
import os
import json
import time
from mistralai import Mistral
from transformers import pipeline
from tqdm.notebook import tqdm

api_key = os.environ["API_KEY"]
model = "mistral-embed"

client = Mistral(api_key=api_key)

# %%
prompts = {
    "review1": {
        "review_content": "Gets my clothes fresh and clean every time. No lingering odor with Tide.",
        "golden_answer": {
            "product category": "Powder Detergents for Laundry",
            "brand": "Tide",
            "other keywords": ['fresh', 'clean', 'no lingering odor']
        },
    },
    "review2": {
        "review_content": "Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo.",
        "golden_answer": {
            "product category": "Thermal Mugs",
            "brand": "Contigo",
            "other keywords": ["hot for hours"]
        },
    },
}

# %%
reviews_for_evaluation = [
    "Gets my clothes fresh and clean every time. No lingering odor with Tide.",
    "Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo.",
]

reviews = [
    # Thermal Mugs
    "Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo.",
    "The lid isn’t leak-proof, but it keeps drinks warm for a decent amount of time.",
    "Love the sleek design of my Zojirushi mug, and it fits perfectly in my car cup holder!",
    "It’s lightweight but keeps my drinks at the right temperature for hours with Hydro Flask.",
    "No more cold coffee! This Yeti thermal mug does the job.",
    "It’s easy to clean, and the thermal insulation works like a charm.",
    "The handle makes it easy to carry, and it doesn’t spill.",
    "Not great for keeping drinks cold, but excellent for hot beverages.",
    "I wish it were bigger, but it’s perfect for my morning tea.",
    "I accidentally dropped it, and it didn’t dent! Very sturdy.",
    "The rubber seal around the lid came loose after a few weeks. Disappointing.",
    "Great for both coffee and soup—keeps them warm for hours.",
    "The exterior stays cool, even when my drink is piping hot inside.",
    "I love the color options, and it’s great for on-the-go.",
    "Keeps ice water cold for hours, even in hot weather!",
    "It’s a little tricky to open one-handed, but overall, a great mug.",
    "The size is perfect for travel, and it keeps drinks hot all day.",
    "It doesn’t leak, even when I toss it in my bag. Highly recommend Contigo.",
    "The lid is a little tight, but the mug works well for keeping drinks warm.",
    "Very stylish and functional! I get compliments all the time.",
    "Keeps my coffee scalding hot for longer than any mug I’ve owned with Zojirushi.",
    "Great value for the price. Works just as well as more expensive brands.",
    "The mug is lightweight and easy to carry around.",
    "It fits perfectly under my single-serve coffee machine!",
    "Durable, sleek, and it does exactly what it’s supposed to.",

    # Dishwasher Detergents
    "My dishes come out sparkling clean every time with Cascade. Love this detergent!",
    "It works well on glass, but I’ve noticed spots on my silverware.",
    "Great for tough, greasy messes. Leaves no residue! Thanks, Finish.",
    "This detergent smells amazing and leaves my dishwasher fresh.",
    "It’s a little pricey, but my dishes have never looked better with Cascade Platinum.",
    "Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.",
    "Not the best on hard water stains, but otherwise it works great.",
    "My dishes have never been so spotless after a wash!",
    "It’s very effective, but I wish it came in a fragrance-free version.",
    "Cuts through grease like a dream. No more pre-rinsing with Cascade Complete.",
    "This detergent doesn’t leave any residue on plastic, which I love.",
    "My glasses come out clear and sparkling every single time.",
    "It doesn’t work well with my eco dishwasher. Dishes aren’t as clean.",
    "Very efficient—gets rid of food stains and smells with no problem.",
    "I noticed some streaks on my glassware, but overall it works well.",
    "Leaves my dishes spotless and my machine smelling fresh.",
    "A great, eco-friendly option that actually works!",
    "It’s a little hard on some of my delicate dishware.",
    "This is the only detergent that works on my hard water stains.",
    "No need to rewash dishes after using this—so efficient!",
    "Perfect for everyday use. My dishes are clean and shiny.",
    "Leaves a chemical smell, but it’s effective at cleaning.",
    "A bit expensive, but worth it for the spotless results.",
    "No more streaks or water spots! Best dishwasher detergent ever.",
    "My silverware and dishes look brand new after every wash.",

    # Sunscreens
    "Absorbs quickly and doesn’t leave a greasy residue. Great for daily use with Neutrogena.",
    "The scent is a little strong, but it protects well with Coppertone.",
    "Perfect for sensitive skin! No breakouts or irritation with La Roche-Posay.",
    "A bit thick to apply, but once it’s on, it stays all day.",
    "I love the lightweight formula of CeraVe, perfect for wearing under makeup.",
    "Doesn’t leave a white cast, even on darker skin tones.",
    "The spray bottle makes it super easy to apply on the go.",
    "This sunscreen saved me from burning on a beach vacation with Banana Boat!",
    "It’s waterproof, which is a must for pool days. Highly recommend Hawaiian Tropic.",
    "A bit pricey, but the protection it provides is worth every penny with Supergoop.",
    "This is my go-to sunscreen for both my face and body with Neutrogena.",
    "It’s a little greasy, but it gets the job done in strong sun.",
    "No weird scent, and it goes on smooth. Love this product!",
    "Perfect for outdoor activities—no sunburn, even after hours outside.",
    "It’s great for kids! No irritation, and it’s easy to apply with Blue Lizard.",
    "A little too heavy for my face, but works perfectly for the body.",
    "The texture is nice and light, not sticky at all.",
    "This sunscreen doesn’t clog my pores, which is a huge plus with EltaMD.",
    "I’ve tried a lot of sunscreens, and this one offers the best protection with La Roche-Posay.",
    "It leaves a slight sheen, but I love how protected my skin feels.",
    "This formula doesn’t dry out my skin like others do.",
    "It’s great under makeup—no pilling or greasiness.",
    "I wish it were more affordable, but it’s worth it for the protection.",
    "Very effective, even after swimming for hours.",
    "My skin stays soft and protected all day with Neutrogena sunscreen.",

     # Powder Detergents for Laundry
    "Gets my clothes fresh and clean every time. No lingering odor with Tide.",
    "It dissolves well, even in cold water. My whites have never been brighter thanks to Ariel.",
    "A little pricey, but worth it for the excellent stain removal power of Persil.",
    "This powder leaves a residue on darker clothes. Not a fan of OMO.",
    "Great for sensitive skin! No itching or redness after using Seventh Generation.",
    "I love how eco-friendly this detergent is. It’s a big plus for me with Ecover.",
    "I don’t need fabric softener anymore—this leaves my clothes so soft!",
    "My laundry has never smelled so fresh, and it lasts for days with Gain.",
    "It’s not the best for heavy stains but works great for daily washes.",
    "Great value for the price. This box lasts forever! Thanks, Arm & Hammer.",
    "Perfect for my workout gear—gets rid of all the sweat smells.",
    "Leaves a bit of powder behind in the machine, but it cleans well.",
    "I’ve been using it for years, and Tide never disappoints.",
    "Not as effective in hard water areas, but still decent.",
    "My go-to detergent for all of my family’s laundry needs.",
    "I noticed some fading in my darker clothes after a few washes.",
    "It’s gentle on my baby’s clothes and skin with Dreft.",
    "Very effective at removing mud and grass stains from the kids’ clothes.",
    "I like the scent, but it might be too strong for some.",
    "No complaints so far! My clothes feel clean and fresh.",
    "Works just as well as liquid detergents but at a lower cost.",
    "A bit too perfumed for my taste, but it gets the job done.",
    "My clothes are noticeably softer and smell better than before.",
    "The box is hard to pour from, but the detergent works well.",
    "This is my new favorite detergent. So much better than the leading brand!",
]

# %%
def run_mistral(user_message, model=model):
    messages = [{"role": "user", "content": user_message}]
    chat_response = client.chat.complete(
        model=model,
        messages=messages,
        response_format={"type": "json_object"},
    )
    return chat_response.choices[0].message.content

prompt_template = """
Extract information from the following reviews:
{content}

Return json format with the following JSON schema:
{{
        "product category": {{
            "type": "string",
            "enum": ["Powder Detergents for Laundry", "Thermal Mugs", "Dishwasher Detergents", "Sunscreens", "Nappies", "Others"]
        }},
        "brand": {{
            "type": "string" or N/A
        }},
        "other keywords": {{
            "type": "array",
            "items": {{
                "type": "string"
            }}
        }},

}}
"""

# %% [markdown]
# ### Model inference loop

# %%
from transformers import pipeline
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

models = [
    "Qwen/Qwen2.5-7B-Instruct", "meta-llama/Llama-3.1-8B-Instruct", 
    "google/gemma-2-9b-it","ministral-8b-latest",
]

# %%
results_for_evaluation = {}

for model in tqdm(models, desc="Processing Models"):
    model_results = {}
    
    if model == "ministral-8b-latest":
        for review in tqdm(reviews_for_evaluation, desc=f"Processing Reviews for {model}", leave=False):
            user_message = prompt_template.format(content=review)
            response = run_mistral(user_message, model=model)
            model_results[review] = response
            time.sleep(4)
    else:
        pipe = pipeline(
            "text-generation", 
            model=model, 
            max_new_tokens=1000, 
            model_kwargs={
                "torch_dtype": torch.float16,
                "quantization_config": {"load_in_4bit": True},
                "low_cpu_mem_usage": True,
            },
            trust_remote_code=True,
        )
        
        for review in tqdm(reviews_for_evaluation, desc=f"Processing Reviews for {model}", leave=False):
            user_message = prompt_template.format(content=review)
            response = pipe(user_message)
            try:
                model_results[review] = response[0]['generated_text']
            except:
                model_results[review] = response
        
        del pipe
    
    results_for_evaluation[model] = model_results

with open('merged_results.json', 'w') as f:
    json.dump(results_for_evaluation, f, indent=4)
# Out:
# Processing Models:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing Reviews for Qwen/Qwen2.5-7B-Instruct:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing Reviews for meta-llama/Llama-3.1-8B-Instruct:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing Reviews for google/gemma-2-9b-it:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing Reviews for ministral-8b-latest:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
with open('merged_results.json', 'r') as f:
    results = json.load(f)
results.keys()
# Out:
# dict_keys(['ministral-8b-latest', 'google/gemma-2-9b-it', 'Qwen/Qwen2.5-7B-Instruct', 'meta-llama/Llama-3.1-8B-Instruct'])

# %%
for k, v in results.items():
    print(k, ' : ', len(v))
# Out:
# ministral-8b-latest  :  100
# google/gemma-2-9b-it  :  100
# Qwen/Qwen2.5-7B-Instruct  :  100
# meta-llama/Llama-3.1-8B-Instruct  :  100

# %% [markdown]
# Each model was called for each review.

# %% [markdown]
# # Evaluation on 2 cases from `prompts`

# %%
def compare_json_objects(obj1, obj2, keys_to_compare={'other keywords', 'brand', 'product category'}):
    total_fields = 0
    identical_fields = 0
    common_keys = set(obj1.keys()) & set(obj2.keys() & keys_to_compare)
    for key in common_keys:
        if obj2[key] == "N/A":
            obj2[key] = "Not mentioned."
        identical_fields += obj1[key] == obj2[key]
    percentage_identical = (identical_fields / max(len(keys_to_compare), 1)) * 100

    return percentage_identical

# %%
import unicodedata
import re

json_pattern = re.compile(r'\{\s*"product category":\s*".+?",\s*"brand":\s*".+?",\s*"other keywords":\s*\[.*?\]\s*?\}', re.DOTALL)

accuracy_rates = {}

for model_name in models:
    model_accuracy_rates = []
    i=0
    for _, content in prompts.items():
        i+=1
        if i==1: continue
        text = content["review_content"]
        golden_answer = content["golden_answer"]
        response = results[model_name].get(text)

        response = re.sub(r'("brand":\s*)(N/A)(,)', r'\1"N/A"\3', response)

        match = json_pattern.search(response)
        if match:
            response = match.group()
        else:
            continue
        
        response = unicodedata.normalize("NFKD", response).encode("ascii", "ignore").decode("ascii")
                
        accuracy_rate = compare_json_objects(ast.literal_eval(response), 
                                         golden_answer, 
                                         keys_to_compare={'product category', 'brand'})
        model_accuracy_rates.append(accuracy_rate)

    average_accuracy = sum(model_accuracy_rates) / len(model_accuracy_rates) if model_accuracy_rates else 0
    accuracy_rates[model_name] = average_accuracy

print("Model Accuracy Rates:")
for model_name, accuracy in accuracy_rates.items():
    print(f"{model_name}: {accuracy:.2f}%")
# Out:
# Model Accuracy Rates:
# Qwen/Qwen2.5-7B-Instruct: 100.00%
# meta-llama/Llama-3.1-8B-Instruct: 100.00%
# google/gemma-2-9b-it: 100.00%
# ministral-8b-latest: 100.00%

# %% [markdown]
# All models achieved 100% accuracy on both test examples.
#
# To achieve a more meaningful accuracy measure, we expanded the test set (`golden data`) by generating additional answers with `Llama3.1-7b` and new prompt with **few-shot examples**, allowing for a more robust comparison.

# %%
prompt_template_for_golden_dataset = """
You are experienced at categorizing reviews in different product categories ['Powder Detergents for Laundry', 'Thermal Mugs', 'Dishwasher Detergents', 'Sunscreens', 'Nappies', 'Others']
and also providing brand name and other relevant keyword.

For example:
    - for this review: 'Gets my clothes fresh and clean every time. No lingering odor with Tide.'
{{
    'product category': 'Powder Detergents for Laundry',
    'brand': 'Tide',
    'other keywords': ['fresh', 'clean', 'no lingering odor']
}}

    - for this review: 'Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo.'
{{
    'product category': 'Thermal Mugs',
    'brand': 'Contigo',
    'other keywords': ['hot for hours']
}}

If brand is not mentioned please assign: "Not mentioned."

Please return only dictionary in your response with these keys ['product category', 'brand', 'other keywords'] as in examples above for this review:

{review}
"""

# %% [markdown]
# ### Llama3.1 7b - for golden dataset creation

# %%
pipe = pipeline("text-generation", model="meta-llama/Llama-3.1-7B-Instruct", max_new_tokens=250,
                model_kwargs={
                    "torch_dtype": torch.float16,
                    "quantization_config": {"load_in_4bit": True},
                    "low_cpu_mem_usage": True,
                 },
                trust_remote_code=True,               
)
pipe.model.generation_config.pad_token_id = pipe.tokenizer.pad_token_id
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
json_pattern = re.compile(
    r"\{\s*'product category':\s*'.+?',\s*'brand':\s*'.+?',\s*'other keywords':\s*\[.*?\]\s*\}", re.DOTALL
)

golden_data = {}
i = 3  # Starting index (to have unique keys in final dictionary)

skip_reviews = {
    "Gets my clothes fresh and clean every time. No lingering odor with Tide.",
    "Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo."
}

for review in tqdm(reviews):
    if review in skip_reviews:
        continue

    user_message = prompt_template_for_golden_dataset.format(review=review)
    response = pipe(user_message)
    generated_text = response[0]['generated_text']

    match = json_pattern.search(generated_text)
    if match:
        try:
            extracted_dict = ast.literal_eval(match.group())
        except (ValueError, SyntaxError) as e:
            print(f"Error parsing response for review: {review} (index: {i}) - {e}")
            i += 1
            continue
    else:
        print(f"No valid JSON found for review: {review} (index: {i})")
        i += 1
        continue

    golden_data[f'review{i}'] = {
        "review_content": review,
        "golden_answer": extracted_dict,
    }
    i += 1
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
golden = prompts | golden_data
# Out:
# {'review1': {'review_content': 'Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review2': {'review_content': 'Keeps my coffee hot for hours—just what I need for long workdays. Thanks, Contigo.',
#   'golden_answer': {'product category': 'Thermal Mugs',
#    'brand': 'Contigo',
#    'other keywords': ['hot for hours']}},
#  'review3': {'review_content': 'The lid isn’t leak-proof, but it keeps drinks warm for a decent amount of time.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review4': {'review_content': 'Love the sleek design of my Zojirushi mug, and it fits perfectly in my car cup holder!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review5': {'review_content': 'It’s lightweight but keeps my drinks at the right temperature for hours with Hydro Flask.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review6': {'review_content': 'No more cold coffee! This Yeti thermal mug does the job.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review7': {'review_content': 'It’s easy to clean, and the thermal insulation works like a charm.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review8': {'review_content': 'The handle makes it easy to carry, and it doesn’t spill.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review9': {'review_content': 'Not great for keeping drinks cold, but excellent for hot beverages.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review10': {'review_content': 'I wish it were bigger, but it’s perfect for my morning tea.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review11': {'review_content': 'I accidentally dropped it, and it didn’t dent! Very sturdy.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review12': {'review_content': 'The rubber seal around the lid came loose after a few weeks. Disappointing.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review13': {'review_content': 'Great for both coffee and soup—keeps them warm for hours.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review14': {'review_content': 'The exterior stays cool, even when my drink is piping hot inside.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review15': {'review_content': 'I love the color options, and it’s great for on-the-go.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review16': {'review_content': 'Keeps ice water cold for hours, even in hot weather!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review17': {'review_content': 'It’s a little tricky to open one-handed, but overall, a great mug.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review18': {'review_content': 'The size is perfect for travel, and it keeps drinks hot all day.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review19': {'review_content': 'It doesn’t leak, even when I toss it in my bag. Highly recommend Contigo.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review20': {'review_content': 'The lid is a little tight, but the mug works well for keeping drinks warm.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review21': {'review_content': 'Very stylish and functional! I get compliments all the time.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review22': {'review_content': 'Keeps my coffee scalding hot for longer than any mug I’ve owned with Zojirushi.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review23': {'review_content': 'Great value for the price. Works just as well as more expensive brands.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review24': {'review_content': 'The mug is lightweight and easy to carry around.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review25': {'review_content': 'It fits perfectly under my single-serve coffee machine!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review26': {'review_content': 'Durable, sleek, and it does exactly what it’s supposed to.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review27': {'review_content': 'My dishes come out sparkling clean every time with Cascade. Love this detergent!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review28': {'review_content': 'It works well on glass, but I’ve noticed spots on my silverware.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review29': {'review_content': 'Great for tough, greasy messes. Leaves no residue! Thanks, Finish.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review30': {'review_content': 'This detergent smells amazing and leaves my dishwasher fresh.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review31': {'review_content': 'It’s a little pricey, but my dishes have never looked better with Cascade Platinum.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review32': {'review_content': 'Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review33': {'review_content': 'Not the best on hard water stains, but otherwise it works great.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review34': {'review_content': 'My dishes have never been so spotless after a wash!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review35': {'review_content': 'It’s very effective, but I wish it came in a fragrance-free version.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review36': {'review_content': 'Cuts through grease like a dream. No more pre-rinsing with Cascade Complete.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review37': {'review_content': 'This detergent doesn’t leave any residue on plastic, which I love.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review38': {'review_content': 'My glasses come out clear and sparkling every single time.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review39': {'review_content': 'It doesn’t work well with my eco dishwasher. Dishes aren’t as clean.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review40': {'review_content': 'Very efficient—gets rid of food stains and smells with no problem.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review41': {'review_content': 'I noticed some streaks on my glassware, but overall it works well.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review42': {'review_content': 'Leaves my dishes spotless and my machine smelling fresh.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review43': {'review_content': 'A great, eco-friendly option that actually works!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review44': {'review_content': 'It’s a little hard on some of my delicate dishware.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review45': {'review_content': 'This is the only detergent that works on my hard water stains.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review46': {'review_content': 'No need to rewash dishes after using this—so efficient!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review47': {'review_content': 'Perfect for everyday use. My dishes are clean and shiny.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review48': {'review_content': 'Leaves a chemical smell, but it’s effective at cleaning.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review49': {'review_content': 'A bit expensive, but worth it for the spotless results.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review50': {'review_content': 'No more streaks or water spots! Best dishwasher detergent ever.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review51': {'review_content': 'My silverware and dishes look brand new after every wash.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review52': {'review_content': 'Absorbs quickly and doesn’t leave a greasy residue. Great for daily use with Neutrogena.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review53': {'review_content': 'The scent is a little strong, but it protects well with Coppertone.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review54': {'review_content': 'Perfect for sensitive skin! No breakouts or irritation with La Roche-Posay.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review55': {'review_content': 'A bit thick to apply, but once it’s on, it stays all day.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review56': {'review_content': 'I love the lightweight formula of CeraVe, perfect for wearing under makeup.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review57': {'review_content': 'Doesn’t leave a white cast, even on darker skin tones.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review58': {'review_content': 'The spray bottle makes it super easy to apply on the go.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review59': {'review_content': 'This sunscreen saved me from burning on a beach vacation with Banana Boat!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review60': {'review_content': 'It’s waterproof, which is a must for pool days. Highly recommend Hawaiian Tropic.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review61': {'review_content': 'A bit pricey, but the protection it provides is worth every penny with Supergoop.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review62': {'review_content': 'This is my go-to sunscreen for both my face and body with Neutrogena.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review63': {'review_content': 'It’s a little greasy, but it gets the job done in strong sun.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review64': {'review_content': 'No weird scent, and it goes on smooth. Love this product!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review65': {'review_content': 'Perfect for outdoor activities—no sunburn, even after hours outside.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review66': {'review_content': 'It’s great for kids! No irritation, and it’s easy to apply with Blue Lizard.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review67': {'review_content': 'A little too heavy for my face, but works perfectly for the body.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review68': {'review_content': 'The texture is nice and light, not sticky at all.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review69': {'review_content': 'This sunscreen doesn’t clog my pores, which is a huge plus with EltaMD.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review70': {'review_content': 'I’ve tried a lot of sunscreens, and this one offers the best protection with La Roche-Posay.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review71': {'review_content': 'It leaves a slight sheen, but I love how protected my skin feels.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review72': {'review_content': 'This formula doesn’t dry out my skin like others do.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review73': {'review_content': 'It’s great under makeup—no pilling or greasiness.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review74': {'review_content': 'I wish it were more affordable, but it’s worth it for the protection.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review75': {'review_content': 'Very effective, even after swimming for hours.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review76': {'review_content': 'My skin stays soft and protected all day with Neutrogena sunscreen.Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review77': {'review_content': 'It dissolves well, even in cold water. My whites have never been brighter thanks to Ariel.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review78': {'review_content': 'A little pricey, but worth it for the excellent stain removal power of Persil.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review79': {'review_content': 'This powder leaves a residue on darker clothes. Not a fan of OMO.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review80': {'review_content': 'Great for sensitive skin! No itching or redness after using Seventh Generation.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review81': {'review_content': 'I love how eco-friendly this detergent is. It’s a big plus for me with Ecover.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review82': {'review_content': 'I don’t need fabric softener anymore—this leaves my clothes so soft!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review83': {'review_content': 'My laundry has never smelled so fresh, and it lasts for days with Gain.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review84': {'review_content': 'It’s not the best for heavy stains but works great for daily washes.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review85': {'review_content': 'Great value for the price. This box lasts forever! Thanks, Arm & Hammer.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review86': {'review_content': 'Perfect for my workout gear—gets rid of all the sweat smells.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review87': {'review_content': 'Leaves a bit of powder behind in the machine, but it cleans well.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review88': {'review_content': 'I’ve been using it for years, and Tide never disappoints.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review89': {'review_content': 'Not as effective in hard water areas, but still decent.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review90': {'review_content': 'My go-to detergent for all of my family’s laundry needs.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review91': {'review_content': 'I noticed some fading in my darker clothes after a few washes.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review92': {'review_content': 'It’s gentle on my baby’s clothes and skin with Dreft.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review93': {'review_content': 'Very effective at removing mud and grass stains from the kids’ clothes.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review94': {'review_content': 'I like the scent, but it might be too strong for some.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review95': {'review_content': 'No complaints so far! My clothes feel clean and fresh.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review96': {'review_content': 'Works just as well as liquid detergents but at a lower cost.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review97': {'review_content': 'A bit too perfumed for my taste, but it gets the job done.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review98': {'review_content': 'My clothes are noticeably softer and smell better than before.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review99': {'review_content': 'The box is hard to pour from, but the detergent works well.',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}},
#  'review100': {'review_content': 'This is my new favorite detergent. So much better than the leading brand!',
#   'golden_answer': {'product category': 'Powder Detergents for Laundry',
#    'brand': 'Tide',
#    'other keywords': ['fresh', 'clean', 'no lingering odor']}}}

# %%
with open('golden_dataset.json', 'w') as f:
    json.dump(golden, f, indent=4)

# %% [markdown]
# As we can see updated prompt resulted in accurate responses, so we decided to evaluate all previous results against these.

# %% [markdown]
# ### Evaluation using `golden` dataset

# %%
accuracy_rates = {}

for model_name in models:
    model_accuracy_rates = []
    i=0
    for _, content in golden.items():
        i+=1
        if i==1: continue
        text = content["review_content"]
        golden_answer = content["golden_answer"]
        response = results[model_name].get(text)
        if response is None:
            print('Response is None')
            print(text)
            continue

        # JSON extraction using RegEx
        response = re.sub(r'("brand":\s*)(N/A)(,)', r'\1"N/A"\3', response)
        
        match = json_pattern.search(response)
        if match:
            response = match.group()
        else:
            continue
        
        response = unicodedata.normalize("NFKD", response).encode("ascii", "ignore").decode("ascii")
                
        accuracy_rate = compare_json_objects(ast.literal_eval(response), 
                                         golden_answer, 
                                         keys_to_compare={'product category', 'brand'})
        model_accuracy_rates.append(accuracy_rate)

        results[model_name][text] = ast.literal_eval(response)

    average_accuracy = sum(model_accuracy_rates) / len(model_accuracy_rates) if model_accuracy_rates else 0
    accuracy_rates[model_name] = average_accuracy

print("Model Accuracy Rates:")
for model_name, accuracy in accuracy_rates.items():
    print(f"{model_name}: {accuracy:.2f}%")
# Out:
# Model Accuracy Rates:
# Qwen/Qwen2.5-7B-Instruct: 15.96%
# meta-llama/Llama-3.1-8B-Instruct: 20.54%
# google/gemma-2-9b-it: 14.14%
# ministral-8b-latest: 16.67%

# %% [markdown]
# Let's investigate what is the reason behind poor accuracies.

# %%
print(results['meta-llama/Llama-3.1-8B-Instruct']['A bit too perfumed for my taste, but it gets the job done.'])
# Out:
# Extract information from the following reviews:
# A bit too perfumed for my taste, but it gets the job done.
#
# Return json format with the following JSON schema:
# {
#         "product category": {
#             "type": "string",
#             "enum": ["Powder Detergents for Laundry", "Thermal Mugs", "Dishwasher Detergents", "Sunscreens", "Nappies", "Others"]
#         },
#         "brand": {
#             "type": "string" or N/A
#         },
#         "other keywords": {
#             "type": "array",
#             "items": {
#                 "type": "string"
#             }
#         },
#
# }
# ----------------------------------------------------------
#
# Review 1:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: perfumed, job done
#
# Review 2:
# Product: Thermal Mugs
# Brand: Yeti
# Other keywords: job done, good
#
# Review 3:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, cheap
#
# Review 4:
# Product: Sunscreens
# Brand: N/A
# Other keywords: job done, good, perfumed
#
# Review 5:
# Product: Nappies
# Brand: N/A
# Other keywords: job done, good, perfumed
#
# Review 6:
# Product: Others
# Brand: N/A
# Other keywords: job done, good
#
# Review 7:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 8:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 9:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 10:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 11:
# Product: Nappies
# Brand: N/A
# Other keywords: job done, good
#
# Review 12:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 13:
# Product: Thermal Mugs
# Brand: N/A
# Other keywords: job done, good
#
# Review 14:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 15:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 16:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 17:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 18:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 19:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 20:
# Product: Thermal Mugs
# Brand: N/A
# Other keywords: job done, good
#
# Review 21:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 22:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 23:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 24:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 25:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 26:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 27:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 28:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 29:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 30:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 31:
# Product: Thermal Mugs
# Brand: N/A
# Other keywords: job done, good
#
# Review 32:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 33:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 34:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 35:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 36:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 37:
# Product: Powder Detergents for Laundry
# Brand: N/A
# Other keywords: job done, good
#
# Review 38:
# Product: Dishwasher Detergents
# Brand: N/A
# Other keywords: job done, good
#
# Review 39:
# Product: Powder Detergents for Laundry
# Brand

# %% [markdown]
# The response above is an example that didn’t follow the expected format due to unnecessary repetition. To get better results we would try different prompt engineering techniques as we did in `golden` dataset.

# %% [markdown]
# ### Product offers

# %%
product_offers = [
    # Thermal Mugs
    "Contigo Workday Travel Mug – Keeps Coffee Hot for Hours!",
    "Zojirushi Sleek Travel Mug – Perfect Fit for Car Holders",
    "Hydro Flask Lightweight Insulation Mug – Stay Warm for Hours",
    "Yeti Thermal Mug – No More Cold Coffee!",
    "Contigo All-Day Heat Retention Mug – Ideal for Travel",
    "Contigo Leak-Proof Mug – Toss in Your Bag with Confidence",
    "Zojirushi Scalding Hot Coffee Mug – Best Insulation Yet",

    # Dishwasher Detergents
    "Cascade Sparkling Clean Detergent – Your Dishes Will Shine",
    "Finish Detergent – Tough on Grease, No Residue Left",
    "Cascade Platinum Detergent – Pricey, But Worth It for Results",
    "Finish Quantum Detergent – Stubborn Food Stains Gone",
    "Cascade Complete Detergent – No Pre-Rinsing Needed for Grease",

    # Sunscreens
    "Neutrogena Daily Sunscreen – Quick Absorption, No Grease",
    "Coppertone Suncream – Strong Scent, Strong Protection",
    "La Roche-Posay Sensitive Skin Sunscreen – No Breakouts",
    "CeraVe Lightweight Sunscreen – Perfect Under Makeup",
    "Banana Boat Beach-Saver Sunscreen – No Burns, Just Fun",
    "Hawaiian Tropic Waterproof Sunscreen – Pool Day Essential",
    "Supergoop Premium Sunscreen – Worth Every Penny",
    "Neutrogena Face & Body Sunscreen – All-Purpose Protection",
    "EltaMD Pore-Friendly Sunscreen – Protection Without Clogging",
    "La Roche-Posay Suncream – The Best in Sun Protection",
    "Neutrogena Sunscreen – Soft, Protected Skin All Day",

    # Powder Detergents for Laundry
    "Tide Powder Detergent – Fresh, Clean Clothes Every Time",
    "Ariel Powder Detergent – Whites Brighter, Even in Cold Water",
    "Persil Powder Detergent – Powerful Stain Removal",
    "OMO Powder Detergent – Leaves Residue on Dark Clothes",
    "Seventh Generation Powder Detergent – Great for Sensitive Skin",
    "Ecover Eco-Friendly Detergent – Perfect for the Eco-Conscious",
    "Gain Powder Detergent – Fresh-Smelling Laundry for Days",
    "Arm & Hammer Powder Detergent – Great Value, Lasts Forever",
    "Dreft Baby Powder Detergent – Gentle on Baby Clothes"
]

# %%
product_results = {}

for model in models:
    model_results = {}
    
    if model == "ministral-8b-latest":
        for product in tqdm(product_offers, desc=f"Processing Reviews for {model}", leave=False):
            user_message = prompt_template.format(content=product)
            response = run_mistral(user_message, model=model)
            model_results[product] = response
            time.sleep(4)
    else:
        pipe = pipeline(
            "text-generation", 
            model=model, 
            max_new_tokens=1000, 
            model_kwargs={
                "torch_dtype": torch.float16,
                "quantization_config": {"load_in_4bit": True},
                "low_cpu_mem_usage": True,
            },
            trust_remote_code=True,
        )
        
        for product in tqdm(product_offers, desc=f"Processing Reviews for {model}", leave=False):
            user_message = prompt_template.format(content=product)
            response = pipe(user_message)
            try:
                model_results[product] = response[0]['generated_text']
            except Exception as e:
                print(f"Error processing review: {e}")
                model_results[product] = response
    
        del pipe
    
    product_results[model] = model_results

with open(f'product_offers/merged_results_product_offers.json', 'w') as f:
    json.dump(product_results, f, indent=4)

# %%
with open('product_offers/merged_results_product_offers.json', 'r') as f:
    product_results = json.load(f)

# %% [markdown]
# JSON extraction using RegEx

# %%
json_pattern = re.compile(r'\{\s*"product category":\s*".+?",\s*"brand":\s*".+?",\s*"other keywords":\s*\[.*?\]\s*?\}', re.DOTALL)

for model_name in product_results:
    results_per_model = product_results[model_name]

    for review in results_per_model:
        response = results_per_model[review]

        if isinstance(response, str):
            response = re.sub(r'("brand":\s*)(N/A)(,)', r'\1"N/A"\3', response)
            match = json_pattern.search(response)

            if match:
                response = match.group()
            else:
                product_results[model_name][review] = 'Nothing was extracted'    
                continue
        
            response = unicodedata.normalize("NFKD", response).encode("ascii", "ignore").decode("ascii")
            response = ast.literal_eval(response)
        product_results[model_name][review] = response

# %% [markdown]
# ### Similarity analysis between Reviews and Product offers

# %%
from bert_score import score
import random
random.seed(3)

# %%
def compare_json_objects_with_keywords_method_1(obj1, obj2, keys_to_compare={'other keywords', 'brand', 'product category'}):
    identical_fields = 0
    common_keys = set(obj1.keys()) & set(obj2.keys() & keys_to_compare)
    for key in common_keys:
        if key == 'other keywords':
            if isinstance(obj1.get(key), list) and isinstance(obj2.get(key), list):
                common_keywords = set(obj1.get(key)) & set(obj2.get(key))
                identical_fields += len(common_keywords) * 0.3  # Keywords have lower weight
            else:
              identical_fields += 0
        else:
          identical_fields += obj1[key] == obj2[key]
    percentage_identical = (identical_fields / max(len(keys_to_compare), 1)) * 100

    return percentage_identical

def compare_json_objects_with_keywords_method_2(obj1, obj2, keys_to_compare={'other keywords', 'brand', 'product category'}):
    if obj1.get('product category') != obj2.get('product category'):
        return 0  # No similarity if categories don't match

    similarity_score = 0
    common_keys = set(obj1.keys()) & set(obj2.keys() & keys_to_compare)

    if obj1.get('product category') == obj2.get('product category'):
        similarity_score += 0.3  # Base similarity for matching categories

    if obj1.get('brand') == obj2.get('brand'):
        similarity_score += 0.4  # Additional similarity for matching brands

    for key in common_keys:
        if key == 'other keywords':
            if isinstance(obj1.get(key), list) and isinstance(obj2.get(key), list):
                common_keywords = set(obj1.get(key)) & set(obj2.get(key))
                similarity_score += len(common_keywords) * 0.05  # Keywords have lower weight
            else:
                similarity_score += 0

    return min(100, round(similarity_score * 100))

def compare_keywords_with_bert_score(review_keywords, product_keywords):
    """Compares keywords using BERTScore."""

    max_length = max(len(review_keywords), len(product_keywords))
    review_keywords = review_keywords + [''] * (max_length - len(review_keywords))
    product_keywords = product_keywords + [''] * (max_length - len(product_keywords))

    if not review_keywords or not product_keywords:
        return 0
    P, R, F1 = score(
        review_keywords,
        product_keywords,
        lang="en",
        model_type="bert-base-uncased",
        verbose=False
    )
    return F1.mean().item()*100

def compare_product_review_similarity(review_data, product_data):
    """
    Calculates a similarity score between a review and a product based on
    categories, brands, and keywords, including a comparison of full product
    title with review information using BERTScore.
    """
    similarity_score = 0

    # Category Matching (Highest weight)
    if review_data.get('product category') == product_data.get('product category'):
        similarity_score += 0.5

    # Brand Matching (Medium weight)
    if review_data.get('brand') == product_data.get('brand'):
        similarity_score += 0.3

    # String Comparison (BERTScore) between Product Title and Review Data
    review_info_string = " ".join(
        [
            review_data.get("product category"),
            review_data.get("brand"),
            " ".join(review_data.get("other keywords")),
        ]
    )

    product_info_string = " ".join(
        [
            product_data.get("product category"),
            product_data.get("brand"),
            " ".join(product_data.get("other keywords")),
        ]
    )

    P, R, F1 = score(
        [product_info_string],
        [review_info_string],
        lang="en",
        model_type="bert-base-uncased",
        verbose=False
    )

    similarity_score += F1.mean().item() * 0.2

    return round(min(1, similarity_score) * 100)

# %% [markdown]
# We chose only 3 random review and products for further comparison.

# %%
random_reviews = random.sample(reviews, 3)
random_products = random.sample(product_offers, 3)

# %%
similarity_results = {}

for model in models:
    similarity_results[model] = {}

    for review in random_reviews:
        review_json = results[model][review]
        review_keywords = review_json.get('other keywords', [])

        for product in random_products:
            product_json = product_results[model][product]
            product_keywords = product_json.get('other keywords', [])
            
            # Calculate similarity rates for the chosen model, review, and product
            similarity_rate_m_1 = round(compare_json_objects_with_keywords_method_1(review_json, product_json), 2)
            similarity_rate_m_2 = round(compare_json_objects_with_keywords_method_2(review_json, product_json), 2)
            bert_score = round(compare_keywords_with_bert_score(review_keywords, product_keywords), 2)
            custom_score = round(compare_product_review_similarity(review_json, product_json), 2)

            # Store results in nested dictionary structure
            similarity_results[model][(review, product)] = {
                "similarity_1": similarity_rate_m_1,
                "similarity_2": similarity_rate_m_2,
                "bert_score": bert_score,
                "custom_score": custom_score,
                "review_extracted": review_json,
                "product_extracted": product_json,
            }

similarity_results
# Out:
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# {'Qwen/Qwen2.5-7B-Instruct': {('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 29.47,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food',
#      'highly recommend',
#      'Finish Quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['tough on grease', 'no residue left']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 38.62,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food',
#      'highly recommend',
#      'Finish Quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 27.25,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food',
#      'highly recommend',
#      'Finish Quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 31.69,
#    'custom_score': 65,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['tough on grease', 'no residue left']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 63.82,
#    'custom_score': 64,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 34.68,
#    'custom_score': 64,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 33.33,
#    'similarity_2': 0,
#    'bert_score': 29.07,
#    'custom_score': 42,
#    'review_extracted': {'product category': 'Naphtha',
#     'brand': 'N/A',
#     'other keywords': ['sheen', 'protected', 'skin']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['tough on grease', 'no residue left']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 33.33,
#    'similarity_2': 0,
#    'bert_score': 53.91,
#    'custom_score': 41,
#    'review_extracted': {'product category': 'Naphtha',
#     'brand': 'N/A',
#     'other keywords': ['sheen', 'protected', 'skin']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'N/A',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 32.76,
#    'custom_score': 9,
#    'review_extracted': {'product category': 'Naphtha',
#     'brand': 'N/A',
#     'other keywords': ['sheen', 'protected', 'skin']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}}},
#  'meta-llama/Llama-3.1-8B-Instruct': {('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 86.67,
#    'similarity_2': 80,
#    'bert_score': 34.95,
#    'custom_score': 97,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['quantum', 'finish', 'dishwasher', 'detergent']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['finish', 'detergent', 'grease']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 10.0,
#    'similarity_2': 0,
#    'bert_score': 53.45,
#    'custom_score': 13,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['quantum', 'finish', 'dishwasher', 'detergent']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['power', 'detergent', 'clothes', 'clean']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 10.0,
#    'similarity_2': 0,
#    'bert_score': 43.47,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['quantum', 'finish', 'dishwasher', 'detergent']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['power', 'great', 'detergent']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 55.4,
#    'custom_score': 13,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['finish', 'detergent', 'grease']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 76.67,
#    'similarity_2': 75,
#    'bert_score': 44.43,
#    'custom_score': 96,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['power', 'detergent', 'clothes', 'clean']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 59.12,
#    'custom_score': 64,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['power', 'great', 'detergent']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 32.97,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected skin', 'slight sheen']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['finish', 'detergent', 'grease']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 29.13,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected skin', 'slight sheen']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['power', 'detergent', 'clothes', 'clean']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 38.56,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected skin', 'slight sheen']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['power', 'great', 'detergent']}}},
#  'google/gemma-2-9b-it': {('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 66.67,
#    'similarity_2': 70,
#    'bert_score': 43.88,
#    'custom_score': 95,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['baked-on food', 'highly recommend']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 22.39,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['baked-on food', 'highly recommend']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean', 'Clothes', 'Every Time']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 41.2,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['baked-on food', 'highly recommend']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 31.69,
#    'custom_score': 13,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'odor']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 66.67,
#    'similarity_2': 70,
#    'bert_score': 66.81,
#    'custom_score': 97,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean', 'Clothes', 'Every Time']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 34.68,
#    'custom_score': 65,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 47.95,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected', 'slight sheen']},
#    'product_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 33.25,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected', 'slight sheen']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean', 'Clothes', 'Every Time']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 51.39,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['protected', 'slight sheen']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}}},
#  'ministral-8b-latest': {('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 33.33,
#    'similarity_2': 0,
#    'bert_score': 46.84,
#    'custom_score': 43,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food', 'quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 28.25,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food', 'quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('Gets rid of even the most stubborn baked-on food. Highly recommend Finish Quantum.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 43.73,
#    'custom_score': 12,
#    'review_extracted': {'product category': 'Dishwasher Detergents',
#     'brand': 'Finish',
#     'other keywords': ['stubborn baked-on food', 'quantum']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 31.69,
#    'custom_score': 66,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 66.67,
#    'similarity_2': 70,
#    'bert_score': 63.82,
#    'custom_score': 96,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('Gets my clothes fresh and clean every time. No lingering odor with Tide.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 33.33,
#    'similarity_2': 30,
#    'bert_score': 34.68,
#    'custom_score': 64,
#    'review_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['fresh', 'clean', 'no lingering odor']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Finish Detergent – Tough on Grease, No Residue Left'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 43.29,
#    'custom_score': 11,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['leaves a slight sheen', 'protected skin feels']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Finish',
#     'other keywords': ['Tough on Grease', 'No Residue Left']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Tide Powder Detergent – Fresh, Clean Clothes Every Time'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 34.77,
#    'custom_score': 11,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['leaves a slight sheen', 'protected skin feels']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Tide',
#     'other keywords': ['Fresh', 'Clean Clothes', 'Every Time']}},
#   ('It leaves a slight sheen, but I love how protected my skin feels.',
#    'Arm & Hammer Powder Detergent – Great Value, Lasts Forever'): {'similarity_1': 0.0,
#    'similarity_2': 0,
#    'bert_score': 46.3,
#    'custom_score': 10,
#    'review_extracted': {'product category': 'Sunscreens',
#     'brand': 'N/A',
#     'other keywords': ['leaves a slight sheen', 'protected skin feels']},
#    'product_extracted': {'product category': 'Powder Detergents for Laundry',
#     'brand': 'Arm & Hammer',
#     'other keywords': ['Great Value', 'Lasts Forever']}}}}

# %%
import pandas as pd


rows = []

for model, reviews in similarity_results.items():
    for (review, product), scores in reviews.items():
        row = {
            'review': review,
            'product': product,
            'review_extracted': scores['review_extracted'],
            'product_extracted': scores['product_extracted'],
            'model': model,
            'similarity_1': scores['similarity_1'],
            'similarity_2': scores['similarity_2'],
            'bert_score': scores['bert_score'],
            'custom_score': scores['custom_score']
        }
        rows.append(row)

df = pd.DataFrame(rows)
df.sort_values(['review', 'product'])
# Out:
#                                                review  \
# 5   Gets my clothes fresh and clean every time. No...
# 14  Gets my clothes fresh and clean every time. No...
# 23  Gets my clothes fresh and clean every time. No...
# 32  Gets my clothes fresh and clean every time. No...
# 3   Gets my clothes fresh and clean every time. No...
# 12  Gets my clothes fresh and clean every time. No...
# 21  Gets my clothes fresh and clean every time. No...
# 30  Gets my clothes fresh and clean every time. No...
# 4   Gets my clothes fresh and clean every time. No...
# 13  Gets my clothes fresh and clean every time. No...
# 22  Gets my clothes fresh and clean every time. No...
# 31  Gets my clothes fresh and clean every time. No...
# 2   Gets rid of even the most stubborn baked-on fo...
# 11  Gets rid of even the most stubborn baked-on fo...
# 20  Gets rid of even the most stubborn baked-on fo...
# 29  Gets rid of even the most stubborn baked-on fo...
# 0   Gets rid of even the most stubborn baked-on fo...
# 9   Gets rid of even the most stubborn baked-on fo...
# 18  Gets rid of even the most stubborn baked-on fo...
# 27  Gets rid of even the most stubborn baked-on fo...
# 1   Gets rid of even the most stubborn baked-on fo...
# 10  Gets rid of even the most stubborn baked-on fo...
# 19  Gets rid of even the most stubborn baked-on fo...
# 28  Gets rid of even the most stubborn baked-on fo...
# 8   It leaves a slight sheen, but I love how prote...
# 17  It leaves a slight sheen, but I love how prote...
# 26  It leaves a slight sheen, but I love how prote...
# 35  It leaves a slight sheen, but I love how prote...
# 6   It leaves a slight sheen, but I love how prote...
# 15  It leaves a slight sheen, but I love how prote...
# 24  It leaves a slight sheen, but I love how prote...
# 33  It leaves a slight sheen, but I love how prote...
# 7   It leaves a slight sheen, but I love how prote...
# 16  It leaves a slight sheen, but I love how prote...
# 25  It leaves a slight sheen, but I love how prote...
# 34  It leaves a slight sheen, but I love how prote...
#
#                                               product  \
# 5   Arm & Hammer Powder Detergent – Great Value, L...
# 14  Arm & Hammer Powder Detergent – Great Value, L...
# 23  Arm & Hammer Powder Detergent – Great Value, L...
# 32  Arm & Hammer Powder Detergent – Great Value, L...
# 3   Finish Detergent – Tough on Grease, No Residue...
# 12  Finish Detergent – Tough on Grease, No Residue...
# 21  Finish Detergent – Tough on Grease, No Residue...
# 30  Finish Detergent – Tough on Grease, No Residue...
# 4   Tide Powder Detergent – Fresh, Clean Clothes E...
# 13  Tide Powder Detergent – Fresh, Clean Clothes E...
# 22  Tide Powder Detergent – Fresh, Clean Clothes E...
# 31  Tide Powder Detergent – Fresh, Clean Clothes E...
# 2   Arm & Hammer Powder Detergent – Great Value, L...
# 11  Arm & Hammer Powder Detergent – Great Value, L...
# 20  Arm & Hammer Powder Detergent – Great Value, L...
# 29  Arm & Hammer Powder Detergent – Great Value, L...
# 0   Finish Detergent – Tough on Grease, No Residue...
# 9   Finish Detergent – Tough on Grease, No Residue...
# 18  Finish Detergent – Tough on Grease, No Residue...
# 27  Finish Detergent – Tough on Grease, No Residue...
# 1   Tide Powder Detergent – Fresh, Clean Clothes E...
# 10  Tide Powder Detergent – Fresh, Clean Clothes E...
# 19  Tide Powder Detergent – Fresh, Clean Clothes E...
# 28  Tide Powder Detergent – Fresh, Clean Clothes E...
# 8   Arm & Hammer Powder Detergent – Great Value, L...
# 17  Arm & Hammer Powder Detergent – Great Value, L...
# 26  Arm & Hammer Powder Detergent – Great Value, L...
# 35  Arm & Hammer Powder Detergent – Great Value, L...
# 6   Finish Detergent – Tough on Grease, No Residue...
# 15  Finish Detergent – Tough on Grease, No Residue...
# 24  Finish Detergent – Tough on Grease, No Residue...
# 33  Finish Detergent – Tough on Grease, No Residue...
# 7   Tide Powder Detergent – Fresh, Clean Clothes E...
# 16  Tide Powder Detergent – Fresh, Clean Clothes E...
# 25  Tide Powder Detergent – Fresh, Clean Clothes E...
# 34  Tide Powder Detergent – Fresh, Clean Clothes E...
#
#                                      review_extracted  \
# 5   {'product category': 'Powder Detergents for La...
# 14  {'product category': 'Powder Detergents for La...
# 23  {'product category': 'Powder Detergents for La...
# 32  {'product category': 'Powder Detergents for La...
# 3   {'product category': 'Powder Detergents for La...
# 12  {'product category': 'Powder Detergents for La...
# 21  {'product category': 'Powder Detergents for La...
# 30  {'product category': 'Powder Detergents for La...
# 4   {'product category': 'Powder Detergents for La...
# 13  {'product category': 'Powder Detergents for La...
# 22  {'product category': 'Powder Detergents for La...
# 31  {'product category': 'Powder Detergents for La...
# 2   {'product category': 'Dishwasher Detergents', ...
# 11  {'product category': 'Dishwasher Detergents', ...
# 20  {'product category': 'Dishwasher Detergents', ...
# 29  {'product category': 'Dishwasher Detergents', ...
# 0   {'product category': 'Dishwasher Detergents', ...
# 9   {'product category': 'Dishwasher Detergents', ...
# 18  {'product category': 'Dishwasher Detergents', ...
# 27  {'product category': 'Dishwasher Detergents', ...
# 1   {'product category': 'Dishwasher Detergents', ...
# 10  {'product category': 'Dishwasher Detergents', ...
# 19  {'product category': 'Dishwasher Detergents', ...
# 28  {'product category': 'Dishwasher Detergents', ...
# 8   {'product category': 'Naphtha', 'brand': 'N/A'...
# 17  {'product category': 'Sunscreens', 'brand': 'N...
# 26  {'product category': 'Sunscreens', 'brand': 'N...
# 35  {'product category': 'Sunscreens', 'brand': 'N...
# 6   {'product category': 'Naphtha', 'brand': 'N/A'...
# 15  {'product category': 'Sunscreens', 'brand': 'N...
# 24  {'product category': 'Sunscreens', 'brand': 'N...
# 33  {'product category': 'Sunscreens', 'brand': 'N...
# 7   {'product category': 'Naphtha', 'brand': 'N/A'...
# 16  {'product category': 'Sunscreens', 'brand': 'N...
# 25  {'product category': 'Sunscreens', 'brand': 'N...
# 34  {'product category': 'Sunscreens', 'brand': 'N...
#
#                                     product_extracted  \
# 5   {'product category': 'Powder Detergents for La...
# 14  {'product category': 'Powder Detergents for La...
# 23  {'product category': 'Powder Detergents for La...
# 32  {'product category': 'Powder Detergents for La...
# 3   {'product category': 'Powder Detergents for La...
# 12  {'product category': 'Dishwasher Detergents', ...
# 21  {'product category': 'Dishwasher Detergents', ...
# 30  {'product category': 'Powder Detergents for La...
# 4   {'product category': 'Powder Detergents for La...
# 13  {'product category': 'Powder Detergents for La...
# 22  {'product category': 'Powder Detergents for La...
# 31  {'product category': 'Powder Detergents for La...
# 2   {'product category': 'Powder Detergents for La...
# 11  {'product category': 'Powder Detergents for La...
# 20  {'product category': 'Powder Detergents for La...
# 29  {'product category': 'Powder Detergents for La...
# 0   {'product category': 'Powder Detergents for La...
# 9   {'product category': 'Dishwasher Detergents', ...
# 18  {'product category': 'Dishwasher Detergents', ...
# 27  {'product category': 'Powder Detergents for La...
# 1   {'product category': 'Powder Detergents for La...
# 10  {'product category': 'Powder Detergents for La...
# 19  {'product category': 'Powder Detergents for La...
# 28  {'product category': 'Powder Detergents for La...
# 8   {'product category': 'Powder Detergents for La...
# 17  {'product category': 'Powder Detergents for La...
# 26  {'product category': 'Powder Detergents for La...
# 35  {'product category': 'Powder Detergents for La...
# 6   {'product category': 'Powder Detergents for La...
# 15  {'product category': 'Dishwasher Detergents', ...
# 24  {'product category': 'Dishwasher Detergents', ...
# 33  {'product category': 'Powder Detergents for La...
# 7   {'product category': 'Powder Detergents for La...
# 16  {'product category': 'Powder Detergents for La...
# 25  {'product category': 'Powder Detergents for La...
# 34  {'product category': 'Powder Detergents for La...
#
#                                model  similarity_1  similarity_2  bert_score  \
# 5           Qwen/Qwen2.5-7B-Instruct         33.33            30       34.68
# 14  meta-llama/Llama-3.1-8B-Instruct         33.33            30       59.12
# 23              google/gemma-2-9b-it         33.33            30       34.68
# 32               ministral-8b-latest         33.33            30       34.68
# 3           Qwen/Qwen2.5-7B-Instruct         33.33            30       31.69
# 12  meta-llama/Llama-3.1-8B-Instruct          0.00             0       55.40
# 21              google/gemma-2-9b-it          0.00             0       31.69
# 30               ministral-8b-latest         33.33            30       31.69
# 4           Qwen/Qwen2.5-7B-Instruct         33.33            30       63.82
# 13  meta-llama/Llama-3.1-8B-Instruct         76.67            75       44.43
# 22              google/gemma-2-9b-it         66.67            70       66.81
# 31               ministral-8b-latest         66.67            70       63.82
# 2           Qwen/Qwen2.5-7B-Instruct          0.00             0       27.25
# 11  meta-llama/Llama-3.1-8B-Instruct         10.00             0       43.47
# 20              google/gemma-2-9b-it          0.00             0       41.20
# 29               ministral-8b-latest          0.00             0       43.73
# 0           Qwen/Qwen2.5-7B-Instruct          0.00             0       29.47
# 9   meta-llama/Llama-3.1-8B-Instruct         86.67            80       34.95
# 18              google/gemma-2-9b-it         66.67            70       43.88
# 27               ministral-8b-latest         33.33             0       46.84
# 1           Qwen/Qwen2.5-7B-Instruct          0.00             0       38.62
# 10  meta-llama/Llama-3.1-8B-Instruct         10.00             0       53.45
# 19              google/gemma-2-9b-it          0.00             0       22.39
# 28               ministral-8b-latest          0.00             0       28.25
# 8           Qwen/Qwen2.5-7B-Instruct          0.00             0       32.76
# 17  meta-llama/Llama-3.1-8B-Instruct          0.00             0       38.56
# 26              google/gemma-2-9b-it          0.00             0       51.39
# 35               ministral-8b-latest          0.00             0       46.30
# 6           Qwen/Qwen2.5-7B-Instruct         33.33             0       29.07
# 15  meta-llama/Llama-3.1-8B-Instruct          0.00             0       32.97
# 24              google/gemma-2-9b-it          0.00             0       47.95
# 33               ministral-8b-latest          0.00             0       43.29
# 7           Qwen/Qwen2.5-7B-Instruct         33.33             0       53.91
# 16  meta-llama/Llama-3.1-8B-Instruct          0.00             0       29.13
# 25              google/gemma-2-9b-it          0.00             0       33.25
# 34               ministral-8b-latest          0.00             0       34.77
#
#     custom_score
# 5             64
# 14            64
# 23            65
# 32            64
# 3             65
# 12            13
# 21            13
# 30            66
# 4             64
# 13            96
# 22            97
# 31            96
# 2             12
# 11            12
# 20            12
# 29            12
# 0             12
# 9             97
# 18            95
# 27            43
# 1             10
# 10            13
# 19            12
# 28            12
# 8              9
# 17            10
# 26            10
# 35            10
# 6             42
# 15            10
# 24            10
# 33            11
# 7             41
# 16            10
# 25            10
# 34            11

# %% [markdown]
# From the results we can see that `Llama3.1-7b` exhibits in brand and keywords extraction, hence having higher score results than other models for the same pairs (*review-product*). The rest of the models behave in a similar manner.
